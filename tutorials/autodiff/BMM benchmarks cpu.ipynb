# %% [markdown]
# # BMM OR MATMUL

# %%
import numpy as np
import torch
import torch.utils.benchmark as benchmark
#import jax
#import jax.numpy as jnp
# mute this since it requires py3.8 and py3.10 env, not default py3.11
import tensorflow as tf
import iree.compiler
import iree.runtime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import wraps
from time import perf_counter
from collections import namedtuple

from ragdoll.utils import *
from ragdoll.visualisation import *
from ragdoll.benchmark import *
import ragdoll
# Out:
# 2024-03-29 18:32:08.061325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
ragdoll_results = []
ragdoll_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33
    mm_src = f"""module BRKLEFT
      func.func @matmul(%arg0: tensor<{B}x{M}x{K}xf32>, %arg1: tensor<{B}x{K}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32> BRKLEFT
        # %cst = arith.constant 0.000000e+00 : f32
        %0 = tensor.empty() : tensor<{B}x{M}x{N}xf32>
        %1 = linalg.fill ins(%cst : f32) outs(%0 : tensor<{B}x{M}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32>
        %2 = linalg.batch_matmul ins(%arg0, %arg1 : tensor<{B}x{M}x{K}xf32>, tensor<{B}x{K}x{N}xf32>) outs(%1 : tensor<{B}x{M}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32>
        return %2 : tensor<{B}x{M}x{N}xf32>
      BRKRIGHT
    BRKRIGHT"""

    mm_src = mm_src.replace("BRKLEFT", "{")
    mm_src = mm_src.replace("BRKRIGHT", "}")
    
    mlir_file_name = "mm_src.mlir"
    with open(mlir_file_name, "w", encoding="utf-8") as mlir_file:
        mlir_file.write(mm_src)
    """
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=cuda \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-hal-cuda-llvm-target-arch=sm_86
    """
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=llvm-cpu \
    --iree-llvmcpu-fail-on-out-of-bounds-stack-allocation=0 \
    --iree-opt-const-eval=1 \
    --iree-opt-const-expr-hoisting=1 \
    --iree-opt-numeric-precision-reduction=1 \
    --iree-llvmcpu-target-cpu-features=host \
    --iree-llvmcpu-enable-ukernels=all \
    --iree-llvmcpu-slp-vectorization=1 \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-llvmcpu-target-triple=x86_64-pc-linux-elf
    #"""
    #print(tf_bench)
    
    
    ragdoll_bench = ragdoll_op_benchmark(
        mlir_file_name + ".vmfb",
        [(B, M, K), (B, K, N)],
        device='cpu',
        warmups=3,
        repetitions=BENCH_CNT, 
        measure_count=1)
    #print(np.mean(ragdoll_bench))
    ragdoll_results.append(np.mean(ragdoll_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    ragdoll_throughput.append(GFLOPS/np.mean(ragdoll_bench))
ragdoll_data = pd.DataFrame([list(range(16, 1300, 16)), ragdoll_results])
ragdoll_data.to_csv('ragdoll_output_bmm_cpu.csv')
# Out:
# benchmarking 4x16x16x16
# /root/AlbertResearches/researches/Ragdoll/ragdoll/benchmark/op_benchmark.py:192: UserWarning: Making copy of unaligned VmModule buffer. It is recommended to make this deterministic by calling `copy_buffer` to always make a copy or `mmap` to efficiently load from a file. This warning can be silenced by adding `warn_if_copy=False` to `from_buffer`
#   vmm = iree.runtime.VmModule.from_flatbuffer(vmi, binary_data)
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
torch_results = []
torch_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33


    # cpu or gpu
    torch_bench = torch_op_benchmark('batch-matmul', 
                                     [(B, M, K), (B, K, N)], 
                                     device='cpu',
                                     warmups=0,
                                     repetitions=BENCH_CNT, 
                                     measure_count=3)
    #print(torch_bench)

    torch_results.append(np.mean(torch_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    torch_throughput.append(GFLOPS/np.mean(torch_bench))
    #tf_results.append(np.mean(tf_bench))
    #ragdoll_results.append(np.mean(ragdoll_bench))
torch_data = pd.DataFrame([list(range(16, 1300, 16)), torch_results])
torch_data.to_csv('torch_output_bmm_cpu.csv')
# Out:
# benchmarking 4x16x16x16
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
tf_results = []
tf_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33
    
    #print(torch_bench)
    
    tf_bench = tf_op_benchmark('matmul', 
                                 [(B, M, K), (B, K, N)],
                                 device='cpu',
                                 warmups=0,
                                 repetitions=BENCH_CNT, 
                                 measure_count=1)
    #print(tf_bench)
    
    tf_results.append(np.mean(tf_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    tf_throughput.append(GFLOPS/np.mean(tf_bench))
tf_data = pd.DataFrame([list(range(16, 1300, 16)), tf_results])
tf_data.to_csv('tf_output_bmm_cpu.csv')
# Out:
# benchmarking 4x16x16x16
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# 2024-03-29 18:59:12.500731: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-29 18:59:12.500838: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-03-29 18:59:12.500967: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.501135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.78GiB deviceMemoryBandwidth: 417.29GiB/s
# 2024-03-29 18:59:12.501155: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-29 18:59:12.502404: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-29 18:59:12.502433: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-29 18:59:12.502450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-29 18:59:12.502463: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-29 18:59:12.503524: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-29 18:59:12.503999: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-29 18:59:12.506065: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-29 18:59:12.506147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.506309: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.506393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-29 18:59:12.507116: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-29 18:59:12.509421: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-29 18:59:12.509482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.509585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.78GiB deviceMemoryBandwidth: 417.29GiB/s
# 2024-03-29 18:59:12.509603: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-29 18:59:12.509628: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-29 18:59:12.509638: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-29 18:59:12.509643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-29 18:59:12.509648: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-29 18:59:12.509656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-29 18:59:12.509668: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-29 18:59:12.509677: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-29 18:59:12.509702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.509804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.509885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-29 18:59:12.509993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-03-29 18:59:12.510000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-03-29 18:59:12.510005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-03-29 18:59:12.510068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.510179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.510287: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:59:12.510384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 135 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:21:00.0, compute capability: 8.6)
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
# do throughput
names = ['pytorch', 'tensorflow', 'nabla']
results = [torch_results, tf_results, ragdoll_results]
throughputs = [torch_throughput, tf_throughput, ragdoll_throughput]

from matplotlib.ticker import FuncFormatter
line_data = pd.DataFrame(dict(zip(names, [res for res in throughputs])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in throughputs])))

plt.rcParams["figure.dpi"] = 300
plt.rcParams["figure.figsize"] = (3, 3)

fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Throughput (TFLOPS)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()

line_data = pd.DataFrame(dict(zip(names, [res for res in results])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in results])))
fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Time Cost (ms)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()
# Out:
# /tmp/ipykernel_1113459/1917048578.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)
# /tmp/ipykernel_1113459/1917048578.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)
