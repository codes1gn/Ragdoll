# %% [markdown]
# # BMM OR MATMUL

# %%
import numpy as np
import torch
import torch.utils.benchmark as benchmark
#import jax
#import jax.numpy as jnp
# mute this since it requires py3.8 and py3.10 env, not default py3.11
import tensorflow as tf
import iree.compiler
import iree.runtime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import wraps
from time import perf_counter
from collections import namedtuple

from ragdoll.utils import *
from ragdoll.visualisation import *
from ragdoll.benchmark import *
import ragdoll
# Out:
# 2024-03-29 18:24:37.284978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
ragdoll_results = []
ragdoll_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33
    mm_src = f"""module BRKLEFT
      func.func @matmul(%arg0: tensor<{B}x{M}x{K}xf32>, %arg1: tensor<{B}x{K}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32> BRKLEFT
        # %cst = arith.constant 0.000000e+00 : f32
        %0 = tensor.empty() : tensor<{B}x{M}x{N}xf32>
        %1 = linalg.fill ins(%cst : f32) outs(%0 : tensor<{B}x{M}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32>
        %2 = linalg.batch_matmul ins(%arg0, %arg1 : tensor<{B}x{M}x{K}xf32>, tensor<{B}x{K}x{N}xf32>) outs(%1 : tensor<{B}x{M}x{N}xf32>) -> tensor<{B}x{M}x{N}xf32>
        return %2 : tensor<{B}x{M}x{N}xf32>
      BRKRIGHT
    BRKRIGHT"""

    mm_src = mm_src.replace("BRKLEFT", "{")
    mm_src = mm_src.replace("BRKRIGHT", "}")
    
    mlir_file_name = "mm_src.mlir"
    with open(mlir_file_name, "w", encoding="utf-8") as mlir_file:
        mlir_file.write(mm_src)
    #"""
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=cuda \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-hal-cuda-llvm-target-arch=sm_86
    """
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=llvm-cpu \
    --iree-llvmcpu-fail-on-out-of-bounds-stack-allocation=0 \
    --iree-opt-const-eval=1 \
    --iree-opt-const-expr-hoisting=1 \
    --iree-opt-numeric-precision-reduction=1 \
    --iree-llvmcpu-target-cpu-features=host \
    --iree-llvmcpu-enable-ukernels=all \
    --iree-llvmcpu-slp-vectorization=1 \
    --iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
    --iree-llvmcpu-target-triple=x86_64-pc-linux-elf
    """
    #print(tf_bench)
    
    
    ragdoll_bench = ragdoll_op_benchmark(
        mlir_file_name + ".vmfb",
        [(B, M, K), (B, K, N)],
        device='gpu',
        warmups=3,
        repetitions=BENCH_CNT, 
        measure_count=1)
    #print(np.mean(ragdoll_bench))
    ragdoll_results.append(np.mean(ragdoll_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    ragdoll_throughput.append(GFLOPS/np.mean(ragdoll_bench))
ragdoll_data = pd.DataFrame([list(range(16, 1300, 16)), ragdoll_results])
ragdoll_data.to_csv('ragdoll_output_bmm_gpu.csv')
# Out:
# benchmarking 4x16x16x16
# /root/AlbertResearches/researches/Ragdoll/ragdoll/benchmark/op_benchmark.py:192: UserWarning: Making copy of unaligned VmModule buffer. It is recommended to make this deterministic by calling `copy_buffer` to always make a copy or `mmap` to efficiently load from a file. This warning can be silenced by adding `warn_if_copy=False` to `from_buffer`
#   vmm = iree.runtime.VmModule.from_flatbuffer(vmi, binary_data)
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
torch_results = []
torch_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33


    # cpu or gpu
    torch_bench = torch_op_benchmark('batch-matmul', 
                                     [(B, M, K), (B, K, N)], 
                                     device='gpu',
                                     warmups=0,
                                     repetitions=BENCH_CNT, 
                                     measure_count=11)
    #print(torch_bench)

    torch_results.append(np.mean(torch_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    torch_throughput.append(GFLOPS/np.mean(torch_bench))
    #tf_results.append(np.mean(tf_bench))
    #ragdoll_results.append(np.mean(ragdoll_bench))
torch_data = pd.DataFrame([list(range(16, 1300, 16)), torch_results])
torch_data.to_csv('torch_output_bmm_gpu.csv')
# Out:
# benchmarking 4x16x16x16
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
tf_results = []
tf_throughput = []
for size in list(range(16, 1300, 16)):
    B = 4
    M = size
    N = size
    K = size
    print("benchmarking {}x{}x{}x{}".format(B, M, K, N))
    BENCH_CNT=33
    
    #print(torch_bench)
    
    tf_bench = tf_op_benchmark('matmul', 
                                 [(B, M, K), (B, K, N)],
                                 device='gpu',
                                 warmups=0,
                                 repetitions=BENCH_CNT, 
                                 measure_count=11)
    #print(tf_bench)
    
    tf_results.append(np.mean(tf_bench))
    GFLOPS = 2*B*M*K*N*1000000000
    tf_throughput.append(GFLOPS/np.mean(tf_bench))
tf_data = pd.DataFrame([list(range(16, 1300, 16)), tf_results])
tf_data.to_csv('tf_output_bmm_gpu.csv')
# Out:
# benchmarking 4x16x16x16
# 2024-03-29 18:28:25.833897: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-29 18:28:25.833994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-03-29 18:28:25.834112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.834269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.78GiB deviceMemoryBandwidth: 417.29GiB/s
# 2024-03-29 18:28:25.834287: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-29 18:28:25.835572: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-29 18:28:25.835601: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-29 18:28:25.835617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-29 18:28:25.835631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-29 18:28:25.836758: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-29 18:28:25.837217: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-29 18:28:25.839416: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-29 18:28:25.839508: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.839664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.839746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-29 18:28:25.840582: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-29 18:28:25.842774: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-29 18:28:25.842834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.842933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3070 computeCapability: 8.6
# coreClock: 1.77GHz coreCount: 46 deviceMemorySize: 7.78GiB deviceMemoryBandwidth: 417.29GiB/s
# 2024-03-29 18:28:25.842953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-29 18:28:25.842982: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-29 18:28:25.842992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-29 18:28:25.842997: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-29 18:28:25.843002: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-29 18:28:25.843011: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-29 18:28:25.843020: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-29 18:28:25.843029: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-29 18:28:25.843054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.843154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.843233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-29 18:28:25.843339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-03-29 18:28:25.843344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-03-29 18:28:25.843347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-03-29 18:28:25.843412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.843518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.843621: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-29 18:28:25.843715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6920 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:21:00.0, compute capability: 8.6)
# benchmarking 4x32x32x32
# benchmarking 4x48x48x48
# benchmarking 4x64x64x64
# benchmarking 4x80x80x80
# benchmarking 4x96x96x96
# benchmarking 4x112x112x112
# benchmarking 4x128x128x128
# benchmarking 4x144x144x144
# benchmarking 4x160x160x160
# benchmarking 4x176x176x176
# benchmarking 4x192x192x192
# benchmarking 4x208x208x208
# benchmarking 4x224x224x224
# benchmarking 4x240x240x240
# benchmarking 4x256x256x256
# benchmarking 4x272x272x272
# benchmarking 4x288x288x288
# benchmarking 4x304x304x304
# benchmarking 4x320x320x320
# benchmarking 4x336x336x336
# benchmarking 4x352x352x352
# benchmarking 4x368x368x368
# benchmarking 4x384x384x384
# benchmarking 4x400x400x400
# benchmarking 4x416x416x416
# benchmarking 4x432x432x432
# benchmarking 4x448x448x448
# benchmarking 4x464x464x464
# benchmarking 4x480x480x480
# benchmarking 4x496x496x496
# benchmarking 4x512x512x512
# benchmarking 4x528x528x528
# benchmarking 4x544x544x544
# benchmarking 4x560x560x560
# benchmarking 4x576x576x576
# benchmarking 4x592x592x592
# benchmarking 4x608x608x608
# benchmarking 4x624x624x624
# benchmarking 4x640x640x640
# benchmarking 4x656x656x656
# benchmarking 4x672x672x672
# benchmarking 4x688x688x688
# benchmarking 4x704x704x704
# benchmarking 4x720x720x720
# benchmarking 4x736x736x736
# benchmarking 4x752x752x752
# benchmarking 4x768x768x768
# benchmarking 4x784x784x784
# benchmarking 4x800x800x800
# benchmarking 4x816x816x816
# benchmarking 4x832x832x832
# benchmarking 4x848x848x848
# benchmarking 4x864x864x864
# benchmarking 4x880x880x880
# benchmarking 4x896x896x896
# benchmarking 4x912x912x912
# benchmarking 4x928x928x928
# benchmarking 4x944x944x944
# benchmarking 4x960x960x960
# benchmarking 4x976x976x976
# benchmarking 4x992x992x992
# benchmarking 4x1008x1008x1008
# benchmarking 4x1024x1024x1024
# benchmarking 4x1040x1040x1040
# benchmarking 4x1056x1056x1056
# benchmarking 4x1072x1072x1072
# benchmarking 4x1088x1088x1088
# benchmarking 4x1104x1104x1104
# benchmarking 4x1120x1120x1120
# benchmarking 4x1136x1136x1136
# benchmarking 4x1152x1152x1152
# benchmarking 4x1168x1168x1168
# benchmarking 4x1184x1184x1184
# benchmarking 4x1200x1200x1200
# benchmarking 4x1216x1216x1216
# benchmarking 4x1232x1232x1232
# benchmarking 4x1248x1248x1248
# benchmarking 4x1264x1264x1264
# benchmarking 4x1280x1280x1280
# benchmarking 4x1296x1296x1296

# %%
# do throughput
names = ['pytorch', 'tensorflow', 'nabla']
results = [torch_results, tf_results, ragdoll_results]
throughputs = [torch_throughput, tf_throughput, ragdoll_throughput]

from matplotlib.ticker import FuncFormatter
line_data = pd.DataFrame(dict(zip(names, [res for res in throughputs])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in throughputs])))

plt.rcParams["figure.dpi"] = 300
plt.rcParams["figure.figsize"] = (3, 3)

fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Throughput (TFLOPS)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()

line_data = pd.DataFrame(dict(zip(names, [res for res in results])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in results])))
fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Time Cost (ms)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()
# Out:
# /tmp/ipykernel_1091201/1917048578.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)
# /tmp/ipykernel_1091201/1917048578.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)

# %%
print(torch_results)
# Out:
# [0.024746526186623843, 0.02016124287337968, 0.013034582938537126, 0.013063707935416008, 0.013217948295032351, 0.014891770999293685, 0.016646713695742867, 0.018321070050405078, 0.020125921887471324, 0.021729120579304453, 0.02338752130010568, 0.025050345161729607, 0.026722182070749192, 0.02836462459206253, 0.03007234179366062, 0.03172054414742577, 0.033499339477418205, 0.035324085185678866, 0.0372053824426714, 0.03989322300866944, 0.041810084986128426, 0.04447472458782275, 0.04579189436166411, 0.048282381773159196, 0.0885974887768756, 0.09234306292182487, 0.09527180046253626, 0.09887353016817867, 0.10211956392224499, 0.10595373942750216, 0.1099607920063757, 0.11289356271261684, 0.17177197856433465, 0.17702217744894264, 0.1824331282543085, 0.18816868987539911, 0.19418444617884872, 0.1994825222275474, 0.20660700137950175, 0.21287310386163802, 0.28567422006905246, 0.29093689303178105, 0.3031455288248614, 0.30980442878956965, 0.31739075927284466, 0.3268122750003476, 0.33531038054667883, 0.34302883311982985, 0.4342344843528487, 0.4434850523581846, 0.45474608667379574, 0.46680280913088273, 0.478873611748547, 0.48513468816753264, 0.5020204105365702, 0.507480675257106, 0.6194604925051866, 0.6323791809441629, 0.6460826407820397, 0.6562711019325519, 0.6725539019736706, 0.6819772367306649, 0.6990347175599786, 0.707620498275297, 0.9282794255075704, 0.9442568466724116, 0.9645350949618113, 0.9833801789183589, 1.0015170112991136, 1.018232255455712, 1.0369992750817423, 1.0513568543328728, 1.2046758793602306, 1.2209823729660227, 1.2456516352977305, 1.258914025382398, 1.283654435114427, 1.297748999121104, 1.3243378378635595, 1.3386868145676027, 1.6331209213608882]

# %%
print(tf_results)
# Out:
# [0.020759493194664146, 0.020553257839738832, 0.02029776244780906, 0.019874782930064137, 0.019819611688619145, 0.020035699050945356, 0.020043580656866067, 0.01999366381936822, 0.020048178260319818, 0.019790055666416475, 0.019782174060495764, 0.020174283955051223, 0.0198958005458527, 0.019841942905394497, 0.01978217406049576, 0.01997198940308626, 0.01995688299173823, 0.020022563041077503, 0.01992535656805538, 0.02048626418941277, 0.03474080529751528, 0.037019903009588066, 0.04021852141241068, 0.04264408563451005, 0.04548409096794023, 0.046862058403078194, 0.058629952843195804, 0.09192185625228673, 0.09402558823262365, 0.09743898039678568, 0.10161557473427006, 0.10547165043097882, 0.10944857741847183, 0.11358379332487249, 0.12970758863717072, 0.17548921022861785, 0.1802851674313716, 0.18662000819014454, 0.19262644870222106, 0.19957277072034263, 0.2070800003598216, 0.2182968391859827, 0.23403180860619244, 0.2915721294308497, 0.29770730283963126, 0.30659775431819525, 0.3158185764449359, 0.3239386009447502, 0.33188194611184196, 0.3459006958428164, 0.370858457791247, 0.44512683038212386, 0.4515050199734606, 0.46197507663863424, 0.47103038504103995, 0.4908552511336061, 0.5016543648459694, 0.5082552098045665, 0.5389291064469939, 0.6266106587139372, 0.6429275533712928, 0.6582631880915198, 0.6640679908521249, 0.6816328064469267, 0.6930703302388678, 0.7052743402065982, 0.7641322028210012, 0.935013957588469, 0.9552007207528947, 0.9767280137243349, 0.9905976697433094, 1.0115364694726698, 1.0274651950384304, 1.048300877090328, 1.089228743035603, 1.2160142262776694, 1.2276034709835841, 1.2550025603659554, 1.2706600273279447, 1.2934989508846904, 1.3068746929326331]
