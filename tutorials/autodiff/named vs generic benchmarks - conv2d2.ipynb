# %% [markdown]
# # named op or generic op
# BMM, bsx197x1024, bsx1024x197 => MM, bs*197x1024, 1024xbs*197

# %%
import numpy as np
import torch
import torch.utils.benchmark as benchmark
#import jax
#import jax.numpy as jnp
# mute this since it requires py3.8 and py3.10 env, not default py3.11
#import tensorflow as tf
import iree.compiler
import iree.runtime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from functools import wraps
from time import perf_counter
from collections import namedtuple

from ragdoll.utils import *
from ragdoll.visualisation import *
from ragdoll.benchmark import *
import ragdoll
# Out:
# /tmp/ipykernel_1297970/3465895806.py:10: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
gen_results = []
gen_throughput = []
bs_list = [32, 32, 32, 32, 32, 32, 32]
hi_list = [224, 56, 28, 14, 56, 28, 14]
ci_list = [3, 64, 128, 256, 128, 256, 512]
ho_list = [112, 56, 28, 14, 56, 28, 14]
co_list = [64, 128, 256, 512, 32, 64, 128]
k_list = [7, 1, 1, 1, 3, 3, 3]
dilation_list = [1, 1, 1, 1, 1, 1, 1]
pad_list = [3, 0, 0, 0, 1, 1, 1]
stride_list = [2, 1, 1, 1, 1, 1, 1]
for size in range(255, 2, -1):
    B = 32
    HI = size
    CI = 64
    HO = size
    CO = 128
    K = 1
    D = 1
    P = 0
    S = 1
    print("benchmarking CONV #{}".format(size))
    BENCH_CNT=33
    mm_src = f"""module BRKLEFT
      func.func @matmul(%arg0: tensor<{B}x{HI}x{HI}x{CI}xf32>, %arg1: tensor<{CO}x{K}x{K}x{CI}xf32>) -> tensor<{B}x{HO}x{HO}x{CO}xf32> BRKLEFT
        # %cst = arith.constant 0.000000e+00 : f32
        %0 = tensor.empty() : tensor<{CO}xf32>
        %1 = linalg.fill ins(%cst : f32) outs(%0 : tensor<{CO}xf32>) -> tensor<{CO}xf32>
        %2 = tosa.conv2d %arg0, %arg1, %1 BRKLEFTdilation = array<i64: {D}, {D}>, pad = array<i64: {P}, {P}, {P}, {P}>, stride = array<i64: {S}, {S}>BRKRIGHT : (tensor<{B}x{HI}x{HI}x{CI}xf32>, tensor<{CO}x{K}x{K}x{CI}xf32>, tensor<{CO}xf32>) -> tensor<{B}x{HO}x{HO}x{CO}xf32>
        return %2 : tensor<{B}x{HO}x{HO}x{CO}xf32>
      BRKRIGHT
    BRKRIGHT"""

    mm_src = mm_src.replace("BRKLEFT", "{")
    mm_src = mm_src.replace("BRKRIGHT", "}")
    
    mlir_file_name = "mm_src.mlir"
    with open(mlir_file_name, "w", encoding="utf-8") as mlir_file:
        mlir_file.write(mm_src)
    #"""
    # !ragdoll-opt {mlir_file_name} --linalg-generalize-named-ops > {mlir_file_name}.generic
    # !iree-compile {mlir_file_name}.generic \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=cuda \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-hal-cuda-llvm-target-arch=sm_70
    """
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=llvm-cpu \
    --iree-llvmcpu-fail-on-out-of-bounds-stack-allocation=0 \
    --iree-opt-const-eval=1 \
    --iree-opt-const-expr-hoisting=1 \
    --iree-opt-numeric-precision-reduction=1 \
    --iree-llvmcpu-target-cpu-features=host \
    --iree-llvmcpu-enable-ukernels=all \
    --iree-llvmcpu-slp-vectorization=1 \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-llvmcpu-target-triple=x86_64-pc-linux-elf
    """
    #print(tf_bench)
    
    
    ragdoll_bench = ragdoll_op_benchmark(
        mlir_file_name + ".vmfb",
        [(B, HI, HI, CI), (CO, K, K, CI)],
        device='gpu',
        warmups=3,
        repetitions=BENCH_CNT, 
        measure_count=1)
    #print(np.mean(ragdoll_bench))
    gen_results.append(np.mean(ragdoll_bench))
    GFLOPS = 2*B*CO*CI*HO*HO*K*K*1000000000
    gen_throughput.append(GFLOPS/np.mean(ragdoll_bench))
gen_data = pd.DataFrame([list(range(16, 1000, 16)), gen_results])
gen_data.to_csv('op_spec_generic_gpu.csv')
# Out:
# benchmarking CONV #255
# /root/AlbertResearches/researches/Ragdoll/ragdoll/benchmark/op_benchmark.py:192: UserWarning: Making copy of unaligned VmModule buffer. It is recommended to make this deterministic by calling `copy_buffer` to always make a copy or `mmap` to efficiently load from a file. This warning can be silenced by adding `warn_if_copy=False` to `from_buffer`
#   vmm = iree.runtime.VmModule.from_flatbuffer(vmi, binary_data)
# benchmarking CONV #254
# benchmarking CONV #253
# benchmarking CONV #252
# benchmarking CONV #251
# benchmarking CONV #250
# benchmarking CONV #249
# benchmarking CONV #248
# benchmarking CONV #247
# benchmarking CONV #246
# benchmarking CONV #245
# benchmarking CONV #244
# benchmarking CONV #243
# benchmarking CONV #242
# benchmarking CONV #241
# benchmarking CONV #240
# benchmarking CONV #239
# benchmarking CONV #238
# benchmarking CONV #237
# benchmarking CONV #236
# benchmarking CONV #235
# benchmarking CONV #234
# benchmarking CONV #233
# benchmarking CONV #232
# benchmarking CONV #231
# benchmarking CONV #230
# benchmarking CONV #229
# benchmarking CONV #228
# benchmarking CONV #227
# benchmarking CONV #226
# benchmarking CONV #225
# benchmarking CONV #224
# benchmarking CONV #223
# benchmarking CONV #222
# benchmarking CONV #221
# benchmarking CONV #220
# benchmarking CONV #219
# benchmarking CONV #218
# benchmarking CONV #217
# benchmarking CONV #216
# benchmarking CONV #215
# benchmarking CONV #214
# benchmarking CONV #213
# benchmarking CONV #212
# benchmarking CONV #211
# benchmarking CONV #210
# benchmarking CONV #209
# benchmarking CONV #208
# benchmarking CONV #207
# benchmarking CONV #206
# benchmarking CONV #205
# benchmarking CONV #204
# benchmarking CONV #203
# benchmarking CONV #202
# benchmarking CONV #201
# benchmarking CONV #200
# benchmarking CONV #199
# benchmarking CONV #198
# benchmarking CONV #197
# benchmarking CONV #196
# benchmarking CONV #195
# benchmarking CONV #194
# benchmarking CONV #193
# benchmarking CONV #192
# benchmarking CONV #191
# benchmarking CONV #190
# benchmarking CONV #189
# benchmarking CONV #188
# benchmarking CONV #187
# benchmarking CONV #186
# benchmarking CONV #185
# benchmarking CONV #184
# benchmarking CONV #183
# benchmarking CONV #182
# benchmarking CONV #181
# benchmarking CONV #180
# benchmarking CONV #179
# benchmarking CONV #178
# benchmarking CONV #177
# benchmarking CONV #176
# benchmarking CONV #175
# benchmarking CONV #174
# benchmarking CONV #173
# benchmarking CONV #172
# benchmarking CONV #171
# benchmarking CONV #170
# benchmarking CONV #169
# benchmarking CONV #168
# benchmarking CONV #167
# benchmarking CONV #166
# benchmarking CONV #165
# benchmarking CONV #164
# benchmarking CONV #163
# benchmarking CONV #162
# benchmarking CONV #161
# benchmarking CONV #160
# benchmarking CONV #159
# benchmarking CONV #158
# benchmarking CONV #157
# benchmarking CONV #156
# benchmarking CONV #155
# benchmarking CONV #154
# benchmarking CONV #153
# benchmarking CONV #152
# benchmarking CONV #151
# benchmarking CONV #150
# benchmarking CONV #149
# benchmarking CONV #148
# benchmarking CONV #147
# benchmarking CONV #146
# benchmarking CONV #145
# benchmarking CONV #144
# benchmarking CONV #143
# benchmarking CONV #142
# benchmarking CONV #141
# benchmarking CONV #140
# benchmarking CONV #139
# benchmarking CONV #138
# benchmarking CONV #137
# benchmarking CONV #136
# benchmarking CONV #135
# benchmarking CONV #134
# benchmarking CONV #133
# benchmarking CONV #132
# benchmarking CONV #131
# benchmarking CONV #130
# benchmarking CONV #129
# benchmarking CONV #128
# benchmarking CONV #127
# benchmarking CONV #126
# benchmarking CONV #125
# benchmarking CONV #124
# benchmarking CONV #123
# benchmarking CONV #122
# benchmarking CONV #121
# benchmarking CONV #120
# benchmarking CONV #119
# benchmarking CONV #118
# benchmarking CONV #117
# benchmarking CONV #116
# benchmarking CONV #115
# benchmarking CONV #114
# benchmarking CONV #113
# benchmarking CONV #112
# benchmarking CONV #111
# benchmarking CONV #110
# benchmarking CONV #109
# benchmarking CONV #108
# benchmarking CONV #107
# benchmarking CONV #106
# benchmarking CONV #105
# benchmarking CONV #104
# benchmarking CONV #103
# benchmarking CONV #102
# benchmarking CONV #101
# benchmarking CONV #100
# benchmarking CONV #99
# benchmarking CONV #98
# benchmarking CONV #97
# benchmarking CONV #96
# benchmarking CONV #95
# benchmarking CONV #94
# benchmarking CONV #93
# benchmarking CONV #92
# benchmarking CONV #91
# benchmarking CONV #90
# benchmarking CONV #89
# benchmarking CONV #88
# benchmarking CONV #87
# benchmarking CONV #86
# benchmarking CONV #85
# benchmarking CONV #84
# benchmarking CONV #83
# benchmarking CONV #82
# benchmarking CONV #81
# benchmarking CONV #80
# benchmarking CONV #79
# benchmarking CONV #78
# benchmarking CONV #77
# benchmarking CONV #76
# benchmarking CONV #75
# benchmarking CONV #74
# benchmarking CONV #73
# benchmarking CONV #72
# benchmarking CONV #71
# benchmarking CONV #70
# benchmarking CONV #69
# benchmarking CONV #68
# benchmarking CONV #67
# benchmarking CONV #66
# benchmarking CONV #65
# benchmarking CONV #64
# benchmarking CONV #63
# benchmarking CONV #62
# benchmarking CONV #61
# benchmarking CONV #60
# benchmarking CONV #59
# benchmarking CONV #58
# benchmarking CONV #57
# benchmarking CONV #56
# benchmarking CONV #55
# benchmarking CONV #54
# benchmarking CONV #53
# benchmarking CONV #52
# benchmarking CONV #51
# benchmarking CONV #50
# benchmarking CONV #49
# benchmarking CONV #48
# benchmarking CONV #47
# benchmarking CONV #46
# benchmarking CONV #45
# benchmarking CONV #44
# benchmarking CONV #43
# benchmarking CONV #42
# benchmarking CONV #41
# benchmarking CONV #40
# benchmarking CONV #39
# benchmarking CONV #38
# benchmarking CONV #37
# benchmarking CONV #36
# benchmarking CONV #35
# benchmarking CONV #34
# benchmarking CONV #33
# benchmarking CONV #32
# benchmarking CONV #31
# benchmarking CONV #30
# benchmarking CONV #29
# benchmarking CONV #28
# benchmarking CONV #27
# benchmarking CONV #26
# benchmarking CONV #25
# benchmarking CONV #24
# benchmarking CONV #23
# benchmarking CONV #22
# benchmarking CONV #21
# benchmarking CONV #20
# benchmarking CONV #19
# benchmarking CONV #18
# benchmarking CONV #17
# benchmarking CONV #16
# benchmarking CONV #15
# benchmarking CONV #14
# benchmarking CONV #13
# benchmarking CONV #12
# benchmarking CONV #11
# benchmarking CONV #10
# benchmarking CONV #9
# benchmarking CONV #8
# benchmarking CONV #7
# benchmarking CONV #6
# benchmarking CONV #5
# benchmarking CONV #4
# benchmarking CONV #3

# %%
mm_results = []
mm_throughput = []
bs_list = [32, 32, 32, 32, 32, 32, 32]
hi_list = [224, 56, 28, 14, 56, 28, 14]
ci_list = [3, 64, 128, 256, 128, 256, 512]
ho_list = [112, 56, 28, 14, 56, 28, 14]
co_list = [64, 128, 256, 512, 32, 64, 128]
k_list = [7, 1, 1, 1, 3, 3, 3]
dilation_list = [1, 1, 1, 1, 1, 1, 1]
pad_list = [3, 0, 0, 0, 1, 1, 1]
stride_list = [2, 1, 1, 1, 1, 1, 1]
for size in range(255, 2, -1):
    B = 32
    HI = size
    CI = 64
    HO = size
    CO = 128
    K = 1
    D = 1
    P = 0
    S = 1
    print("benchmarking CONV #{}".format(size))
    BENCH_CNT=33
    mm_src = f"""module BRKLEFT
      func.func @matmul(%arg0: tensor<{B}x{HI}x{HI}x{CI}xf32>, %arg1: tensor<{CO}x{K}x{K}x{CI}xf32>) -> tensor<{B}x{HO}x{HO}x{CO}xf32> BRKLEFT
        # %cst = arith.constant 0.000000e+00 : f32
        %0 = tensor.empty() : tensor<{CO}xf32>
        %1 = linalg.fill ins(%cst : f32) outs(%0 : tensor<{CO}xf32>) -> tensor<{CO}xf32>
        %2 = tosa.conv2d %arg0, %arg1, %1 BRKLEFTdilation = array<i64: {D}, {D}>, pad = array<i64: {P}, {P}, {P}, {P}>, stride = array<i64: {S}, {S}>BRKRIGHT : (tensor<{B}x{HI}x{HI}x{CI}xf32>, tensor<{CO}x{K}x{K}x{CI}xf32>, tensor<{CO}xf32>) -> tensor<{B}x{HO}x{HO}x{CO}xf32>
        return %2 : tensor<{B}x{HO}x{HO}x{CO}xf32>
      BRKRIGHT
    BRKRIGHT"""
    
    mm_src = mm_src.replace("BRKLEFT", "{")
    mm_src = mm_src.replace("BRKRIGHT", "}")
    
    mlir_file_name = "mm_src.mlir"
    with open(mlir_file_name, "w", encoding="utf-8") as mlir_file:
        mlir_file.write(mm_src)
    #"""
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb2 \
    --iree-hal-target-backends=cuda \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-hal-cuda-llvm-target-arch=sm_70
    """
    # !iree-compile {mlir_file_name} \
    -o {mlir_file_name}.vmfb \
    --iree-hal-target-backends=llvm-cpu \
    --iree-llvmcpu-fail-on-out-of-bounds-stack-allocation=0 \
    --iree-opt-const-eval=1 \
    --iree-opt-const-expr-hoisting=1 \
    --iree-opt-numeric-precision-reduction=1 \
    --iree-llvmcpu-target-cpu-features=host \
    --iree-llvmcpu-enable-ukernels=all \
    --iree-llvmcpu-slp-vectorization=1 \
    --iree-hal-benchmark-dispatch-repeat-count={BENCH_CNT} \
    --iree-llvmcpu-target-triple=x86_64-pc-linux-elf
    """
    #print(tf_bench)
    
    
    ragdoll_bench = ragdoll_op_benchmark(
        mlir_file_name + ".vmfb2",
        [(B, HI, HI, CI), (CO, K, K, CI)],
        device='gpu',
        warmups=3,
        repetitions=BENCH_CNT, 
        measure_count=1)
    #print(np.mean(ragdoll_bench))
    mm_results.append(np.mean(ragdoll_bench))
    GFLOPS = 2*B*CO*CI*HO*HO*K*K*1000000000
    mm_throughput.append(GFLOPS/np.mean(ragdoll_bench))
mm_data = pd.DataFrame([list(range(16, 1000, 16)), mm_results])
mm_data.to_csv('op_spec_named_gpu.csv')
# Out:
# benchmarking CONV #255
# benchmarking CONV #254
# benchmarking CONV #253
# benchmarking CONV #252
# benchmarking CONV #251
# benchmarking CONV #250
# benchmarking CONV #249
# benchmarking CONV #248
# benchmarking CONV #247
# benchmarking CONV #246
# benchmarking CONV #245
# benchmarking CONV #244
# benchmarking CONV #243
# benchmarking CONV #242
# benchmarking CONV #241
# benchmarking CONV #240
# benchmarking CONV #239
# benchmarking CONV #238
# benchmarking CONV #237
# benchmarking CONV #236
# benchmarking CONV #235
# benchmarking CONV #234
# benchmarking CONV #233
# benchmarking CONV #232
# benchmarking CONV #231
# benchmarking CONV #230
# benchmarking CONV #229
# benchmarking CONV #228
# benchmarking CONV #227
# benchmarking CONV #226
# benchmarking CONV #225
# benchmarking CONV #224
# benchmarking CONV #223
# benchmarking CONV #222
# benchmarking CONV #221
# benchmarking CONV #220
# benchmarking CONV #219
# benchmarking CONV #218
# benchmarking CONV #217
# benchmarking CONV #216
# benchmarking CONV #215
# benchmarking CONV #214
# benchmarking CONV #213
# benchmarking CONV #212
# benchmarking CONV #211
# benchmarking CONV #210
# benchmarking CONV #209
# benchmarking CONV #208
# benchmarking CONV #207
# benchmarking CONV #206
# benchmarking CONV #205
# benchmarking CONV #204
# benchmarking CONV #203
# benchmarking CONV #202
# benchmarking CONV #201
# benchmarking CONV #200
# benchmarking CONV #199
# benchmarking CONV #198
# benchmarking CONV #197
# benchmarking CONV #196
# benchmarking CONV #195
# benchmarking CONV #194
# benchmarking CONV #193
# benchmarking CONV #192
# benchmarking CONV #191
# benchmarking CONV #190
# benchmarking CONV #189
# benchmarking CONV #188
# benchmarking CONV #187
# benchmarking CONV #186
# benchmarking CONV #185
# benchmarking CONV #184
# benchmarking CONV #183
# benchmarking CONV #182
# benchmarking CONV #181
# benchmarking CONV #180
# benchmarking CONV #179
# benchmarking CONV #178
# benchmarking CONV #177
# benchmarking CONV #176
# benchmarking CONV #175
# benchmarking CONV #174
# benchmarking CONV #173
# benchmarking CONV #172
# benchmarking CONV #171
# benchmarking CONV #170
# benchmarking CONV #169
# benchmarking CONV #168
# benchmarking CONV #167
# benchmarking CONV #166
# benchmarking CONV #165
# benchmarking CONV #164
# benchmarking CONV #163
# benchmarking CONV #162
# benchmarking CONV #161
# benchmarking CONV #160
# benchmarking CONV #159
# benchmarking CONV #158
# benchmarking CONV #157
# benchmarking CONV #156
# benchmarking CONV #155
# benchmarking CONV #154
# benchmarking CONV #153
# benchmarking CONV #152
# benchmarking CONV #151
# benchmarking CONV #150
# benchmarking CONV #149
# benchmarking CONV #148
# benchmarking CONV #147
# benchmarking CONV #146
# benchmarking CONV #145
# benchmarking CONV #144
# benchmarking CONV #143
# benchmarking CONV #142
# benchmarking CONV #141
# benchmarking CONV #140
# benchmarking CONV #139
# benchmarking CONV #138
# benchmarking CONV #137
# benchmarking CONV #136
# benchmarking CONV #135
# benchmarking CONV #134
# benchmarking CONV #133
# benchmarking CONV #132
# benchmarking CONV #131
# benchmarking CONV #130
# benchmarking CONV #129
# benchmarking CONV #128
# benchmarking CONV #127
# benchmarking CONV #126
# benchmarking CONV #125
# benchmarking CONV #124
# benchmarking CONV #123
# benchmarking CONV #122
# benchmarking CONV #121
# benchmarking CONV #120
# benchmarking CONV #119
# benchmarking CONV #118
# benchmarking CONV #117
# benchmarking CONV #116
# benchmarking CONV #115
# benchmarking CONV #114
# benchmarking CONV #113
# benchmarking CONV #112
# benchmarking CONV #111
# benchmarking CONV #110
# benchmarking CONV #109
# benchmarking CONV #108
# benchmarking CONV #107
# benchmarking CONV #106
# benchmarking CONV #105
# benchmarking CONV #104
# benchmarking CONV #103
# benchmarking CONV #102
# benchmarking CONV #101
# benchmarking CONV #100
# benchmarking CONV #99
# benchmarking CONV #98
# benchmarking CONV #97
# benchmarking CONV #96
# benchmarking CONV #95
# benchmarking CONV #94
# benchmarking CONV #93
# benchmarking CONV #92
# benchmarking CONV #91
# benchmarking CONV #90
# benchmarking CONV #89
# benchmarking CONV #88
# benchmarking CONV #87
# benchmarking CONV #86
# benchmarking CONV #85
# benchmarking CONV #84
# benchmarking CONV #83
# benchmarking CONV #82
# benchmarking CONV #81
# benchmarking CONV #80
# benchmarking CONV #79
# benchmarking CONV #78
# benchmarking CONV #77
# benchmarking CONV #76
# benchmarking CONV #75
# benchmarking CONV #74
# benchmarking CONV #73
# benchmarking CONV #72
# benchmarking CONV #71
# benchmarking CONV #70
# benchmarking CONV #69
# benchmarking CONV #68
# benchmarking CONV #67
# benchmarking CONV #66
# benchmarking CONV #65
# benchmarking CONV #64
# benchmarking CONV #63
# benchmarking CONV #62
# benchmarking CONV #61
# benchmarking CONV #60
# benchmarking CONV #59
# benchmarking CONV #58
# benchmarking CONV #57
# benchmarking CONV #56
# benchmarking CONV #55
# benchmarking CONV #54
# benchmarking CONV #53
# benchmarking CONV #52
# benchmarking CONV #51
# benchmarking CONV #50
# benchmarking CONV #49
# benchmarking CONV #48
# benchmarking CONV #47
# benchmarking CONV #46
# benchmarking CONV #45
# benchmarking CONV #44
# benchmarking CONV #43
# benchmarking CONV #42
# benchmarking CONV #41
# benchmarking CONV #40
# benchmarking CONV #39
# benchmarking CONV #38
# benchmarking CONV #37
# benchmarking CONV #36
# benchmarking CONV #35
# benchmarking CONV #34
# benchmarking CONV #33
# benchmarking CONV #32
# benchmarking CONV #31
# benchmarking CONV #30
# benchmarking CONV #29
# benchmarking CONV #28
# benchmarking CONV #27
# benchmarking CONV #26
# benchmarking CONV #25
# benchmarking CONV #24
# benchmarking CONV #23
# benchmarking CONV #22
# benchmarking CONV #21
# benchmarking CONV #20
# benchmarking CONV #19
# benchmarking CONV #18
# benchmarking CONV #17
# benchmarking CONV #16
# benchmarking CONV #15
# benchmarking CONV #14
# benchmarking CONV #13
# benchmarking CONV #12
# benchmarking CONV #11
# benchmarking CONV #10
# benchmarking CONV #9
# benchmarking CONV #8
# benchmarking CONV #7
# benchmarking CONV #6
# benchmarking CONV #5
# benchmarking CONV #4
# benchmarking CONV #3

# %%
scaled_mm = [val * 2 for val in mm_results]

# %%
# do throughput
names = ['TOSA', 'LinAlg Named', 'LinAlg Generic']
results = [scaled_mm, scaled_mm, scaled_mm]
throughputs = [mm_throughput, gen_throughput, gen_results]

from matplotlib.ticker import FuncFormatter
line_data = pd.DataFrame(dict(zip(names, [res for res in throughputs])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in throughputs])))

plt.rcParams["figure.dpi"] = 300
plt.rcParams["figure.figsize"] = (3, 3)

fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Throughput (TFLOPS)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1e18)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()

line_data = pd.DataFrame(dict(zip(names, [res for res in results])))
bar_data = pd.DataFrame(dict(zip(names, [[np.mean(res)] for res in results])))
fig, (left, right) = plt.subplots(ncols=2, figsize=(9, 3))
left.set_ylabel('Time Cost (ms)')
left.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
#right.set_ylabel('Throughput (TFLOPS)')
right.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:,.02f}'.format(y / 1)))
sns.lineplot(line_data, ax=left)
sns.barplot(bar_data, ax=right)
left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0) 
left.set_xlabel('Size')
right.set_xticklabels(right.get_xticklabels(), rotation=30) 
#plt.suptitle("Time Cost (ms)")
#plt.tight_layout(rect=[0, 0, 1, 1.2])
plt.show()
# Out:
# /tmp/ipykernel_1297970/3721296108.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)
# /tmp/ipykernel_1297970/3721296108.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   right.set_xticklabels(right.get_xticklabels(), rotation=30)
# /tmp/ipykernel_1297970/3721296108.py:36: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   left.set_xticklabels([f'{16 + (x-2)*320}' for x in range(1, len(line_data)+1)], rotation=0)
# /tmp/ipykernel_1297970/3721296108.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   right.set_xticklabels(right.get_xticklabels(), rotation=30)
