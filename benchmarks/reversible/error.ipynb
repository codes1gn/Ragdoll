rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.dpi"] = 300

colors = ["#60D3FF"]
sns.set_palette(colors)

# %%
plt.rcParams["figure.figsize"] = (6, 6)

sns.scatterplot(data, x="pred", y="real", alpha=0.2, s=50)
sns.lineplot(data, x="pred", y="real", color="black", linestyle="--")

plt.xlabel("ReverSyn")
plt.ylabel("Original")
# Out:
# Text(0, 0.5, 'Original')

# %%
base = np.load("base.npy").flatten()
rev = np.load("rev.npy").flatten()

data = pd.DataFrame(dict(pred=rev, real=base))

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

plt.rcParams["figure.figsize"] = (5, 5)

fig, ax = plt.subplots()

sns.regplot(data, x="pred", y="real", ax=ax, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 1})
plt.xlabel("ReverSyn")
plt.ylabel("Original")

zoom = plt.axes([.2, .6, .2, .2])
zoom.set_xlim(-0.2, 0.2)
zoom.set_ylim(-0.2, 0.2)

sns.regplot(data, x="pred", y="real", ax=zoom, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 1})
zoom.set_xlabel(None)
zoom.set_ylabel(None)
zoom.set_yticklabels([])

plt.savefig("error.pdf", format="pdf", bbox_inches="tight", dpi=300, pad_inches=0.1)

# %%
indices = np.arange(5000)
np.random.shuffle(indices)
indices = indices[:1000]

r_real = np.load("base.npy").flatten()[indices]
r_pred = np.load("rev.npy").flatten()[indices]
r_data = pd.DataFrame(dict(pred=r_pred, real=r_real))

d_real = np.load("base_resnet.npy").flatten()[indices]
d_pred = np.load("rev_resnet.npy").flatten()[indices]
d_data = pd.DataFrame(dict(pred=d_pred, real=d_real))

# %%
fig, (left, right) = plt.subplots(1, 2, figsize=(11, 5))

fontsize = 15

left.set_title("ResNet32", fontsize=fontsize)
right.set_title("ResNet101-1k", fontsize=fontsize)

sns.regplot(r_data, x="pred", y="real", ax=left, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 10})
sns.regplot(d_data, x="pred", y="real", ax=right, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 10})

zoom_left = plt.axes([.16, .65, .1, .2])
zoom_right = plt.axes([.58, .65, .1, .2])

sns.regplot(r_data, x="pred", y="real", ax=zoom_left, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 10})
zoom_left.set_xlim(-0.2, 0.2)
zoom_left.set_ylim(-0.2, 0.2)
zoom_left.set_xlabel(None)
zoom_left.set_ylabel(None)

sns.regplot(d_data, x="pred", y="real", ax=zoom_right, line_kws={"color": "black", "linestyle": "--"}, scatter_kws={"alpha": 0.2, "s": 10})
zoom_left.set_xlim(-0.25, 0.25)
zoom_left.set_ylim(-0.25, 0.25)
zoom_right.set_xlabel(None)
zoom_right.set_ylabel(None)

left.set_ylabel("Original", fontsize=fontsize)
left.set_xlabel("ReverSyn", fontsize=fontsize)
right.set_ylabel(None)
right.set_xlabel(None)

plt.savefig("error.pdf", format="pdf", bbox_inches="tight", dpi=300, pad_inches=0.1)

# %% [markdown]
# ######
