# %%
model_file = "vgg11.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
target_file = model_file + ".heuristic"
# !./convert_v0_to_v1.sh {model_file}
# !ragdoll-opt {model_file} --ragdoll-identical-transpose-removal > {model_file}.tmp
#!cat {model_file}.tmp

# !mv {model_file}.tmp {model_file}
# Out:
# /bin/bash: line 1: ./convert_v0_to_v1.sh: No such file or directory

# %%
model_file = "vgg11.mlir.v0"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"
target_file = model_file + ".heuristic"
# !ragdoll-opt {model_file}  \
--canonicalize \
--enable-cse-in-legalizer \
--symbol-dce \
--ragdoll-autodiff-vjp-public-functions='strategy=heuristic' \
--ragdoll-autodiff-vjp \
--inline \
--ragdoll-autodiff-inline-function-call \
--ragdoll-initialisation \
--eliminate-empty-tensors \
--ragdoll-legalise-to-iree-compatibility \
--ragdoll-raise-linalg-to-tosa \
--canonicalize \
--cse > {target_file}

# %%
# !cat {target_file}
# Out:
# #map = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 + d4, d2 + d5, d3)>
# #map1 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d4, d5)>
# #map2 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1, d2, d3)>
# #map3 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 * 2 + d4, d2 * 2 + d5, d3)>
# module attributes {torch.debug_module_name = "ResNet"} {
#   ml_program.global private mutable @global983(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global982(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global976(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global975(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global970(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global969(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global964(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global963(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global957(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global956(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global951(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global950(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global945(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global944(dense<1.000000e+00> : tensor<1x2048x7x7xf32>) : tensor<1x2048x7x7xf32>
#   ml_program.global private mutable @global935(dense<1.000000e+00> : tensor<2048x1x1xf32>) : tensor<2048x1x1xf32>
#   ml_program.global private mutable @global932(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global931(dense<1.000000e+00> : tensor<1x512x7x7xf32>) : tensor<1x512x7x7xf32>
#   ml_program.global private mutable @global926(dense<1.000000e+00> : tensor<1x512x14x14xf32>) : tensor<1x512x14x14xf32>
#   ml_program.global private mutable @global925(dense<1.000000e+00> : tensor<1x512x14x14xf32>) : tensor<1x512x14x14xf32>
#   ml_program.global private mutable @global920(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global919(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global913(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global912(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global907(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global906(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global901(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global900(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global894(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global893(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global888(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global887(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global882(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global881(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global875(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global874(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global869(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global868(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global863(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global862(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global856(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global855(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global850(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global849(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global844(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global843(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global837(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global836(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global831(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global830(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global825(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global824(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global818(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global817(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global812(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global811(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global806(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global805(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global799(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global798(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global793(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global792(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global787(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global786(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global780(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global779(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global774(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global773(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global768(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global767(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global761(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global760(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global755(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global754(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global749(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global748(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global742(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global741(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global736(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global735(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global730(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global729(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global723(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global722(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global717(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global716(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global711(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global710(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global704(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global703(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global698(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global697(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global692(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global691(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global685(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global684(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global679(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global678(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global673(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global672(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global666(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global665(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global660(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global659(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global654(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global653(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global647(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global646(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global641(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global640(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global635(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global634(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global628(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global627(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global622(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global621(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global616(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global615(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global609(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global608(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global603(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global602(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global597(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global596(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global590(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global589(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global584(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global583(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global578(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global577(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global571(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global570(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global565(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global564(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global559(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global558(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global552(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global551(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global546(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global545(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global540(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global539(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global533(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global532(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global527(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global526(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global521(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global520(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global514(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global513(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global508(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global507(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global502(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global501(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global495(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global494(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global489(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global488(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global483(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global482(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global476(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global475(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global470(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global469(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global464(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global463(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global457(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global456(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global451(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global450(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global445(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global444(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global438(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global437(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global432(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global431(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global426(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global425(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global419(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global418(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global413(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global412(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global407(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global406(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global400(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global399(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global394(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global393(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global388(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global387(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global381(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global380(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global375(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global374(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global369(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global368(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global362(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global361(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global356(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global355(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global350(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global349(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global343(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global342(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global337(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global336(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global331(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global330(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global324(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global323(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global318(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global317(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global312(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global311(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global305(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global304(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global299(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global298(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global293(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global292(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global286(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global285(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global280(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global279(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global274(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global273(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global267(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global266(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global261(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global260(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global255(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global254(dense<1.000000e+00> : tensor<1x1024x14x14xf32>) : tensor<1x1024x14x14xf32>
#   ml_program.global private mutable @global245(dense<1.000000e+00> : tensor<1024x1x1xf32>) : tensor<1024x1x1xf32>
#   ml_program.global private mutable @global242(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global241(dense<1.000000e+00> : tensor<1x256x14x14xf32>) : tensor<1x256x14x14xf32>
#   ml_program.global private mutable @global236(dense<1.000000e+00> : tensor<1x256x28x28xf32>) : tensor<1x256x28x28xf32>
#   ml_program.global private mutable @global235(dense<1.000000e+00> : tensor<1x256x28x28xf32>) : tensor<1x256x28x28xf32>
#   ml_program.global private mutable @global230(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global229(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global223(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global222(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global217(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global216(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global211(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global210(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global204(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global203(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global198(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global197(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global192(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global191(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global185(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global184(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global179(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global178(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global173(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global172(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global166(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global165(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global160(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global159(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global154(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global153(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global147(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global146(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global141(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global140(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global135(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global134(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global128(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global127(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global122(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global121(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global116(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global115(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global109(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global108(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global103(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global102(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global97(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global96(dense<1.000000e+00> : tensor<1x512x28x28xf32>) : tensor<1x512x28x28xf32>
#   ml_program.global private mutable @global87(dense<1.000000e+00> : tensor<512x1x1xf32>) : tensor<512x1x1xf32>
#   ml_program.global private mutable @global84(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global83(dense<1.000000e+00> : tensor<1x128x28x28xf32>) : tensor<1x128x28x28xf32>
#   ml_program.global private mutable @global78(dense<1.000000e+00> : tensor<1x128x56x56xf32>) : tensor<1x128x56x56xf32>
#   ml_program.global private mutable @global77(dense<1.000000e+00> : tensor<1x128x56x56xf32>) : tensor<1x128x56x56xf32>
#   ml_program.global private mutable @global74(dense<1.000000e+00> : tensor<128x1x1xf32>) : tensor<128x1x1xf32>
#   ml_program.global private mutable @global71(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global70(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global64(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global63(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global58(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global57(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global52(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global51(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global45(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global44(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global39(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global38(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global33(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global32(dense<1.000000e+00> : tensor<1x256x56x56xf32>) : tensor<1x256x56x56xf32>
#   ml_program.global private mutable @global23(dense<1.000000e+00> : tensor<256x1x1xf32>) : tensor<256x1x1xf32>
#   ml_program.global private mutable @global20(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global19(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global14(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global13(dense<1.000000e+00> : tensor<1x64x56x56xf32>) : tensor<1x64x56x56xf32>
#   ml_program.global private mutable @global8(dense<1.000000e+00> : tensor<1x56x56x64xf32>) : tensor<1x56x56x64xf32>
#   ml_program.global private mutable @global7(dense<1.000000e+00> : tensor<1x64x112x112xf32>) : tensor<1x64x112x112xf32>
#   ml_program.global private mutable @global6(dense<1.000000e+00> : tensor<1x64x112x112xf32>) : tensor<1x64x112x112xf32>
#   ml_program.global private mutable @global3(dense<1.000000e+00> : tensor<64x1x1xf32>) : tensor<64x1x1xf32>
#   func.func @forward(%arg0: tensor<1x3x224x224xf32>) -> tensor<1x1000xf32> {
#     %0 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x7x7x3xf32>}> : () -> tensor<64x7x7x3xf32>
#     %1 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x64x1x1xf32>}> : () -> tensor<1x64x1x1xf32>
#     %2 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<64x1x1xf32>}> : () -> tensor<64x1x1xf32>
#     %3 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x1x1x64xf32>}> : () -> tensor<64x1x1x64xf32>
#     %4 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x3x3x64xf32>}> : () -> tensor<64x3x3x64xf32>
#     %5 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x64xf32>}> : () -> tensor<256x1x1x64xf32>
#     %6 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x256x1x1xf32>}> : () -> tensor<1x256x1x1xf32>
#     %7 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<256x1x1xf32>}> : () -> tensor<256x1x1xf32>
#     %8 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x1x1x256xf32>}> : () -> tensor<64x1x1x256xf32>
#     %9 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x256xf32>}> : () -> tensor<128x1x1x256xf32>
#     %10 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x128x1x1xf32>}> : () -> tensor<1x128x1x1xf32>
#     %11 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<128x1x1xf32>}> : () -> tensor<128x1x1xf32>
#     %12 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x3x3x128xf32>}> : () -> tensor<128x3x3x128xf32>
#     %13 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x128xf32>}> : () -> tensor<512x1x1x128xf32>
#     %14 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x512x1x1xf32>}> : () -> tensor<1x512x1x1xf32>
#     %15 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<512x1x1xf32>}> : () -> tensor<512x1x1xf32>
#     %16 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x256xf32>}> : () -> tensor<512x1x1x256xf32>
#     %17 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x512xf32>}> : () -> tensor<128x1x1x512xf32>
#     %18 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x512xf32>}> : () -> tensor<256x1x1x512xf32>
#     %19 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x3x3x256xf32>}> : () -> tensor<256x3x3x256xf32>
#     %20 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x1x1x256xf32>}> : () -> tensor<1024x1x1x256xf32>
#     %21 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1024x1x1xf32>}> : () -> tensor<1x1024x1x1xf32>
#     %22 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1024x1x1xf32>}> : () -> tensor<1024x1x1xf32>
#     %23 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x1x1x512xf32>}> : () -> tensor<1024x1x1x512xf32>
#     %24 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x1024xf32>}> : () -> tensor<256x1x1x1024xf32>
#     %25 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x1024xf32>}> : () -> tensor<512x1x1x1024xf32>
#     %26 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x3x3x512xf32>}> : () -> tensor<512x3x3x512xf32>
#     %27 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<2048x1x1x512xf32>}> : () -> tensor<2048x1x1x512xf32>
#     %28 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x2048x1x1xf32>}> : () -> tensor<1x2048x1x1xf32>
#     %29 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<2048x1x1xf32>}> : () -> tensor<2048x1x1xf32>
#     %30 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<2048x1x1x1024xf32>}> : () -> tensor<2048x1x1x1024xf32>
#     %31 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x2048xf32>}> : () -> tensor<512x1x1x2048xf32>
#     %32 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x2048x1000xf32>}> : () -> tensor<1x2048x1000xf32>
#     %33 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1000xf32>}> : () -> tensor<1x1000xf32>
#     %34 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<2048xf32>}> : () -> tensor<2048xf32>
#     %35 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<1024xf32>}> : () -> tensor<1024xf32>
#     %36 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<512xf32>}> : () -> tensor<512xf32>
#     %37 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<128xf32>}> : () -> tensor<128xf32>
#     %38 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<256xf32>}> : () -> tensor<256xf32>
#     %39 = "tosa.const"() <{value = dense<[0, 3, 1, 2]> : tensor<4xi32>}> : () -> tensor<4xi32>
#     %40 = "tosa.const"() <{value = dense<[0, 2, 3, 1]> : tensor<4xi32>}> : () -> tensor<4xi32>
#     %41 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<64xf32>}> : () -> tensor<64xf32>
#     %42 = tosa.transpose %arg0, %40 : (tensor<1x3x224x224xf32>, tensor<4xi32>) -> tensor<1x224x224x3xf32>
#     %43 = tosa.conv2d %42, %0, %41 {dilation = array<i64: 1, 1>, pad = array<i64: 3, 3, 3, 3>, stride = array<i64: 2, 2>} : (tensor<1x224x224x3xf32>, tensor<64x7x7x3xf32>, tensor<64xf32>) -> tensor<1x112x112x64xf32>
#     %44 = tosa.transpose %43, %39 : (tensor<1x112x112x64xf32>, tensor<4xi32>) -> tensor<1x64x112x112xf32>
#     %45 = tosa.sub %44, %1 : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %46 = tosa.rsqrt %2 : (tensor<64x1x1xf32>) -> tensor<64x1x1xf32>
#     ml_program.global_store @global3 = %46 : tensor<64x1x1xf32>
#     %47 = tosa.reshape %46 {new_shape = array<i64: 1, 64, 1, 1>} : (tensor<64x1x1xf32>) -> tensor<1x64x1x1xf32>
#     %48 = tosa.mul %45, %47 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %49 = tosa.mul %48, %1 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %50 = tosa.add %49, %1 : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     ml_program.global_store @global6 = %50 : tensor<1x64x112x112xf32>
#     %51 = tosa.clamp %50 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xf32>
#     ml_program.global_store @global7 = %51 : tensor<1x64x112x112xf32>
#     %52 = tosa.transpose %51, %40 : (tensor<1x64x112x112xf32>, tensor<4xi32>) -> tensor<1x112x112x64xf32>
#     %53 = tosa.max_pool2d %52 {kernel = array<i64: 3, 3>, pad = array<i64: 1, 0, 1, 0>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>) -> tensor<1x56x56x64xf32>
#     ml_program.global_store @global8 = %53 : tensor<1x56x56x64xf32>
#     %54 = tosa.conv2d %53, %3, %41 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x1x1x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %55 = tosa.transpose %54, %39 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %56 = tosa.sub %55, %1 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %57 = tosa.mul %56, %47 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %58 = tosa.mul %57, %1 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %59 = tosa.add %58, %1 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     ml_program.global_store @global13 = %59 : tensor<1x64x56x56xf32>
#     %60 = tosa.clamp %59 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     ml_program.global_store @global14 = %60 : tensor<1x64x56x56xf32>
#     %61 = tosa.transpose %60, %40 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %62 = tosa.conv2d %61, %4, %41 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x3x3x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %63 = tosa.transpose %62, %39 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %64 = tosa.sub %63, %1 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %65 = tosa.mul %64, %47 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %66 = tosa.mul %65, %1 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %67 = tosa.add %66, %1 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     ml_program.global_store @global19 = %67 : tensor<1x64x56x56xf32>
#     %68 = tosa.clamp %67 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     ml_program.global_store @global20 = %68 : tensor<1x64x56x56xf32>
#     %69 = tosa.transpose %68, %40 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %70 = tosa.conv2d %69, %5, %38 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %71 = tosa.transpose %70, %39 : (tensor<1x56x56x256xf32>, tensor<4xi32>) -> tensor<1x256x56x56xf32>
#     %72 = tosa.sub %71, %6 : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %73 = tosa.rsqrt %7 : (tensor<256x1x1xf32>) -> tensor<256x1x1xf32>
#     ml_program.global_store @global23 = %73 : tensor<256x1x1xf32>
#     %74 = tosa.reshape %73 {new_shape = array<i64: 1, 256, 1, 1>} : (tensor<256x1x1xf32>) -> tensor<1x256x1x1xf32>
#     %75 = tosa.mul %72, %74 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %76 = tosa.mul %75, %6 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %77 = tosa.add %76, %6 : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %78 = tosa.conv2d %53, %5, %38 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %79 = tosa.transpose %78, %39 : (tensor<1x56x56x256xf32>, tensor<4xi32>) -> tensor<1x256x56x56xf32>
#     %80 = tosa.sub %79, %6 : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %81 = tosa.mul %80, %74 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %82 = tosa.mul %81, %6 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
# ...
#     %1046 = tosa.transpose %1045, %23 : (tensor<1x128x28x28xf32>, tensor<4xi32>) -> tensor<1x28x28x128xf32>
#     %1047 = tosa.transpose_conv2d %1046, %8, %cst_3 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 28, 28, 128>, stride = array<i64: 1, 1>} : (tensor<1x28x28x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x28x28x128xf32>
#     %1048 = tosa.transpose %1047, %21 : (tensor<1x28x28x128xf32>, tensor<4xi32>) -> tensor<1x128x28x28xf32>
#     %1049 = tosa.equal %global102, %global103 : (tensor<1x128x28x28xf32>, tensor<1x128x28x28xf32>) -> tensor<1x128x28x28xi1>
#     %1050 = tosa.select %1049, %1048, %20 : (tensor<1x128x28x28xi1>, tensor<1x128x28x28xf32>, tensor<f32>) -> tensor<1x128x28x28xf32>
#     %1051 = tosa.mul %1050, %27 {shift = 0 : i8} : (tensor<1x128x28x28xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x28x28xf32>
#     %1052 = tosa.mul %33, %1051 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x28x28xf32>) -> tensor<1x128x28x28xf32>
#     %1053 = tosa.transpose %1052, %23 : (tensor<1x128x28x28xf32>, tensor<4xi32>) -> tensor<1x28x28x128xf32>
#     %1054 = tosa.transpose_conv2d %1053, %7, %cst_7 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 512>, stride = array<i64: 1, 1>} : (tensor<1x28x28x128xf32>, tensor<512x1x1x128xf32>, tensor<512xf32>) -> tensor<1x28x28x512xf32>
#     %1055 = tosa.transpose %1054, %21 : (tensor<1x28x28x512xf32>, tensor<4xi32>) -> tensor<1x512x28x28xf32>
#     %1056 = tosa.add %1036, %1055 : (tensor<1x512x28x28xf32>, tensor<1x512x28x28xf32>) -> tensor<1x512x28x28xf32>
#     %1057 = tosa.equal %global96, %global97 : (tensor<1x512x28x28xf32>, tensor<1x512x28x28xf32>) -> tensor<1x512x28x28xi1>
#     %1058 = tosa.select %1057, %1056, %20 : (tensor<1x512x28x28xi1>, tensor<1x512x28x28xf32>, tensor<f32>) -> tensor<1x512x28x28xf32>
#     %1059 = tosa.mul %1058, %26 {shift = 0 : i8} : (tensor<1x512x28x28xf32>, tensor<1x512x1x1xf32>) -> tensor<1x512x28x28xf32>
#     %1060 = tosa.mul %34, %1059 {shift = 0 : i8} : (tensor<1x512x1x1xf32>, tensor<1x512x28x28xf32>) -> tensor<1x512x28x28xf32>
#     %1061 = tosa.transpose %1060, %23 : (tensor<1x512x28x28xf32>, tensor<4xi32>) -> tensor<1x28x28x512xf32>
#     %1062 = tosa.transpose_conv2d %1061, %6, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 2, 2>} : (tensor<1x28x28x512xf32>, tensor<256x1x1x512xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %1063 = tosa.transpose_conv2d %1061, %9, %cst_3 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 128>, stride = array<i64: 1, 1>} : (tensor<1x28x28x512xf32>, tensor<128x1x1x512xf32>, tensor<128xf32>) -> tensor<1x28x28x128xf32>
#     %1064 = tosa.transpose %1063, %21 : (tensor<1x28x28x128xf32>, tensor<4xi32>) -> tensor<1x128x28x28xf32>
#     %1065 = tosa.equal %global83, %global84 : (tensor<1x128x28x28xf32>, tensor<1x128x28x28xf32>) -> tensor<1x128x28x28xi1>
#     %1066 = tosa.select %1065, %1064, %20 : (tensor<1x128x28x28xi1>, tensor<1x128x28x28xf32>, tensor<f32>) -> tensor<1x128x28x28xf32>
#     %1067 = tosa.mul %1066, %27 {shift = 0 : i8} : (tensor<1x128x28x28xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x28x28xf32>
#     %1068 = tosa.mul %33, %1067 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x28x28xf32>) -> tensor<1x128x28x28xf32>
#     %1069 = tosa.transpose %1068, %23 : (tensor<1x128x28x28xf32>, tensor<4xi32>) -> tensor<1x28x28x128xf32>
#     %1070 = tosa.transpose_conv2d %1069, %8, %cst_3 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 2, 2>} : (tensor<1x28x28x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %1071 = tosa.transpose %1070, %21 : (tensor<1x56x56x128xf32>, tensor<4xi32>) -> tensor<1x128x56x56xf32>
#     %1072 = tosa.equal %global77, %global78 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %1073 = tosa.select %1072, %1071, %20 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %1074 = tosa.mul %1073, %27 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %1075 = tosa.mul %33, %1074 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %1076 = tosa.transpose %1075, %23 : (tensor<1x128x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x128xf32>
#     %1077 = tosa.transpose_conv2d %1076, %5, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %1078 = tosa.add %1062, %1077 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %1079 = tosa.transpose %1078, %21 : (tensor<1x56x56x256xf32>, tensor<4xi32>) -> tensor<1x256x56x56xf32>
#     %1080 = tosa.equal %global70, %global71 : (tensor<1x256x56x56xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xi1>
#     %1081 = tosa.select %1080, %1079, %20 : (tensor<1x256x56x56xi1>, tensor<1x256x56x56xf32>, tensor<f32>) -> tensor<1x256x56x56xf32>
#     %1082 = tosa.mul %1081, %28 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %1083 = tosa.mul %32, %1082 {shift = 0 : i8} : (tensor<1x256x1x1xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xf32>
#     %1084 = tosa.transpose %1083, %23 : (tensor<1x256x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x256xf32>
#     %1085 = tosa.transpose_conv2d %1084, %4, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1086 = tosa.transpose %1085, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1087 = tosa.equal %global63, %global64 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1088 = tosa.select %1087, %1086, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1089 = tosa.mul %1088, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1090 = tosa.mul %30, %1089 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1091 = tosa.transpose %1090, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1092 = tosa.transpose_conv2d %1091, %3, %cst_2 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x3x3x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1093 = tosa.transpose %1092, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1094 = tosa.equal %global57, %global58 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1095 = tosa.select %1094, %1093, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1096 = tosa.mul %1095, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1097 = tosa.mul %30, %1096 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1098 = tosa.transpose %1097, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1099 = tosa.transpose_conv2d %1098, %2, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %1100 = tosa.transpose %1099, %21 : (tensor<1x56x56x256xf32>, tensor<4xi32>) -> tensor<1x256x56x56xf32>
#     %1101 = tosa.add %1081, %1100 : (tensor<1x256x56x56xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xf32>
#     %1102 = tosa.equal %global51, %global52 : (tensor<1x256x56x56xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xi1>
#     %1103 = tosa.select %1102, %1101, %20 : (tensor<1x256x56x56xi1>, tensor<1x256x56x56xf32>, tensor<f32>) -> tensor<1x256x56x56xf32>
#     %1104 = tosa.mul %1103, %28 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %1105 = tosa.mul %32, %1104 {shift = 0 : i8} : (tensor<1x256x1x1xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xf32>
#     %1106 = tosa.transpose %1105, %23 : (tensor<1x256x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x256xf32>
#     %1107 = tosa.transpose_conv2d %1106, %4, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1108 = tosa.transpose %1107, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1109 = tosa.equal %global44, %global45 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1110 = tosa.select %1109, %1108, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1111 = tosa.mul %1110, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1112 = tosa.mul %30, %1111 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1113 = tosa.transpose %1112, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1114 = tosa.transpose_conv2d %1113, %3, %cst_2 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x3x3x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1115 = tosa.transpose %1114, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1116 = tosa.equal %global38, %global39 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1117 = tosa.select %1116, %1115, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1118 = tosa.mul %1117, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1119 = tosa.mul %30, %1118 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1120 = tosa.transpose %1119, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1121 = tosa.transpose_conv2d %1120, %2, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %1122 = tosa.transpose %1121, %21 : (tensor<1x56x56x256xf32>, tensor<4xi32>) -> tensor<1x256x56x56xf32>
#     %1123 = tosa.add %1103, %1122 : (tensor<1x256x56x56xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xf32>
#     %1124 = tosa.equal %global32, %global33 : (tensor<1x256x56x56xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xi1>
#     %1125 = tosa.select %1124, %1123, %20 : (tensor<1x256x56x56xi1>, tensor<1x256x56x56xf32>, tensor<f32>) -> tensor<1x256x56x56xf32>
#     %1126 = tosa.mul %1125, %28 {shift = 0 : i8} : (tensor<1x256x56x56xf32>, tensor<1x256x1x1xf32>) -> tensor<1x256x56x56xf32>
#     %1127 = tosa.mul %32, %1126 {shift = 0 : i8} : (tensor<1x256x1x1xf32>, tensor<1x256x56x56xf32>) -> tensor<1x256x56x56xf32>
#     %1128 = tosa.transpose %1127, %23 : (tensor<1x256x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x256xf32>
#     %1129 = tosa.transpose_conv2d %1128, %4, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1130 = tosa.transpose %1129, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1131 = tosa.equal %global19, %global20 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1132 = tosa.select %1131, %1130, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1133 = tosa.mul %1132, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1134 = tosa.mul %30, %1133 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1135 = tosa.transpose %1134, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1136 = tosa.transpose_conv2d %1135, %3, %cst_2 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x3x3x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1137 = tosa.transpose %1136, %21 : (tensor<1x56x56x64xf32>, tensor<4xi32>) -> tensor<1x64x56x56xf32>
#     %1138 = tosa.equal %global13, %global14 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %1139 = tosa.select %1138, %1137, %20 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %1140 = tosa.mul %1139, %29 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %1141 = tosa.mul %30, %1140 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %1142 = tosa.transpose %1141, %23 : (tensor<1x64x56x56xf32>, tensor<4xi32>) -> tensor<1x56x56x64xf32>
#     %1143 = tosa.transpose_conv2d %1142, %1, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<64x1x1x64xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %1144 = tosa.add %1129, %1143 : (tensor<1x56x56x64xf32>, tensor<1x56x56x64xf32>) -> tensor<1x56x56x64xf32>
#     %padded = tensor.pad %31 low[0, 1, 1, 0] high[0, 0, 0, 0] {
#     ^bb0(%arg1: index, %arg2: index, %arg3: index, %arg4: index):
#       tensor.yield %cst_11 : f32
#     } : tensor<1x112x112x64xf32> to tensor<1x113x113x64xf32>
#     %1145 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%padded, %cst_0, %global8, %1144 : tensor<1x113x113x64xf32>, tensor<3x3xf32>, tensor<1x56x56x64xf32>, tensor<1x56x56x64xf32>) outs(%cst_1 : tensor<1x113x113x64xf32>) {
#     ^bb0(%in: f32, %in_13: f32, %in_14: f32, %in_15: f32, %out: f32):
#       %1154 = arith.cmpf oge, %in, %in_14 : f32
#       %1155 = arith.select %1154, %in_15, %cst_10 : f32
#       %1156 = arith.addf %out, %1155 : f32
#       linalg.yield %1156 : f32
#     } -> tensor<1x113x113x64xf32>
#     %extracted_slice = tensor.extract_slice %1145[0, 1, 1, 0] [1, 112, 112, 64] [1, 1, 1, 1] : tensor<1x113x113x64xf32> to tensor<1x112x112x64xf32>
#     %1146 = tosa.transpose %extracted_slice, %21 : (tensor<1x112x112x64xf32>, tensor<4xi32>) -> tensor<1x64x112x112xf32>
#     %1147 = tosa.equal %global6, %global7 : (tensor<1x64x112x112xf32>, tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xi1>
#     %1148 = tosa.select %1147, %1146, %20 : (tensor<1x64x112x112xi1>, tensor<1x64x112x112xf32>, tensor<f32>) -> tensor<1x64x112x112xf32>
#     %1149 = tosa.mul %1148, %29 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %1150 = tosa.mul %30, %1149 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xf32>
#     %1151 = tosa.transpose %1150, %23 : (tensor<1x64x112x112xf32>, tensor<4xi32>) -> tensor<1x112x112x64xf32>
#     %1152 = tosa.transpose_conv2d %1151, %0, %cst {out_pad = array<i64: -3, -3, -3, -3>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>, tensor<3x7x7x64xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
#     %1153 = tosa.transpose %1152, %21 : (tensor<1x224x224x3xf32>, tensor<4xi32>) -> tensor<1x3x224x224xf32>
#     return %1153 : tensor<1x3x224x224xf32>
#   }
# }

# %%
# !ragdoll-opt --help | grep const
# Out:
#       --convert-scf-to-openmp                                -   Convert SCF parallel loop to OpenMP parallel + workshare constructs.
#       --convert-shape-constraints                            -   Convert shape constraint operations to the standard dialect
#       --expand-strided-metadata                              -   Expand memref operations into easier to analyze constructs
#       --remove-shape-constraints                             -   Replace all cstr_ ops with a true witness
#       --tosa-layerwise-constant-fold                         -   Fold layerwise operations on constant tensors
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimizationMay add more tosa.const but would reduce runtime calculations
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimization
