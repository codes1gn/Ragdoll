# %%
model_file = "wideresnet101.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
target_file = model_file + ".heuristic"
#!./convert_v0_to_v1.sh {model_file}
# !ragdoll-opt {model_file} --ragdoll-identical-transpose-removal > {model_file}.tmp
#!cat {model_file}.tmp

# !mv {model_file}.tmp {model_file}

# %%
model_file = "wideresnet101.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"
target_file = model_file + ".storeall"
# !ragdoll-opt {model_file}  \
--canonicalize \
--enable-cse-in-legalizer \
--symbol-dce \
--ragdoll-autodiff-vjp-public-functions='strategy=storeall' \
--ragdoll-autodiff-vjp \
--inline \
--ragdoll-autodiff-inline-function-call \
--ragdoll-initialisation \
--eliminate-empty-tensors \
--ragdoll-legalise-to-iree-compatibility \
--ragdoll-raise-linalg-to-tosa \
--canonicalize \
--cse > {target_file}

# %%
# !cat {target_file}
# Out:
# #map = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 + d4, d2 + d5, d3)>
# #map1 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d4, d5)>
# #map2 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1, d2, d3)>
# #map3 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 * 2 + d4, d2 * 2 + d5, d3)>
# module attributes {torch.debug_module_name = "ResNet"} {
#   ml_program.global private mutable @global704(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global703(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global697(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global696(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global691(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global690(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global685(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global684(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global678(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global677(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global672(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global671(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global666(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global665(dense<1.000000e+00> : tensor<1x7x7x2048xf32>) : tensor<1x7x7x2048xf32>
#   ml_program.global private mutable @global656(dense<1.000000e+00> : tensor<1x1x1x2048xf32>) : tensor<1x1x1x2048xf32>
#   ml_program.global private mutable @global652(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global651(dense<1.000000e+00> : tensor<1x7x7x1024xf32>) : tensor<1x7x7x1024xf32>
#   ml_program.global private mutable @global646(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global645(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global640(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global639(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global633(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global632(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global627(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global626(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global621(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global620(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global614(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global613(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global608(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global607(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global602(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global601(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global595(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global594(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global589(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global588(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global583(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global582(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global576(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global575(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global570(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global569(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global564(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global563(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global557(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global556(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global551(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global550(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global545(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global544(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global538(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global537(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global532(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global531(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global526(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global525(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global519(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global518(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global513(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global512(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global507(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global506(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global500(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global499(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global494(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global493(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global488(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global487(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global481(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global480(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global475(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global474(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global469(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global468(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global462(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global461(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global456(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global455(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global450(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global449(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global443(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global442(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global437(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global436(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global431(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global430(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global424(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global423(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global418(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global417(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global412(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global411(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global405(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global404(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global399(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global398(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global393(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global392(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global386(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global385(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global380(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global379(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global374(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global373(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global367(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global366(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global361(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global360(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global355(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global354(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global348(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global347(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global342(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global341(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global336(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global335(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global329(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global328(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global323(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global322(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global317(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global316(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global310(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global309(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global304(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global303(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global298(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global297(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global291(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global290(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global285(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global284(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global279(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global278(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global272(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global271(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global266(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global265(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global260(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global259(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global253(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global252(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global247(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global246(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global241(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global240(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global234(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global233(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global228(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global227(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global222(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global221(dense<1.000000e+00> : tensor<1x14x14x1024xf32>) : tensor<1x14x14x1024xf32>
#   ml_program.global private mutable @global212(dense<1.000000e+00> : tensor<1x1x1x1024xf32>) : tensor<1x1x1x1024xf32>
#   ml_program.global private mutable @global208(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global207(dense<1.000000e+00> : tensor<1x14x14x512xf32>) : tensor<1x14x14x512xf32>
#   ml_program.global private mutable @global202(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global201(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global196(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global195(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global189(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global188(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global183(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global182(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global177(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global176(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global170(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global169(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global164(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global163(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global158(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global157(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global151(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global150(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global145(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global144(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global139(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global138(dense<1.000000e+00> : tensor<1x28x28x512xf32>) : tensor<1x28x28x512xf32>
#   ml_program.global private mutable @global129(dense<1.000000e+00> : tensor<1x1x1x512xf32>) : tensor<1x1x1x512xf32>
#   ml_program.global private mutable @global125(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global124(dense<1.000000e+00> : tensor<1x28x28x256xf32>) : tensor<1x28x28x256xf32>
#   ml_program.global private mutable @global119(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global118(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global113(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global112(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global106(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global105(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global100(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global99(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global94(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global93(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global87(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global86(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global81(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global80(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global75(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global74(dense<1.000000e+00> : tensor<1x56x56x256xf32>) : tensor<1x56x56x256xf32>
#   ml_program.global private mutable @global65(dense<1.000000e+00> : tensor<1x1x1x256xf32>) : tensor<1x1x1x256xf32>
#   ml_program.global private mutable @global61(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global60(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global55(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global54(dense<1.000000e+00> : tensor<1x56x56x128xf32>) : tensor<1x56x56x128xf32>
#   ml_program.global private mutable @global51(dense<1.000000e+00> : tensor<1x1x1x128xf32>) : tensor<1x1x1x128xf32>
#   ml_program.global private mutable @global47(dense<1.000000e+00> : tensor<1x56x56x64xf32>) : tensor<1x56x56x64xf32>
#   ml_program.global private mutable @global46(dense<1.000000e+00> : tensor<1x112x112x64xf32>) : tensor<1x112x112x64xf32>
#   ml_program.global private mutable @global45(dense<1.000000e+00> : tensor<1x112x112x64xf32>) : tensor<1x112x112x64xf32>
#   ml_program.global private mutable @global42(dense<1.000000e+00> : tensor<1x1x1x64xf32>) : tensor<1x1x1x64xf32>
#   ml_program.global private mutable @global38(dense<1.000000e+00> : tensor<64x7x7x3xf32>) : tensor<64x7x7x3xf32>
#   ml_program.global private mutable @global37(dense<1.000000e+00> : tensor<1x1x1x64xf32>) : tensor<1x1x1x64xf32>
#   ml_program.global private mutable @global35(dense<1.000000e+00> : tensor<128x1x1x64xf32>) : tensor<128x1x1x64xf32>
#   ml_program.global private mutable @global34(dense<1.000000e+00> : tensor<1x1x1x128xf32>) : tensor<1x1x1x128xf32>
#   ml_program.global private mutable @global32(dense<1.000000e+00> : tensor<128x3x3x128xf32>) : tensor<128x3x3x128xf32>
#   ml_program.global private mutable @global31(dense<1.000000e+00> : tensor<256x1x1x128xf32>) : tensor<256x1x1x128xf32>
#   ml_program.global private mutable @global30(dense<1.000000e+00> : tensor<1x1x1x256xf32>) : tensor<1x1x1x256xf32>
#   ml_program.global private mutable @global28(dense<1.000000e+00> : tensor<256x1x1x64xf32>) : tensor<256x1x1x64xf32>
#   ml_program.global private mutable @global27(dense<1.000000e+00> : tensor<128x1x1x256xf32>) : tensor<128x1x1x256xf32>
#   ml_program.global private mutable @global26(dense<1.000000e+00> : tensor<256x1x1x256xf32>) : tensor<256x1x1x256xf32>
#   ml_program.global private mutable @global25(dense<1.000000e+00> : tensor<256x3x3x256xf32>) : tensor<256x3x3x256xf32>
#   ml_program.global private mutable @global24(dense<1.000000e+00> : tensor<512x1x1x256xf32>) : tensor<512x1x1x256xf32>
#   ml_program.global private mutable @global23(dense<1.000000e+00> : tensor<1x1x1x512xf32>) : tensor<1x1x1x512xf32>
#   ml_program.global private mutable @global21(dense<1.000000e+00> : tensor<256x1x1x512xf32>) : tensor<256x1x1x512xf32>
#   ml_program.global private mutable @global20(dense<1.000000e+00> : tensor<512x1x1x512xf32>) : tensor<512x1x1x512xf32>
#   ml_program.global private mutable @global19(dense<1.000000e+00> : tensor<512x3x3x512xf32>) : tensor<512x3x3x512xf32>
#   ml_program.global private mutable @global18(dense<1.000000e+00> : tensor<1024x1x1x512xf32>) : tensor<1024x1x1x512xf32>
#   ml_program.global private mutable @global17(dense<1.000000e+00> : tensor<1x1x1x1024xf32>) : tensor<1x1x1x1024xf32>
#   ml_program.global private mutable @global15(dense<1.000000e+00> : tensor<512x1x1x1024xf32>) : tensor<512x1x1x1024xf32>
#   ml_program.global private mutable @global14(dense<1.000000e+00> : tensor<1024x1x1x1024xf32>) : tensor<1024x1x1x1024xf32>
#   ml_program.global private mutable @global13(dense<1.000000e+00> : tensor<1024x3x3x1024xf32>) : tensor<1024x3x3x1024xf32>
#   ml_program.global private mutable @global12(dense<1.000000e+00> : tensor<2048x1x1x1024xf32>) : tensor<2048x1x1x1024xf32>
#   ml_program.global private mutable @global11(dense<1.000000e+00> : tensor<1x1x1x2048xf32>) : tensor<1x1x1x2048xf32>
#   ml_program.global private mutable @global9(dense<1.000000e+00> : tensor<1024x1x1x2048xf32>) : tensor<1024x1x1x2048xf32>
#   ml_program.global private mutable @global8(dense<1.000000e+00> : tensor<1x2048x1000xf32>) : tensor<1x2048x1000xf32>
#   func.func @forward(%arg0: tensor<1x224x224x3xf32>) -> tensor<1x1000xf32> {
#     %0 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x7x7x3xf32>}> : () -> tensor<64x7x7x3xf32>
#     %1 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x64xf32>}> : () -> tensor<1x1x1x64xf32>
#     %2 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<64x1x1xf32>}> : () -> tensor<64x1x1xf32>
#     %3 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x64xf32>}> : () -> tensor<128x1x1x64xf32>
#     %4 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x128xf32>}> : () -> tensor<1x1x1x128xf32>
#     %5 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<128x1x1xf32>}> : () -> tensor<128x1x1xf32>
#     %6 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x3x3x128xf32>}> : () -> tensor<128x3x3x128xf32>
#     %7 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x128xf32>}> : () -> tensor<256x1x1x128xf32>
#     %8 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x256xf32>}> : () -> tensor<1x1x1x256xf32>
#     %9 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<256x1x1xf32>}> : () -> tensor<256x1x1xf32>
#     %10 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x64xf32>}> : () -> tensor<256x1x1x64xf32>
#     %11 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x256xf32>}> : () -> tensor<128x1x1x256xf32>
#     %12 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x256xf32>}> : () -> tensor<256x1x1x256xf32>
#     %13 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x3x3x256xf32>}> : () -> tensor<256x3x3x256xf32>
#     %14 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x256xf32>}> : () -> tensor<512x1x1x256xf32>
#     %15 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x512xf32>}> : () -> tensor<1x1x1x512xf32>
#     %16 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<512x1x1xf32>}> : () -> tensor<512x1x1xf32>
#     %17 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x512xf32>}> : () -> tensor<256x1x1x512xf32>
#     %18 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x512xf32>}> : () -> tensor<512x1x1x512xf32>
#     %19 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x3x3x512xf32>}> : () -> tensor<512x3x3x512xf32>
#     %20 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x1x1x512xf32>}> : () -> tensor<1024x1x1x512xf32>
#     %21 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x1024xf32>}> : () -> tensor<1x1x1x1024xf32>
#     %22 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1024x1x1xf32>}> : () -> tensor<1024x1x1xf32>
#     %23 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<512x1x1x1024xf32>}> : () -> tensor<512x1x1x1024xf32>
#     %24 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x1x1x1024xf32>}> : () -> tensor<1024x1x1x1024xf32>
#     %25 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x3x3x1024xf32>}> : () -> tensor<1024x3x3x1024xf32>
#     %26 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<2048x1x1x1024xf32>}> : () -> tensor<2048x1x1x1024xf32>
#     %27 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x1x2048xf32>}> : () -> tensor<1x1x1x2048xf32>
#     %28 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<2048x1x1xf32>}> : () -> tensor<2048x1x1xf32>
#     %29 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1024x1x1x2048xf32>}> : () -> tensor<1024x1x1x2048xf32>
#     %30 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x2048x1000xf32>}> : () -> tensor<1x2048x1000xf32>
#     %31 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1000xf32>}> : () -> tensor<1x1000xf32>
#     %32 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<2048xf32>}> : () -> tensor<2048xf32>
#     %33 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<1024xf32>}> : () -> tensor<1024xf32>
#     %34 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<512xf32>}> : () -> tensor<512xf32>
#     %35 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<256xf32>}> : () -> tensor<256xf32>
#     %36 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<128xf32>}> : () -> tensor<128xf32>
#     %37 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<64xf32>}> : () -> tensor<64xf32>
#     ml_program.global_store @global8 = %30 : tensor<1x2048x1000xf32>
#     ml_program.global_store @global9 = %29 : tensor<1024x1x1x2048xf32>
#     ml_program.global_store @global11 = %27 : tensor<1x1x1x2048xf32>
#     ml_program.global_store @global12 = %26 : tensor<2048x1x1x1024xf32>
#     ml_program.global_store @global13 = %25 : tensor<1024x3x3x1024xf32>
#     ml_program.global_store @global14 = %24 : tensor<1024x1x1x1024xf32>
#     ml_program.global_store @global15 = %23 : tensor<512x1x1x1024xf32>
#     ml_program.global_store @global17 = %21 : tensor<1x1x1x1024xf32>
#     ml_program.global_store @global18 = %20 : tensor<1024x1x1x512xf32>
#     ml_program.global_store @global19 = %19 : tensor<512x3x3x512xf32>
#     ml_program.global_store @global20 = %18 : tensor<512x1x1x512xf32>
#     ml_program.global_store @global21 = %17 : tensor<256x1x1x512xf32>
#     ml_program.global_store @global23 = %15 : tensor<1x1x1x512xf32>
#     ml_program.global_store @global24 = %14 : tensor<512x1x1x256xf32>
#     ml_program.global_store @global25 = %13 : tensor<256x3x3x256xf32>
#     ml_program.global_store @global26 = %12 : tensor<256x1x1x256xf32>
#     ml_program.global_store @global27 = %11 : tensor<128x1x1x256xf32>
#     ml_program.global_store @global28 = %10 : tensor<256x1x1x64xf32>
#     ml_program.global_store @global30 = %8 : tensor<1x1x1x256xf32>
#     ml_program.global_store @global31 = %7 : tensor<256x1x1x128xf32>
#     ml_program.global_store @global32 = %6 : tensor<128x3x3x128xf32>
#     ml_program.global_store @global34 = %4 : tensor<1x1x1x128xf32>
#     ml_program.global_store @global35 = %3 : tensor<128x1x1x64xf32>
#     ml_program.global_store @global37 = %1 : tensor<1x1x1x64xf32>
#     ml_program.global_store @global38 = %0 : tensor<64x7x7x3xf32>
#     %38 = tosa.conv2d %arg0, %0, %37 {dilation = array<i64: 1, 1>, pad = array<i64: 3, 3, 3, 3>, stride = array<i64: 2, 2>} : (tensor<1x224x224x3xf32>, tensor<64x7x7x3xf32>, tensor<64xf32>) -> tensor<1x112x112x64xf32>
#     %39 = tosa.sub %38, %1 : (tensor<1x112x112x64xf32>, tensor<1x1x1x64xf32>) -> tensor<1x112x112x64xf32>
#     %40 = tosa.rsqrt %2 : (tensor<64x1x1xf32>) -> tensor<64x1x1xf32>
#     %41 = tosa.reshape %40 {new_shape = array<i64: 1, 64, 1, 1>} : (tensor<64x1x1xf32>) -> tensor<1x1x1x64xf32>
#     ml_program.global_store @global42 = %41 : tensor<1x1x1x64xf32>
#     %42 = tosa.mul %39, %41 {shift = 0 : i8} : (tensor<1x112x112x64xf32>, tensor<1x1x1x64xf32>) -> tensor<1x112x112x64xf32>
#     %43 = tosa.mul %42, %1 {shift = 0 : i8} : (tensor<1x112x112x64xf32>, tensor<1x1x1x64xf32>) -> tensor<1x112x112x64xf32>
#     %44 = tosa.add %43, %1 : (tensor<1x112x112x64xf32>, tensor<1x1x1x64xf32>) -> tensor<1x112x112x64xf32>
#     ml_program.global_store @global45 = %44 : tensor<1x112x112x64xf32>
#     %45 = tosa.clamp %44 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x112x112x64xf32>) -> tensor<1x112x112x64xf32>
#     ml_program.global_store @global46 = %45 : tensor<1x112x112x64xf32>
#     %46 = tosa.max_pool2d %45 {kernel = array<i64: 3, 3>, pad = array<i64: 1, 0, 1, 0>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>) -> tensor<1x56x56x64xf32>
#     ml_program.global_store @global47 = %46 : tensor<1x56x56x64xf32>
#     %47 = tosa.conv2d %46, %3, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<128x1x1x64xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %48 = tosa.sub %47, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %49 = tosa.rsqrt %5 : (tensor<128x1x1xf32>) -> tensor<128x1x1xf32>
#     %50 = tosa.reshape %49 {new_shape = array<i64: 1, 128, 1, 1>} : (tensor<128x1x1xf32>) -> tensor<1x1x1x128xf32>
#     ml_program.global_store @global51 = %50 : tensor<1x1x1x128xf32>
#     %51 = tosa.mul %48, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %52 = tosa.mul %51, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %53 = tosa.add %52, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global54 = %53 : tensor<1x56x56x128xf32>
#     %54 = tosa.clamp %53 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global55 = %54 : tensor<1x56x56x128xf32>
#     %55 = tosa.conv2d %54, %6, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %56 = tosa.sub %55, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %57 = tosa.mul %56, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %58 = tosa.mul %57, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %59 = tosa.add %58, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global60 = %59 : tensor<1x56x56x128xf32>
#     %60 = tosa.clamp %59 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global61 = %60 : tensor<1x56x56x128xf32>
#     %61 = tosa.conv2d %60, %7, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %62 = tosa.sub %61, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %63 = tosa.rsqrt %9 : (tensor<256x1x1xf32>) -> tensor<256x1x1xf32>
#     %64 = tosa.reshape %63 {new_shape = array<i64: 1, 256, 1, 1>} : (tensor<256x1x1xf32>) -> tensor<1x1x1x256xf32>
#     ml_program.global_store @global65 = %64 : tensor<1x1x1x256xf32>
#     %65 = tosa.mul %62, %64 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %66 = tosa.mul %65, %8 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %67 = tosa.add %66, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %68 = tosa.conv2d %46, %10, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %69 = tosa.sub %68, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %70 = tosa.mul %69, %64 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %71 = tosa.mul %70, %8 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %72 = tosa.add %71, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %73 = tosa.add %67, %72 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global74 = %73 : tensor<1x56x56x256xf32>
#     %74 = tosa.clamp %73 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global75 = %74 : tensor<1x56x56x256xf32>
#     %75 = tosa.conv2d %74, %11, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<128x1x1x256xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %76 = tosa.sub %75, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %77 = tosa.mul %76, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %78 = tosa.mul %77, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %79 = tosa.add %78, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global80 = %79 : tensor<1x56x56x128xf32>
#     %80 = tosa.clamp %79 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global81 = %80 : tensor<1x56x56x128xf32>
#     %81 = tosa.conv2d %80, %6, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %82 = tosa.sub %81, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %83 = tosa.mul %82, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %84 = tosa.mul %83, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %85 = tosa.add %84, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global86 = %85 : tensor<1x56x56x128xf32>
#     %86 = tosa.clamp %85 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global87 = %86 : tensor<1x56x56x128xf32>
#     %87 = tosa.conv2d %86, %7, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %88 = tosa.sub %87, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %89 = tosa.mul %88, %64 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %90 = tosa.mul %89, %8 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %91 = tosa.add %90, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %92 = tosa.add %91, %74 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global93 = %92 : tensor<1x56x56x256xf32>
#     %93 = tosa.clamp %92 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global94 = %93 : tensor<1x56x56x256xf32>
#     %94 = tosa.conv2d %93, %11, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<128x1x1x256xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %95 = tosa.sub %94, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %96 = tosa.mul %95, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %97 = tosa.mul %96, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %98 = tosa.add %97, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global99 = %98 : tensor<1x56x56x128xf32>
#     %99 = tosa.clamp %98 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global100 = %99 : tensor<1x56x56x128xf32>
#     %100 = tosa.conv2d %99, %6, %36 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %101 = tosa.sub %100, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %102 = tosa.mul %101, %50 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %103 = tosa.mul %102, %4 {shift = 0 : i8} : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     %104 = tosa.add %103, %4 : (tensor<1x56x56x128xf32>, tensor<1x1x1x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global105 = %104 : tensor<1x56x56x128xf32>
#     %105 = tosa.clamp %104 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     ml_program.global_store @global106 = %105 : tensor<1x56x56x128xf32>
#     %106 = tosa.conv2d %105, %7, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %107 = tosa.sub %106, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %108 = tosa.mul %107, %64 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %109 = tosa.mul %108, %8 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %110 = tosa.add %109, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %111 = tosa.add %110, %93 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global112 = %111 : tensor<1x56x56x256xf32>
#     %112 = tosa.clamp %111 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global113 = %112 : tensor<1x56x56x256xf32>
#     %113 = tosa.conv2d %112, %12, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<256x1x1x256xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %114 = tosa.sub %113, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %115 = tosa.mul %114, %64 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %116 = tosa.mul %115, %8 {shift = 0 : i8} : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     %117 = tosa.add %116, %8 : (tensor<1x56x56x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global118 = %117 : tensor<1x56x56x256xf32>
#     %118 = tosa.clamp %117 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     ml_program.global_store @global119 = %118 : tensor<1x56x56x256xf32>
#     %119 = tosa.conv2d %118, %13, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 2, 2>} : (tensor<1x56x56x256xf32>, tensor<256x3x3x256xf32>, tensor<256xf32>) -> tensor<1x28x28x256xf32>
#     %120 = tosa.sub %119, %8 : (tensor<1x28x28x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x28x28x256xf32>
#     %121 = tosa.mul %120, %64 {shift = 0 : i8} : (tensor<1x28x28x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x28x28x256xf32>
#     %122 = tosa.mul %121, %8 {shift = 0 : i8} : (tensor<1x28x28x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x28x28x256xf32>
#     %123 = tosa.add %122, %8 : (tensor<1x28x28x256xf32>, tensor<1x1x1x256xf32>) -> tensor<1x28x28x256xf32>
# ...
#     %464 = tosa.select %463, %462, %1 : (tensor<1x28x28x256xi1>, tensor<1x28x28x256xf32>, tensor<f32>) -> tensor<1x28x28x256xf32>
#     %465 = tosa.mul %global30, %464 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %466 = tosa.mul %global65, %465 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %467 = tosa.transpose_conv2d %466, %450, %cst_5 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 512>, stride = array<i64: 1, 1>} : (tensor<1x28x28x256xf32>, tensor<512x1x1x256xf32>, tensor<512xf32>) -> tensor<1x28x28x512xf32>
#     %468 = tosa.add %454, %467 : (tensor<1x28x28x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %469 = tosa.equal %global157, %global158 : (tensor<1x28x28x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xi1>
#     %470 = tosa.select %469, %468, %1 : (tensor<1x28x28x512xi1>, tensor<1x28x28x512xf32>, tensor<f32>) -> tensor<1x28x28x512xf32>
#     %471 = tosa.mul %global23, %470 {shift = 0 : i8} : (tensor<1x1x1x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %472 = tosa.mul %global129, %471 {shift = 0 : i8} : (tensor<1x1x1x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %473 = tosa.transpose_conv2d %472, %438, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 256>, stride = array<i64: 1, 1>} : (tensor<1x28x28x512xf32>, tensor<256x1x1x512xf32>, tensor<256xf32>) -> tensor<1x28x28x256xf32>
#     %474 = tosa.equal %global150, %global151 : (tensor<1x28x28x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xi1>
#     %475 = tosa.select %474, %473, %1 : (tensor<1x28x28x256xi1>, tensor<1x28x28x256xf32>, tensor<f32>) -> tensor<1x28x28x256xf32>
#     %476 = tosa.mul %global30, %475 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %477 = tosa.mul %global65, %476 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %478 = tosa.transpose_conv2d %477, %444, %cst_4 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 28, 28, 256>, stride = array<i64: 1, 1>} : (tensor<1x28x28x256xf32>, tensor<256x3x3x256xf32>, tensor<256xf32>) -> tensor<1x28x28x256xf32>
#     %479 = tosa.equal %global144, %global145 : (tensor<1x28x28x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xi1>
#     %480 = tosa.select %479, %478, %1 : (tensor<1x28x28x256xi1>, tensor<1x28x28x256xf32>, tensor<f32>) -> tensor<1x28x28x256xf32>
#     %481 = tosa.mul %global30, %480 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %482 = tosa.mul %global65, %481 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %483 = tosa.transpose_conv2d %482, %450, %cst_5 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 512>, stride = array<i64: 1, 1>} : (tensor<1x28x28x256xf32>, tensor<512x1x1x256xf32>, tensor<512xf32>) -> tensor<1x28x28x512xf32>
#     %484 = tosa.add %470, %483 : (tensor<1x28x28x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %485 = tosa.equal %global138, %global139 : (tensor<1x28x28x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xi1>
#     %486 = tosa.select %485, %484, %1 : (tensor<1x28x28x512xi1>, tensor<1x28x28x512xf32>, tensor<f32>) -> tensor<1x28x28x512xf32>
#     %487 = tosa.mul %global23, %486 {shift = 0 : i8} : (tensor<1x1x1x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %488 = tosa.mul %global129, %487 {shift = 0 : i8} : (tensor<1x1x1x512xf32>, tensor<1x28x28x512xf32>) -> tensor<1x28x28x512xf32>
#     %489 = tosa.transpose_conv2d %488, %438, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 2, 2>} : (tensor<1x28x28x512xf32>, tensor<256x1x1x512xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %490 = tosa.transpose_conv2d %488, %438, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 28, 28, 256>, stride = array<i64: 1, 1>} : (tensor<1x28x28x512xf32>, tensor<256x1x1x512xf32>, tensor<256xf32>) -> tensor<1x28x28x256xf32>
#     %491 = tosa.equal %global124, %global125 : (tensor<1x28x28x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xi1>
#     %492 = tosa.select %491, %490, %1 : (tensor<1x28x28x256xi1>, tensor<1x28x28x256xf32>, tensor<f32>) -> tensor<1x28x28x256xf32>
#     %493 = tosa.mul %global30, %492 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %494 = tosa.mul %global65, %493 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x28x28x256xf32>) -> tensor<1x28x28x256xf32>
#     %495 = tosa.transpose_conv2d %494, %444, %cst_4 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 2, 2>} : (tensor<1x28x28x256xf32>, tensor<256x3x3x256xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %496 = tosa.equal %global118, %global119 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xi1>
#     %497 = tosa.select %496, %495, %1 : (tensor<1x56x56x256xi1>, tensor<1x56x56x256xf32>, tensor<f32>) -> tensor<1x56x56x256xf32>
#     %498 = tosa.mul %global30, %497 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %499 = tosa.mul %global65, %498 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %500 = tosa.transpose %global26, %0 : (tensor<256x1x1x256xf32>, tensor<4xi64>) -> tensor<256x1x1x256xf32>
#     %501 = tosa.transpose_conv2d %499, %500, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<256x1x1x256xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %502 = tosa.add %489, %501 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %503 = tosa.equal %global112, %global113 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xi1>
#     %504 = tosa.select %503, %502, %1 : (tensor<1x56x56x256xi1>, tensor<1x56x56x256xf32>, tensor<f32>) -> tensor<1x56x56x256xf32>
#     %505 = tosa.mul %global30, %504 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %506 = tosa.mul %global65, %505 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %507 = tosa.transpose %global31, %0 : (tensor<256x1x1x128xf32>, tensor<4xi64>) -> tensor<128x1x1x256xf32>
#     %508 = tosa.transpose_conv2d %506, %507, %cst_3 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<128x1x1x256xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %509 = tosa.equal %global105, %global106 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %510 = tosa.select %509, %508, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %511 = tosa.mul %global34, %510 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %512 = tosa.mul %global51, %511 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %513 = tosa.transpose %global32, %0 : (tensor<128x3x3x128xf32>, tensor<4xi64>) -> tensor<128x3x3x128xf32>
#     %514 = tosa.transpose_conv2d %512, %513, %cst_3 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %515 = tosa.equal %global99, %global100 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %516 = tosa.select %515, %514, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %517 = tosa.mul %global34, %516 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %518 = tosa.mul %global51, %517 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %519 = tosa.transpose %global27, %0 : (tensor<128x1x1x256xf32>, tensor<4xi64>) -> tensor<256x1x1x128xf32>
#     %520 = tosa.transpose_conv2d %518, %519, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %521 = tosa.add %504, %520 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %522 = tosa.equal %global93, %global94 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xi1>
#     %523 = tosa.select %522, %521, %1 : (tensor<1x56x56x256xi1>, tensor<1x56x56x256xf32>, tensor<f32>) -> tensor<1x56x56x256xf32>
#     %524 = tosa.mul %global30, %523 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %525 = tosa.mul %global65, %524 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %526 = tosa.transpose_conv2d %525, %507, %cst_3 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<128x1x1x256xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %527 = tosa.equal %global86, %global87 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %528 = tosa.select %527, %526, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %529 = tosa.mul %global34, %528 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %530 = tosa.mul %global51, %529 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %531 = tosa.transpose_conv2d %530, %513, %cst_3 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %532 = tosa.equal %global80, %global81 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %533 = tosa.select %532, %531, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %534 = tosa.mul %global34, %533 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %535 = tosa.mul %global51, %534 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %536 = tosa.transpose_conv2d %535, %519, %cst_4 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 256>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<256x1x1x128xf32>, tensor<256xf32>) -> tensor<1x56x56x256xf32>
#     %537 = tosa.add %523, %536 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %538 = tosa.equal %global74, %global75 : (tensor<1x56x56x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xi1>
#     %539 = tosa.select %538, %537, %1 : (tensor<1x56x56x256xi1>, tensor<1x56x56x256xf32>, tensor<f32>) -> tensor<1x56x56x256xf32>
#     %540 = tosa.mul %global30, %539 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %541 = tosa.mul %global65, %540 {shift = 0 : i8} : (tensor<1x1x1x256xf32>, tensor<1x56x56x256xf32>) -> tensor<1x56x56x256xf32>
#     %542 = tosa.transpose %global28, %0 : (tensor<256x1x1x64xf32>, tensor<4xi64>) -> tensor<64x1x1x256xf32>
#     %543 = tosa.transpose_conv2d %541, %542, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %544 = tosa.transpose_conv2d %541, %507, %cst_3 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x256xf32>, tensor<128x1x1x256xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %545 = tosa.equal %global60, %global61 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %546 = tosa.select %545, %544, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %547 = tosa.mul %global34, %546 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %548 = tosa.mul %global51, %547 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %549 = tosa.transpose_conv2d %548, %513, %cst_3 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x3x3x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %550 = tosa.equal %global54, %global55 : (tensor<1x56x56x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xi1>
#     %551 = tosa.select %550, %549, %1 : (tensor<1x56x56x128xi1>, tensor<1x56x56x128xf32>, tensor<f32>) -> tensor<1x56x56x128xf32>
#     %552 = tosa.mul %global34, %551 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %553 = tosa.mul %global51, %552 {shift = 0 : i8} : (tensor<1x1x1x128xf32>, tensor<1x56x56x128xf32>) -> tensor<1x56x56x128xf32>
#     %554 = tosa.transpose %global35, %0 : (tensor<128x1x1x64xf32>, tensor<4xi64>) -> tensor<64x1x1x128xf32>
#     %555 = tosa.transpose_conv2d %553, %554, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<64x1x1x128xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %556 = tosa.add %543, %555 : (tensor<1x56x56x64xf32>, tensor<1x56x56x64xf32>) -> tensor<1x56x56x64xf32>
#     %padded = tensor.pad %global46 low[0, 1, 1, 0] high[0, 0, 0, 0] {
#     ^bb0(%arg1: index, %arg2: index, %arg3: index, %arg4: index):
#       tensor.yield %cst_11 : f32
#     } : tensor<1x112x112x64xf32> to tensor<1x113x113x64xf32>
#     %557 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%padded, %cst_0, %global47, %556 : tensor<1x113x113x64xf32>, tensor<3x3xf32>, tensor<1x56x56x64xf32>, tensor<1x56x56x64xf32>) outs(%cst_1 : tensor<1x113x113x64xf32>) {
#     ^bb0(%in: f32, %in_13: f32, %in_14: f32, %in_15: f32, %out: f32):
#       %564 = arith.cmpf oge, %in, %in_14 : f32
#       %565 = arith.select %564, %in_15, %cst_10 : f32
#       %566 = arith.addf %out, %565 : f32
#       linalg.yield %566 : f32
#     } -> tensor<1x113x113x64xf32>
#     %extracted_slice = tensor.extract_slice %557[0, 1, 1, 0] [1, 112, 112, 64] [1, 1, 1, 1] : tensor<1x113x113x64xf32> to tensor<1x112x112x64xf32>
#     %558 = tosa.equal %global45, %global46 : (tensor<1x112x112x64xf32>, tensor<1x112x112x64xf32>) -> tensor<1x112x112x64xi1>
#     %559 = tosa.select %558, %extracted_slice, %1 : (tensor<1x112x112x64xi1>, tensor<1x112x112x64xf32>, tensor<f32>) -> tensor<1x112x112x64xf32>
#     %560 = tosa.mul %global37, %559 {shift = 0 : i8} : (tensor<1x1x1x64xf32>, tensor<1x112x112x64xf32>) -> tensor<1x112x112x64xf32>
#     %561 = tosa.mul %global42, %560 {shift = 0 : i8} : (tensor<1x1x1x64xf32>, tensor<1x112x112x64xf32>) -> tensor<1x112x112x64xf32>
#     %562 = tosa.transpose %global38, %0 : (tensor<64x7x7x3xf32>, tensor<4xi64>) -> tensor<3x7x7x64xf32>
#     %563 = tosa.transpose_conv2d %561, %562, %cst {out_pad = array<i64: -3, -3, -3, -3>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>, tensor<3x7x7x64xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
#     return %563 : tensor<1x224x224x3xf32>
#   }
# }

# %%
# !ragdoll-opt --help | grep const
# Out:
#       --convert-scf-to-openmp                                -   Convert SCF parallel loop to OpenMP parallel + workshare constructs.
#       --convert-shape-constraints                            -   Convert shape constraint operations to the standard dialect
#       --expand-strided-metadata                              -   Expand memref operations into easier to analyze constructs
#       --remove-shape-constraints                             -   Replace all cstr_ ops with a true witness
#       --tosa-layerwise-constant-fold                         -   Fold layerwise operations on constant tensors
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimizationMay add more tosa.const but would reduce runtime calculations
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimization
