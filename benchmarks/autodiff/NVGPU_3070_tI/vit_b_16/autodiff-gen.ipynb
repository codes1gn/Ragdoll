# %%
model_file = "vit.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
target_file = model_file + ".heuristic"
#!./convert_v0_to_v1.sh {model_file}
# !ragdoll-opt {model_file} --ragdoll-identical-transpose-removal > {model_file}.tmp
#!cat {model_file}.tmp

#!mv {model_file}.tmp {model_file}
# Out:
# /bin/bash: line 1: ./convert_v0_to_v1.sh: No such file or directory

# %%
model_file = "vit.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"
target_file = model_file + ".storeall"
# !ragdoll-opt {model_file}  \
--canonicalize \
--enable-cse-in-legalizer \
--symbol-dce \
--ragdoll-autodiff-vjp-public-functions='strategy=storeall' \
--ragdoll-autodiff-vjp \
--inline \
--ragdoll-autodiff-inline-function-call \
--ragdoll-initialisation \
--eliminate-empty-tensors \
--ragdoll-legalise-to-iree-compatibility \
--ragdoll-raise-linalg-to-tosa \
--canonicalize \
--cse > {target_file}

# %%
# !cat {target_file}
# Out:
# #map = affine_map<(d0, d1, d2, d3) -> (d0, d1, d2)>
# #map1 = affine_map<(d0, d1, d2, d3) -> (d0, d1, d3)>
# module {
#   ml_program.global private mutable @global689(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global688(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global684(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global677(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global676(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global671(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global670(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global665(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global664(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global660(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global650(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global649(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global648(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global647(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global644(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global643(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global635(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global634(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global630(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global623(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global622(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global617(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global616(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global611(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global610(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global606(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global596(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global595(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global594(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global593(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global590(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global589(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global581(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global580(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global576(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global569(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global568(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global563(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global562(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global557(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global556(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global552(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global542(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global541(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global540(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global539(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global536(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global535(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global527(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global526(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global522(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global515(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global514(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global509(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global508(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global503(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global502(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global498(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global488(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global487(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global486(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global485(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global482(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global481(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global473(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global472(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global468(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global461(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global460(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global455(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global454(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global449(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global448(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global444(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global434(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global433(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global432(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global431(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global428(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global427(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global419(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global418(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global414(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global407(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global406(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global401(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global400(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global395(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global394(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global390(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global380(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global379(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global378(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global377(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global374(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global373(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global365(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global364(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global360(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global353(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global352(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global347(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global346(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global341(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global340(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global336(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global326(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global325(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global324(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global323(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global320(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global319(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global311(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global310(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global306(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global299(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global298(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global293(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global292(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global287(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global286(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global282(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global272(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global271(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global270(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global269(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global266(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global265(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global257(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global256(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global252(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global245(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global244(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global239(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global238(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global233(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global232(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global228(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global218(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global217(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global216(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global215(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global212(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global211(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global203(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global202(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global198(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global191(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global190(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global185(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global184(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global179(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global178(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global174(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global164(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global163(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global162(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global161(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global158(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global157(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global149(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global148(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global144(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global137(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global136(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global131(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global130(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global125(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global124(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global120(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global110(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global109(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global108(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global107(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global104(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global103(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global95(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global94(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global90(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global83(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global82(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global77(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global76(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global75(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global70(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global69(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global65(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global55(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global54(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global53(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
#   ml_program.global private mutable @global52(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
#   ml_program.global private mutable @global50(dense<1.000000e+00> : tensor<f32>) : tensor<f32>
#   ml_program.global private mutable @global48(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
#   ml_program.global private mutable @global47(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
#   ml_program.global private mutable @global39(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global38(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
#   ml_program.global private mutable @global34(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
#   ml_program.global private mutable @global21(dense<1.000000e+00> : tensor<1x768x1000xf32>) : tensor<1x768x1000xf32>
#   ml_program.global private mutable @global20(dense<1.000000e+00> : tensor<1x3072x768xf32>) : tensor<1x3072x768xf32>
#   ml_program.global private mutable @global19(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global16(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
#   ml_program.global private mutable @global13(dense<1.000000e+00> : tensor<1x768x3072xf32>) : tensor<1x768x3072xf32>
#   ml_program.global private mutable @global10(dense<1.000000e+00> : tensor<1x768x768xf32>) : tensor<1x768x768xf32>
#   ml_program.global private mutable @global8(dense<1.000000e+00> : tensor<f32>) : tensor<f32>
#   ml_program.global private mutable @global2(dense<1.000000e+00> : tensor<768xf32>) : tensor<768xf32>
#   ml_program.global private mutable @global1(dense<1.000000e+00> : tensor<768x16x16x3xf32>) : tensor<768x16x16x3xf32>
#   func.func @forward(%arg0: tensor<1x3x224x224xf32>) -> tensor<1x1000xf32> {
#     %cst = arith.constant dense<0.000000e+00> : tensor<1x197x768xf32>
#     %0 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1000xf32>}> : () -> tensor<1000xf32>
#     %1 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x768x1000xf32>}> : () -> tensor<1x768x1000xf32>
#     %2 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x3072x768xf32>}> : () -> tensor<1x3072x768xf32>
#     %3 = "tosa.const"() <{value = dense<3.000000e+00> : tensor<1x197x3072xf32>}> : () -> tensor<1x197x3072xf32>
#     %4 = "tosa.const"() <{value = dense<4.471500e-02> : tensor<1x197x3072xf32>}> : () -> tensor<1x197x3072xf32>
#     %5 = "tosa.const"() <{value = dense<1.57079637> : tensor<1x197x3072xf32>}> : () -> tensor<1x197x3072xf32>
#     %6 = "tosa.const"() <{value = dense<5.000000e-01> : tensor<1x197x3072xf32>}> : () -> tensor<1x197x3072xf32>
#     %7 = "tosa.const"() <{value = dense<1.000000e+00> : tensor<1x197x3072xf32>}> : () -> tensor<1x197x3072xf32>
#     %8 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<3072xf32>}> : () -> tensor<3072xf32>
#     %9 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x768x3072xf32>}> : () -> tensor<1x768x3072xf32>
#     %10 = "tosa.const"() <{value = dense<6.400000e+01> : tensor<f32>}> : () -> tensor<f32>
#     %11 = "tosa.const"() <{value = dense<[0, 2, 1, 3]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %12 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x768x768xf32>}> : () -> tensor<1x768x768xf32>
#     %13 = "tosa.const"() <{value = dense<9.99999997E-7> : tensor<f32>}> : () -> tensor<f32>
#     %14 = "tosa.const"() <{value = dense<0.00130208337> : tensor<f32>}> : () -> tensor<f32>
#     %15 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x197x768xf32>}> : () -> tensor<1x197x768xf32>
#     %16 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1x768xf32>}> : () -> tensor<1x1x768xf32>
#     %17 = "tosa.const"() <{value = dense<[0, 2, 1]> : tensor<3xi64>}> : () -> tensor<3xi64>
#     %18 = "tosa.const"() <{value = dense<[0, 3, 1, 2]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %19 = "tosa.const"() <{value = dense<[0, 2, 3, 1]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %20 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<768xf32>}> : () -> tensor<768xf32>
#     %21 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<768x16x16x3xf32>}> : () -> tensor<768x16x16x3xf32>
#     ml_program.global_store @global1 = %21 : tensor<768x16x16x3xf32>
#     ml_program.global_store @global2 = %20 : tensor<768xf32>
#     ml_program.global_store @global8 = %14 : tensor<f32>
#     ml_program.global_store @global10 = %12 : tensor<1x768x768xf32>
#     ml_program.global_store @global13 = %9 : tensor<1x768x3072xf32>
#     ml_program.global_store @global16 = %6 : tensor<1x197x3072xf32>
#     ml_program.global_store @global19 = %3 : tensor<1x197x3072xf32>
#     ml_program.global_store @global20 = %2 : tensor<1x3072x768xf32>
#     ml_program.global_store @global21 = %1 : tensor<1x768x1000xf32>
#     %22 = tosa.transpose %arg0, %19 : (tensor<1x3x224x224xf32>, tensor<4xi64>) -> tensor<1x224x224x3xf32>
#     %23 = tosa.conv2d %22, %21, %20 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 16, 16>} : (tensor<1x224x224x3xf32>, tensor<768x16x16x3xf32>, tensor<768xf32>) -> tensor<1x14x14x768xf32>
#     %24 = tosa.transpose %23, %18 : (tensor<1x14x14x768xf32>, tensor<4xi64>) -> tensor<1x768x14x14xf32>
#     %25 = tosa.reshape %24 {new_shape = array<i64: 1, 768, 196>} : (tensor<1x768x14x14xf32>) -> tensor<1x768x196xf32>
#     %26 = tosa.transpose %25, %17 : (tensor<1x768x196xf32>, tensor<3xi64>) -> tensor<1x196x768xf32>
#     %inserted_slice = tensor.insert_slice %16 into %cst[0, 0, 0] [1, 1, 768] [1, 1, 1] : tensor<1x1x768xf32> into tensor<1x197x768xf32>
#     %inserted_slice_0 = tensor.insert_slice %26 into %inserted_slice[0, 1, 0] [1, 196, 768] [1, 1, 1] : tensor<1x196x768xf32> into tensor<1x197x768xf32>
#     %27 = tosa.add %inserted_slice_0, %15 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %28 = tosa.reduce_sum %27 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %29 = tosa.mul %28, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %30 = tosa.sub %27, %29 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global34 = %30 : tensor<1x197x768xf32>
#     %31 = tosa.mul %30, %30 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %32 = tosa.reduce_sum %31 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %33 = tosa.mul %32, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %34 = tosa.add %33, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global38 = %34 : tensor<1x197x1xf32>
#     %35 = tosa.rsqrt %34 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global39 = %35 : tensor<1x197x1xf32>
#     %36 = tosa.mul %30, %35 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %37 = tosa.mul %36, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %38 = tosa.add %37, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %39 = tosa.matmul %38, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %40 = tosa.add %39, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %41 = tosa.reshape %40 {new_shape = array<i64: 1, 197, 12, 64>} : (tensor<1x197x768xf32>) -> tensor<1x197x12x64xf32>
#     %42 = tosa.transpose %41, %11 : (tensor<1x197x12x64xf32>, tensor<4xi64>) -> tensor<1x12x197x64xf32>
#     %43 = tosa.reshape %42 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
#     ml_program.global_store @global47 = %43 : tensor<12x197x64xf32>
#     %44 = tosa.transpose %43, %17 : (tensor<12x197x64xf32>, tensor<3xi64>) -> tensor<12x64x197xf32>
#     ml_program.global_store @global48 = %44 : tensor<12x64x197xf32>
#     %45 = tosa.matmul %43, %44 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
#     %46 = tosa.rsqrt %10 : (tensor<f32>) -> tensor<f32>
#     ml_program.global_store @global50 = %46 : tensor<f32>
#     %47 = tosa.mul %45, %46 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<f32>) -> tensor<12x197x197xf32>
#     %48 = tosa.exp %47 : (tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global52 = %48 : tensor<12x197x197xf32>
#     %49 = tosa.reduce_sum %48 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global53 = %49 : tensor<12x197x1xf32>
#     %50 = tosa.reciprocal %49 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global54 = %50 : tensor<12x197x1xf32>
#     %51 = tosa.mul %48, %50 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x1xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global55 = %51 : tensor<12x197x197xf32>
#     %52 = tosa.matmul %51, %43 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %53 = tosa.reshape %52 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
#     %54 = tosa.transpose %53, %11 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
#     %55 = tosa.reshape %54 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
#     %56 = tosa.matmul %55, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %57 = tosa.add %56, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %58 = tosa.add %57, %27 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %59 = tosa.reduce_sum %58 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %60 = tosa.mul %59, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %61 = tosa.sub %58, %60 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global65 = %61 : tensor<1x197x768xf32>
#     %62 = tosa.mul %61, %61 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %63 = tosa.reduce_sum %62 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %64 = tosa.mul %63, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %65 = tosa.add %64, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global69 = %65 : tensor<1x197x1xf32>
#     %66 = tosa.rsqrt %65 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global70 = %66 : tensor<1x197x1xf32>
#     %67 = tosa.mul %61, %66 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %68 = tosa.mul %67, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %69 = tosa.add %68, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %70 = tosa.matmul %69, %9 : (tensor<1x197x768xf32>, tensor<1x768x3072xf32>) -> tensor<1x197x3072xf32>
#     %71 = tosa.add %70, %8 : (tensor<1x197x3072xf32>, tensor<3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global75 = %71 : tensor<1x197x3072xf32>
#     %72 = tosa.mul %71, %6 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global76 = %72 : tensor<1x197x3072xf32>
#     %73 = tosa.rsqrt %5 : (tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global77 = %73 : tensor<1x197x3072xf32>
#     %74 = tosa.pow %71, %3 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %75 = tosa.mul %74, %4 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %76 = tosa.add %71, %75 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %77 = tosa.mul %73, %76 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %78 = tosa.tanh %77 : (tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global82 = %78 : tensor<1x197x3072xf32>
#     %79 = tosa.add %78, %7 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global83 = %79 : tensor<1x197x3072xf32>
#     %80 = tosa.mul %72, %79 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %81 = tosa.matmul %80, %2 : (tensor<1x197x3072xf32>, tensor<1x3072x768xf32>) -> tensor<1x197x768xf32>
#     %82 = tosa.add %81, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %83 = tosa.add %58, %82 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %84 = tosa.reduce_sum %83 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %85 = tosa.mul %84, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %86 = tosa.sub %83, %85 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global90 = %86 : tensor<1x197x768xf32>
#     %87 = tosa.mul %86, %86 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %88 = tosa.reduce_sum %87 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %89 = tosa.mul %88, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %90 = tosa.add %89, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global94 = %90 : tensor<1x197x1xf32>
#     %91 = tosa.rsqrt %90 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global95 = %91 : tensor<1x197x1xf32>
#     %92 = tosa.mul %86, %91 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %93 = tosa.mul %92, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %94 = tosa.add %93, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %95 = tosa.matmul %94, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %96 = tosa.add %95, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %97 = tosa.reshape %96 {new_shape = array<i64: 1, 197, 12, 64>} : (tensor<1x197x768xf32>) -> tensor<1x197x12x64xf32>
#     %98 = tosa.transpose %97, %11 : (tensor<1x197x12x64xf32>, tensor<4xi64>) -> tensor<1x12x197x64xf32>
#     %99 = tosa.reshape %98 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
#     ml_program.global_store @global103 = %99 : tensor<12x197x64xf32>
#     %100 = tosa.transpose %99, %17 : (tensor<12x197x64xf32>, tensor<3xi64>) -> tensor<12x64x197xf32>
#     ml_program.global_store @global104 = %100 : tensor<12x64x197xf32>
#     %101 = tosa.matmul %99, %100 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
#     %102 = tosa.mul %101, %46 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<f32>) -> tensor<12x197x197xf32>
#     %103 = tosa.exp %102 : (tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global107 = %103 : tensor<12x197x197xf32>
#     %104 = tosa.reduce_sum %103 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global108 = %104 : tensor<12x197x1xf32>
#     %105 = tosa.reciprocal %104 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global109 = %105 : tensor<12x197x1xf32>
#     %106 = tosa.mul %103, %105 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x1xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global110 = %106 : tensor<12x197x197xf32>
#     %107 = tosa.matmul %106, %99 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %108 = tosa.reshape %107 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
#     %109 = tosa.transpose %108, %11 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
#     %110 = tosa.reshape %109 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
#     %111 = tosa.matmul %110, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %112 = tosa.add %111, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %113 = tosa.add %112, %83 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %114 = tosa.reduce_sum %113 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %115 = tosa.mul %114, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %116 = tosa.sub %113, %115 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global120 = %116 : tensor<1x197x768xf32>
#     %117 = tosa.mul %116, %116 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %118 = tosa.reduce_sum %117 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %119 = tosa.mul %118, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %120 = tosa.add %119, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global124 = %120 : tensor<1x197x1xf32>
#     %121 = tosa.rsqrt %120 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global125 = %121 : tensor<1x197x1xf32>
#     %122 = tosa.mul %116, %121 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %123 = tosa.mul %122, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %124 = tosa.add %123, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %125 = tosa.matmul %124, %9 : (tensor<1x197x768xf32>, tensor<1x768x3072xf32>) -> tensor<1x197x3072xf32>
#     %126 = tosa.add %125, %8 : (tensor<1x197x3072xf32>, tensor<3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global130 = %126 : tensor<1x197x3072xf32>
#     %127 = tosa.mul %126, %6 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global131 = %127 : tensor<1x197x3072xf32>
#     %128 = tosa.pow %126, %3 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %129 = tosa.mul %128, %4 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %130 = tosa.add %126, %129 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %131 = tosa.mul %73, %130 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %132 = tosa.tanh %131 : (tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global136 = %132 : tensor<1x197x3072xf32>
#     %133 = tosa.add %132, %7 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global137 = %133 : tensor<1x197x3072xf32>
#     %134 = tosa.mul %127, %133 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %135 = tosa.matmul %134, %2 : (tensor<1x197x3072xf32>, tensor<1x3072x768xf32>) -> tensor<1x197x768xf32>
#     %136 = tosa.add %135, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %137 = tosa.add %113, %136 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %138 = tosa.reduce_sum %137 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %139 = tosa.mul %138, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %140 = tosa.sub %137, %139 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global144 = %140 : tensor<1x197x768xf32>
#     %141 = tosa.mul %140, %140 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %142 = tosa.reduce_sum %141 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %143 = tosa.mul %142, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %144 = tosa.add %143, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global148 = %144 : tensor<1x197x1xf32>
#     %145 = tosa.rsqrt %144 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global149 = %145 : tensor<1x197x1xf32>
#     %146 = tosa.mul %140, %145 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %147 = tosa.mul %146, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %148 = tosa.add %147, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %149 = tosa.matmul %148, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %150 = tosa.add %149, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %151 = tosa.reshape %150 {new_shape = array<i64: 1, 197, 12, 64>} : (tensor<1x197x768xf32>) -> tensor<1x197x12x64xf32>
#     %152 = tosa.transpose %151, %11 : (tensor<1x197x12x64xf32>, tensor<4xi64>) -> tensor<1x12x197x64xf32>
#     %153 = tosa.reshape %152 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
#     ml_program.global_store @global157 = %153 : tensor<12x197x64xf32>
#     %154 = tosa.transpose %153, %17 : (tensor<12x197x64xf32>, tensor<3xi64>) -> tensor<12x64x197xf32>
#     ml_program.global_store @global158 = %154 : tensor<12x64x197xf32>
#     %155 = tosa.matmul %153, %154 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
#     %156 = tosa.mul %155, %46 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<f32>) -> tensor<12x197x197xf32>
#     %157 = tosa.exp %156 : (tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global161 = %157 : tensor<12x197x197xf32>
#     %158 = tosa.reduce_sum %157 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global162 = %158 : tensor<12x197x1xf32>
#     %159 = tosa.reciprocal %158 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     ml_program.global_store @global163 = %159 : tensor<12x197x1xf32>
#     %160 = tosa.mul %157, %159 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x1xf32>) -> tensor<12x197x197xf32>
#     ml_program.global_store @global164 = %160 : tensor<12x197x197xf32>
#     %161 = tosa.matmul %160, %153 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %162 = tosa.reshape %161 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
#     %163 = tosa.transpose %162, %11 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
#     %164 = tosa.reshape %163 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
#     %165 = tosa.matmul %164, %12 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %166 = tosa.add %165, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %167 = tosa.add %166, %137 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %168 = tosa.reduce_sum %167 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %169 = tosa.mul %168, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %170 = tosa.sub %167, %169 : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     ml_program.global_store @global174 = %170 : tensor<1x197x768xf32>
#     %171 = tosa.mul %170, %170 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %172 = tosa.reduce_sum %171 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %173 = tosa.mul %172, %14 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %174 = tosa.add %173, %13 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global178 = %174 : tensor<1x197x1xf32>
#     %175 = tosa.rsqrt %174 : (tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     ml_program.global_store @global179 = %175 : tensor<1x197x1xf32>
#     %176 = tosa.mul %170, %175 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x1xf32>) -> tensor<1x197x768xf32>
#     %177 = tosa.mul %176, %20 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %178 = tosa.add %177, %20 : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
#     %179 = tosa.matmul %178, %9 : (tensor<1x197x768xf32>, tensor<1x768x3072xf32>) -> tensor<1x197x3072xf32>
#     %180 = tosa.add %179, %8 : (tensor<1x197x3072xf32>, tensor<3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global184 = %180 : tensor<1x197x3072xf32>
#     %181 = tosa.mul %180, %6 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global185 = %181 : tensor<1x197x3072xf32>
#     %182 = tosa.pow %180, %3 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %183 = tosa.mul %182, %4 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %184 = tosa.add %180, %183 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %185 = tosa.mul %73, %184 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %186 = tosa.tanh %185 : (tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     ml_program.global_store @global190 = %186 : tensor<1x197x3072xf32>
#     %187 = tosa.add %186, %7 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# ...
#     %848 = tosa.reshape %847 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
#     %849 = tosa.transpose %global103, %8 : (tensor<12x197x64xf32>, tensor<3xi32>) -> tensor<12x64x197xf32>
#     %850 = tosa.matmul %848, %849 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
#     %851 = tosa.transpose %global110, %8 : (tensor<12x197x197xf32>, tensor<3xi32>) -> tensor<12x197x197xf32>
#     %852 = tosa.matmul %851, %848 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %853 = tosa.mul %global109, %850 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %854 = tosa.mul %global107, %850 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %855 = tosa.reduce_sum %854 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
#     %856 = tosa.mul %global108, %global108 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %857 = tosa.negate %856 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %858 = tosa.reciprocal %857 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %859 = tosa.mul %858, %855 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %860 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%859 : tensor<12x197x1xf32>) outs(%cst_0 : tensor<12x197x197xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<12x197x197xf32>
#     %861 = tosa.add %853, %860 : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %862 = tosa.mul %global107, %861 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %863 = tosa.mul %global50, %862 {shift = 0 : i8} : (tensor<f32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %864 = tosa.transpose %global104, %8 : (tensor<12x64x197xf32>, tensor<3xi32>) -> tensor<12x197x64xf32>
#     %865 = tosa.matmul %863, %864 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %866 = tosa.add %852, %865 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %867 = tosa.matmul %849, %863 : (tensor<12x64x197xf32>, tensor<12x197x197xf32>) -> tensor<12x64x197xf32>
#     %868 = tosa.transpose %867, %3 : (tensor<12x64x197xf32>, tensor<3xi64>) -> tensor<12x197x64xf32>
#     %869 = tosa.add %866, %868 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %870 = tosa.reshape %869 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
#     %871 = tosa.transpose %870, %4 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
#     %872 = tosa.reshape %871 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
#     %873 = tosa.matmul %872, %64 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %874 = tosa.mul %global2, %873 {shift = 0 : i8} : (tensor<768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %875 = tosa.mul %global95, %874 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %876 = tosa.mul %global90, %874 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %877 = tosa.reduce_sum %876 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %878 = tosa.pow %global94, %6 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %879 = tosa.mul %878, %7 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %880 = tosa.mul %879, %877 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %881 = tosa.mul %global8, %880 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %882 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%881 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %883 = tosa.mul %global90, %882 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %884 = tosa.add %875, %883 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %885 = tosa.add %884, %883 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %886 = tosa.add %844, %885 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %887 = tosa.negate %885 : (tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %888 = tosa.reduce_sum %887 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %889 = tosa.mul %global8, %888 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %890 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%889 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %891 = tosa.add %886, %890 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %892 = tosa.matmul %891, %30 : (tensor<1x197x768xf32>, tensor<1x768x3072xf32>) -> tensor<1x197x3072xf32>
#     %893 = tosa.mul %global83, %892 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %894 = tosa.mul %global76, %892 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %895 = tosa.mul %global82, %global82 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %896 = tosa.sub %5, %895 : (tensor<f32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %897 = tosa.mul %896, %894 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %898 = tosa.mul %global77, %897 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %899 = tosa.pow %global75, %38 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %900 = tosa.mul %899, %global19 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %901 = tosa.add %898, %900 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %902 = tosa.mul %global16, %893 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %903 = tosa.add %901, %902 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
#     %904 = tosa.matmul %903, %44 : (tensor<1x197x3072xf32>, tensor<1x3072x768xf32>) -> tensor<1x197x768xf32>
#     %905 = tosa.mul %global2, %904 {shift = 0 : i8} : (tensor<768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %906 = tosa.mul %global70, %905 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %907 = tosa.mul %global65, %905 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %908 = tosa.reduce_sum %907 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %909 = tosa.pow %global69, %6 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %910 = tosa.mul %909, %7 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %911 = tosa.mul %910, %908 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %912 = tosa.mul %global8, %911 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %913 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%912 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %914 = tosa.mul %global65, %913 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %915 = tosa.add %906, %914 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %916 = tosa.add %915, %914 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %917 = tosa.add %891, %916 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %918 = tosa.negate %916 : (tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %919 = tosa.reduce_sum %918 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %920 = tosa.mul %global8, %919 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %921 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%920 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %922 = tosa.add %917, %921 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %923 = tosa.matmul %922, %64 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %924 = tosa.reshape %923 {new_shape = array<i64: 1, 197, 12, 64>} : (tensor<1x197x768xf32>) -> tensor<1x197x12x64xf32>
#     %925 = tosa.transpose %924, %4 : (tensor<1x197x12x64xf32>, tensor<4xi64>) -> tensor<1x12x197x64xf32>
#     %926 = tosa.reshape %925 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
#     %927 = tosa.transpose %global47, %8 : (tensor<12x197x64xf32>, tensor<3xi32>) -> tensor<12x64x197xf32>
#     %928 = tosa.matmul %926, %927 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
#     %929 = tosa.transpose %global55, %8 : (tensor<12x197x197xf32>, tensor<3xi32>) -> tensor<12x197x197xf32>
#     %930 = tosa.matmul %929, %926 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %931 = tosa.mul %global54, %928 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %932 = tosa.mul %global52, %928 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %933 = tosa.reduce_sum %932 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
#     %934 = tosa.mul %global53, %global53 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %935 = tosa.negate %934 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %936 = tosa.reciprocal %935 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %937 = tosa.mul %936, %933 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
#     %938 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%937 : tensor<12x197x1xf32>) outs(%cst_0 : tensor<12x197x197xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<12x197x197xf32>
#     %939 = tosa.add %931, %938 : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %940 = tosa.mul %global52, %939 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %941 = tosa.mul %global50, %940 {shift = 0 : i8} : (tensor<f32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
#     %942 = tosa.transpose %global48, %8 : (tensor<12x64x197xf32>, tensor<3xi32>) -> tensor<12x197x64xf32>
#     %943 = tosa.matmul %941, %942 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %944 = tosa.add %930, %943 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %945 = tosa.matmul %927, %941 : (tensor<12x64x197xf32>, tensor<12x197x197xf32>) -> tensor<12x64x197xf32>
#     %946 = tosa.transpose %945, %3 : (tensor<12x64x197xf32>, tensor<3xi64>) -> tensor<12x197x64xf32>
#     %947 = tosa.add %944, %946 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
#     %948 = tosa.reshape %947 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
#     %949 = tosa.transpose %948, %4 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
#     %950 = tosa.reshape %949 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
#     %951 = tosa.matmul %950, %64 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
#     %952 = tosa.mul %global2, %951 {shift = 0 : i8} : (tensor<768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %953 = tosa.mul %global39, %952 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %954 = tosa.mul %global34, %952 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %955 = tosa.reduce_sum %954 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %956 = tosa.pow %global38, %6 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %957 = tosa.mul %956, %7 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
#     %958 = tosa.mul %957, %955 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %959 = tosa.mul %global8, %958 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %960 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%959 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %961 = tosa.mul %global34, %960 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %962 = tosa.add %953, %961 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %963 = tosa.add %962, %961 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %964 = tosa.add %922, %963 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %965 = tosa.negate %963 : (tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %966 = tosa.reduce_sum %965 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
#     %967 = tosa.mul %global8, %966 {shift = 0 : i8} : (tensor<f32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
#     %968 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%967 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
#     ^bb0(%in: f32, %out: f32):
#       linalg.yield %in : f32
#     } -> tensor<1x197x768xf32>
#     %969 = tosa.add %964, %968 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
#     %extracted_slice = tensor.extract_slice %969[0, 1, 0] [1, 196, 768] [1, 1, 1] : tensor<1x197x768xf32> to tensor<1x196x768xf32>
#     %970 = tosa.transpose %extracted_slice, %3 : (tensor<1x196x768xf32>, tensor<3xi64>) -> tensor<1x768x196xf32>
#     %971 = tosa.reshape %970 {new_shape = array<i64: 1, 768, 14, 14>} : (tensor<1x768x196xf32>) -> tensor<1x768x14x14xf32>
#     %972 = tosa.transpose %971, %2 : (tensor<1x768x14x14xf32>, tensor<4xi64>) -> tensor<1x14x14x768xf32>
#     %973 = tosa.transpose %global1, %1 : (tensor<768x16x16x3xf32>, tensor<4xi64>) -> tensor<3x16x16x768xf32>
#     %974 = tosa.transpose_conv2d %972, %973, %cst {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 16, 16>} : (tensor<1x14x14x768xf32>, tensor<3x16x16x768xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
#     %975 = tosa.transpose %974, %0 : (tensor<1x224x224x3xf32>, tensor<4xi64>) -> tensor<1x3x224x224xf32>
#     return %975 : tensor<1x3x224x224xf32>
#   }
# }

# %%
# !ragdoll-opt --help | grep const
# Out:
#       --convert-scf-to-openmp                                -   Convert SCF parallel loop to OpenMP parallel + workshare constructs.
#       --convert-shape-constraints                            -   Convert shape constraint operations to the standard dialect
#       --expand-strided-metadata                              -   Expand memref operations into easier to analyze constructs
#       --remove-shape-constraints                             -   Replace all cstr_ ops with a true witness
#       --tosa-layerwise-constant-fold                         -   Fold layerwise operations on constant tensors
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimizationMay add more tosa.const but would reduce runtime calculations
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimization
