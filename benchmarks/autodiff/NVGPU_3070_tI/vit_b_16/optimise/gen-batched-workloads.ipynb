# %%
model_file = "vit.mlir"
#batch_size = 2
#for bs in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
#for bs in [1, 2, 4, 8, 16, 18, 20, 22, 24, 26, 28, 30, 32, 64, 128, 256, 512, 1024]:
for bs in [34, 36, 38, 40, 42, 44, 46, 48]:
    # !ragdoll-opt {model_file} --ragdoll-autodiff-prepare-batch-size=batchsize={bs} > {model_file}.bs{bs}
#!cat {model_file}.bs2
