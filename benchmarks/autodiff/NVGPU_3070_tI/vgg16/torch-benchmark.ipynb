# %% [markdown]
# # AlexNet Benchmark
#
# use PY310, py311 not support torch.compile, py39 not support libnvrtc.so compatibility

# %%
model_name = "vgg16-torch"

import torch
from torch import nn
from torchvision import models
#import torch_mlir
import numpy as np
import iree
import iree.compiler
import iree.runtime

import warnings
warnings.filterwarnings("ignore")

from timeit import timeit as ti
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from ragdoll.compiler import *
from ragdoll.benchmark import *
import ragdoll

# %%
    
def get_dataframe(forward, backward, item):
    return pd.concat([
        pd.DataFrame({
            "time": forward,
            "pass": "Forward",
            "item": item
        }, index=[0]),
        pd.DataFrame({
            "time": backward,
            "pass": "Backward",
            "item": item
        }, index=[0]),
        pd.DataFrame({
            "time": forward + backward,
            "pass": "Full",
            "item": item
        }, index=[0]),
    ])

def timeit(stmt, n=3):
    return ti(stmt, globals=globals(), number=n) * 1000 / n

# %% [markdown]
# ## Experimental

# %%
import torch
from torch import nn
from torchvision import models
import pandas as pd

MAGIC_NUM = 7777e-5

device = torch.device("cuda:0")
model = models.vgg16().train(False)
model.load_state_dict({k: torch.ones_like(v) * MAGIC_NUM for k, v in model.state_dict().items()})
model = model.to(device)

# %% [markdown]
# ### PyTorch (Baseline)

# %%
image = torch.randn(1, 3, 224, 224, requires_grad=True)
image = image.to(device)
output = model(image)
grad = torch.randn_like(output)

df = pd.DataFrame()
"""
baseline_f = torch_model_benchmark(model, 
                                 [image], 
                                 device='gpu',
                                 warmups=0,
                                 repetitions=33, 
                                 measure_count=11)
print('torch-native-gpu-forward: ', baseline_f)
baseline_f = np.mean(baseline_f)
print(baseline_f)

baseline_b = torch_model_benchmark(torch.autograd.grad, 
                                 [output, [image], grad], 
                                 device='gpu',
                                 warmups=0,
                                 repetitions=33, 
                                 measure_count=11)
                                 """
baseline_f = timeit("model(image)")
baseline_b = timeit("torch.autograd.grad(output, [image], grad, retain_graph=True)")
print('torch-native-gpu-backward: ', baseline_b)
baseline_b = np.mean(baseline_b)
print(baseline_b)
df = pd.concat([df, get_dataframe(baseline_f, baseline_b, "Torch Native")])
print(df)
# Out:
# torch-native-gpu-backward:  11.275755862394968
# 11.275755862394968
#         time      pass          item
# 0   1.178478   Forward  Torch Native
# 0  11.275756  Backward  Torch Native
# 0  12.454233      Full  Torch Native

# %%
model_dynamo = torch.compile(model, backend="inductor")

image = torch.randn(1, 3, 224, 224, requires_grad=True)
image = image.to(device)

output = model_dynamo(image)
grad = torch.randn_like(output)

image_np = image.detach().cpu().numpy()
grad_np = grad.cpu().numpy()
baseline_f = timeit("model_dynamo(image.to(device))", 7)
#_ = timeit("torch.autograd.grad(output.to(device), [image.to(device)], grad.to(device), retain_graph=True)", 1)
baseline_b = timeit("torch.autograd.grad(output.to(device), [image.to(device)], grad.to(device), retain_graph=True)", 111)
"""
baseline_f = torch_model_benchmark(model_dynamo, 
                                 [image], 
                                 device='gpu',
                                 warmups=0,
                                 repetitions=33, 
                                 measure_count=11)
print('torch-dynamo-gpu-forward: ', baseline_f)
baseline_f = np.mean(baseline_f)
print(baseline_f)

baseline_b = torch_model_benchmark(torch.autograd.grad, 
                                 [output, [image], grad], 
                                 device='gpu',
                                 warmups=0,
                                 repetitions=33, 
                                 measure_count=11)
print('torch-dynamo-gpu-backward: ', baseline_b)
baseline_b = np.mean(baseline_b)
print(baseline_b)
"""
df = pd.concat([df, get_dataframe(baseline_f, baseline_b, "Torch Dynamo")])
print(df)
# Out:
#         time      pass          item
# 0   1.178478   Forward  Torch Native
# 0  11.275756  Backward  Torch Native
# 0  12.454233      Full  Torch Native
# 0   2.529378   Forward  Torch Dynamo
# 0   3.856985  Backward  Torch Dynamo
# 0   6.386363      Full  Torch Dynamo
# 0   2.532166   Forward  Torch Dynamo
# 0   8.902170  Backward  Torch Dynamo
# 0  11.434336      Full  Torch Dynamo
# 0   0.842542   Forward  Torch Dynamo
# 0   8.579425  Backward  Torch Dynamo
# 0   9.421966      Full  Torch Dynamo

# %%
df.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6671a">
#   <thead>
#     <tr>
#       <th id="T_6671a_level0_col0" class="col_heading level0 col0" >time</th>
#       <th id="T_6671a_level0_col1" class="col_heading level0 col1" >pass</th>
#       <th id="T_6671a_level0_col2" class="col_heading level0 col2" >item</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6671a_row0_col0" class="data row0 col0" >1.160273</td>
#       <td id="T_6671a_row0_col1" class="data row0 col1" >Forward</td>
#       <td id="T_6671a_row0_col2" class="data row0 col2" >Torch Native</td>
#     </tr>
#     <tr>
#       <td id="T_6671a_row1_col0" class="data row1 col0" >11.218379</td>
#       <td id="T_6671a_row1_col1" class="data row1 col1" >Backward</td>
#       <td id="T_6671a_row1_col2" class="data row1 col2" >Torch Native</td>
#     </tr>
#     <tr>
#       <td id="T_6671a_row2_col0" class="data row2 col0" >12.378652</td>
#       <td id="T_6671a_row2_col1" class="data row2 col1" >Full</td>
#       <td id="T_6671a_row2_col2" class="data row2 col2" >Torch Native</td>
#     </tr>
#     <tr>
#       <td id="T_6671a_row3_col0" class="data row3 col0" >2.528637</td>
#       <td id="T_6671a_row3_col1" class="data row3 col1" >Forward</td>
#       <td id="T_6671a_row3_col2" class="data row3 col2" >Torch Dynamo</td>
#     </tr>
#     <tr>
#       <td id="T_6671a_row4_col0" class="data row4 col0" >3.856496</td>
#       <td id="T_6671a_row4_col1" class="data row4 col1" >Backward</td>
#       <td id="T_6671a_row4_col2" class="data row4 col2" >Torch Dynamo</td>
#     </tr>
#     <tr>
#       <td id="T_6671a_row5_col0" class="data row5 col0" >6.385133</td>
#       <td id="T_6671a_row5_col1" class="data row5 col1" >Full</td>
#       <td id="T_6671a_row5_col2" class="data row5 col2" >Torch Dynamo</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.rcParams["figure.dpi"] = 300

sns.barplot(df, x="pass", y="time", hue="item")
plt.xlabel("Pass")
plt.ylabel("Time Normalized (ms)")
plt.legend().set_title("Item")
plt.title(model_name)

plt.savefig(f"{model_name}-time.png")

# %%
forward = df[df["pass"] == "Forward"]
forward["acceleration"] = baseline_f / forward["time"]
forward
# Out:
#        time     pass          item  acceleration
# 0  1.160273  Forward  Torch Native      2.179346
# 0  2.528637  Forward  Torch Dynamo      1.000000

# %%
backward = df[df["pass"] == "Backward"]
backward["acceleration"] = baseline_b / backward["time"]
backward
# Out:
#        time      pass          item  acceleration
# 0  4.927272  Backward  Torch Native      1.805917
# 0  8.898246  Backward  Torch Dynamo      1.000000

# %%
full = df[df["pass"] == "Full"]
full["acceleration"] = (baseline_b + baseline_f) / full["time"]
full
# Out:
#         time  pass          item  acceleration
# 0   9.657331  Full  Torch Native      1.392624
# 0  13.449035  Full  Torch Dynamo      1.000000

# %%
df = pd.concat([forward, backward, full])
df.to_csv(f"{model_name}.csv")

sns.barplot(df, x="pass", y="acceleration", hue="item")
plt.xlabel("Pass")
plt.ylabel("Acceleration")
plt.legend().set_title("Item")
plt.title(model_name)

plt.savefig(f"{model_name}-acceleration.png")
