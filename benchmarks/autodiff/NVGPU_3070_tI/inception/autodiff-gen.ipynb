# %%
model_file = "inception.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
target_file = model_file + ".heuristic"
#!./convert_v0_to_v1.sh {model_file}
# !ragdoll-opt {model_file} --ragdoll-identical-transpose-removal > {model_file}.tmp
#!cat {model_file}.tmp

# !mv {model_file}.tmp {model_file}

# %%
model_file = "inception.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"
target_file = model_file + ".recompute"
# !ragdoll-opt {model_file}  \
--canonicalize \
--enable-cse-in-legalizer \
--symbol-dce \
--ragdoll-autodiff-vjp-public-functions='strategy=recompute' \
--ragdoll-autodiff-vjp \
--inline \
--ragdoll-autodiff-inline-function-call \
--ragdoll-initialisation \
--eliminate-empty-tensors \
--ragdoll-legalise-to-iree-compatibility \
--ragdoll-raise-linalg-to-tosa \
--canonicalize \
--cse > {target_file}

# %%
# !cat {target_file}
# Out:
# #map = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 + d4, d2 + d5, d3)>
# #map1 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d4, d5)>
# #map2 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1, d2, d3)>
# #map3 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 * 2 + d4, d2 * 2 + d5, d3)>
# module {
#   ml_program.global private mutable @global0(dense<1.000000e+00> : tensor<1x3x224x224xf32>) : tensor<1x3x224x224xf32>
#   func.func @forward(%arg0: tensor<1x3x224x224xf32>) -> tensor<1x1000xf32> {
#     %0 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1000xf32>}> : () -> tensor<1000xf32>
#     %1 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x2048x1000xf32>}> : () -> tensor<1x2048x1000xf32>
#     %2 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<f32>}> : () -> tensor<f32>
#     %3 = "tosa.const"() <{value = dense<"..."> : tensor<1x2048x1x1xi1>}> : () -> tensor<1x2048x1x1xi1>
#     %4 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x1x2048xf32>}> : () -> tensor<192x1x1x2048xf32>
#     %5 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<448x1x1x2048xf32>}> : () -> tensor<448x1x1x2048xf32>
#     %6 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x1x1x2048xf32>}> : () -> tensor<384x1x1x2048xf32>
#     %7 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<320x1x1x2048xf32>}> : () -> tensor<320x1x1x2048xf32>
#     %8 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x1x1280xf32>}> : () -> tensor<192x1x1x1280xf32>
#     %9 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x3x3x448xf32>}> : () -> tensor<384x3x3x448xf32>
#     %10 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x448x1x1xf32>}> : () -> tensor<1x448x1x1xf32>
#     %11 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<448xf32>}> : () -> tensor<448xf32>
#     %12 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<448x1x1x1280xf32>}> : () -> tensor<448x1x1x1280xf32>
#     %13 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x3x1x384xf32>}> : () -> tensor<384x3x1x384xf32>
#     %14 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x1x3x384xf32>}> : () -> tensor<384x1x3x384xf32>
#     %15 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x1x1x1280xf32>}> : () -> tensor<384x1x1x1280xf32>
#     %16 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<320x1x1x1280xf32>}> : () -> tensor<320x1x1x1280xf32>
#     %17 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x3x3x192xf32>}> : () -> tensor<192x3x3x192xf32>
#     %18 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x320x1x1xf32>}> : () -> tensor<1x320x1x1xf32>
#     %19 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<320xf32>}> : () -> tensor<320xf32>
#     %20 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<320x3x3x192xf32>}> : () -> tensor<320x3x3x192xf32>
#     %21 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x7x1x192xf32>}> : () -> tensor<192x7x1x192xf32>
#     %22 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x7x192xf32>}> : () -> tensor<192x1x7x192xf32>
#     %23 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x7x160xf32>}> : () -> tensor<192x1x7x160xf32>
#     %24 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<160x7x1x160xf32>}> : () -> tensor<160x7x1x160xf32>
#     %25 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x7x1x160xf32>}> : () -> tensor<192x7x1x160xf32>
#     %26 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<160x1x7x160xf32>}> : () -> tensor<160x1x7x160xf32>
#     %27 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x160x1x1xf32>}> : () -> tensor<1x160x1x1xf32>
#     %28 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<160xf32>}> : () -> tensor<160xf32>
#     %29 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<160x1x1x768xf32>}> : () -> tensor<160x1x1x768xf32>
#     %30 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x7x128xf32>}> : () -> tensor<192x1x7x128xf32>
#     %31 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x7x1x128xf32>}> : () -> tensor<128x7x1x128xf32>
#     %32 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x7x1x128xf32>}> : () -> tensor<192x7x1x128xf32>
#     %33 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x7x128xf32>}> : () -> tensor<128x1x7x128xf32>
#     %34 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x128x1x1xf32>}> : () -> tensor<1x128x1x1xf32>
#     %35 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<128xf32>}> : () -> tensor<128xf32>
#     %36 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x768xf32>}> : () -> tensor<128x1x1x768xf32>
#     %37 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x1x1x768xf32>}> : () -> tensor<192x1x1x768xf32>
#     %38 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x384x1x1xf32>}> : () -> tensor<1x384x1x1xf32>
#     %39 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<384xf32>}> : () -> tensor<384xf32>
#     %40 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<384x3x3x288xf32>}> : () -> tensor<384x3x3x288xf32>
#     %41 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<48x1x1x288xf32>}> : () -> tensor<48x1x1x288xf32>
#     %42 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x1x1x288xf32>}> : () -> tensor<64x1x1x288xf32>
#     %43 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<48x1x1x256xf32>}> : () -> tensor<48x1x1x256xf32>
#     %44 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x1x1x256xf32>}> : () -> tensor<64x1x1x256xf32>
#     %45 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<32x1x1x192xf32>}> : () -> tensor<32x1x1x192xf32>
#     %46 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<96x3x3x96xf32>}> : () -> tensor<96x3x3x96xf32>
#     %47 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x96x1x1xf32>}> : () -> tensor<1x96x1x1xf32>
#     %48 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<96xf32>}> : () -> tensor<96xf32>
#     %49 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<96x3x3x64xf32>}> : () -> tensor<96x3x3x64xf32>
#     %50 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x5x5x48xf32>}> : () -> tensor<64x5x5x48xf32>
#     %51 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x48x1x1xf32>}> : () -> tensor<1x48x1x1xf32>
#     %52 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<48xf32>}> : () -> tensor<48xf32>
#     %53 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<48x1x1x192xf32>}> : () -> tensor<48x1x1x192xf32>
#     %54 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x1x1x192xf32>}> : () -> tensor<64x1x1x192xf32>
#     %55 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x192x1x1xf32>}> : () -> tensor<1x192x1x1xf32>
#     %56 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<192xf32>}> : () -> tensor<192xf32>
#     %57 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<192x3x3x80xf32>}> : () -> tensor<192x3x3x80xf32>
#     %58 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x80x1x1xf32>}> : () -> tensor<1x80x1x1xf32>
#     %59 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<80xf32>}> : () -> tensor<80xf32>
#     %60 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<80x1x1x64xf32>}> : () -> tensor<80x1x1x64xf32>
#     %61 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x64x1x1xf32>}> : () -> tensor<1x64x1x1xf32>
#     %62 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<64xf32>}> : () -> tensor<64xf32>
#     %63 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x3x3x32xf32>}> : () -> tensor<64x3x3x32xf32>
#     %64 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<32x3x3x32xf32>}> : () -> tensor<32x3x3x32xf32>
#     %65 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x32x1x1xf32>}> : () -> tensor<1x32x1x1xf32>
#     %66 = "tosa.const"() <{value = dense<[0, 3, 1, 2]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %67 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<32xf32>}> : () -> tensor<32xf32>
#     %68 = "tosa.const"() <{value = dense<[0, 2, 3, 1]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %69 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<32x3x3x3xf32>}> : () -> tensor<32x3x3x3xf32>
#     %cst = arith.constant dense<0.000000e+00> : tensor<1x2048x5x5xf32>
#     %cst_0 = arith.constant dense<0.000000e+00> : tensor<1x768x5x5xf32>
#     %cst_1 = arith.constant dense<0.000000e+00> : tensor<1x1280x5x5xf32>
#     %cst_2 = arith.constant dense<0.000000e+00> : tensor<1x768x12x12xf32>
#     %cst_3 = arith.constant dense<0.000000e+00> : tensor<1x288x25x25xf32>
#     %cst_4 = arith.constant dense<0.000000e+00> : tensor<1x256x25x25xf32>
#     %70 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x32x1x1xf32>}> : () -> tensor<1x32x1x1xf32>
#     %71 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x64x1x1xf32>}> : () -> tensor<1x64x1x1xf32>
#     %72 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x80x1x1xf32>}> : () -> tensor<1x80x1x1xf32>
#     %73 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x192x1x1xf32>}> : () -> tensor<1x192x1x1xf32>
#     %74 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x48x1x1xf32>}> : () -> tensor<1x48x1x1xf32>
#     %75 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x96x1x1xf32>}> : () -> tensor<1x96x1x1xf32>
#     %76 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x384x1x1xf32>}> : () -> tensor<1x384x1x1xf32>
#     %77 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x128x1x1xf32>}> : () -> tensor<1x128x1x1xf32>
#     %78 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x160x1x1xf32>}> : () -> tensor<1x160x1x1xf32>
#     %79 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x320x1x1xf32>}> : () -> tensor<1x320x1x1xf32>
#     %80 = "tosa.const"() <{value = dense<0.0787700042> : tensor<1x448x1x1xf32>}> : () -> tensor<1x448x1x1xf32>
#     ml_program.global_store @global0 = %arg0 : tensor<1x3x224x224xf32>
#     %81 = tosa.transpose %arg0, %68 : (tensor<1x3x224x224xf32>, tensor<4xi64>) -> tensor<1x224x224x3xf32>
#     %82 = tosa.conv2d %81, %69, %67 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x224x224x3xf32>, tensor<32x3x3x3xf32>, tensor<32xf32>) -> tensor<1x111x111x32xf32>
#     %83 = tosa.transpose %82, %66 : (tensor<1x111x111x32xf32>, tensor<4xi64>) -> tensor<1x32x111x111xf32>
#     %84 = tosa.sub %83, %65 : (tensor<1x32x111x111xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x111x111xf32>
#     %85 = tosa.rsqrt %70 : (tensor<1x32x1x1xf32>) -> tensor<1x32x1x1xf32>
#     %86 = tosa.mul %84, %85 {shift = 0 : i8} : (tensor<1x32x111x111xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x111x111xf32>
#     %87 = tosa.mul %86, %65 {shift = 0 : i8} : (tensor<1x32x111x111xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x111x111xf32>
#     %88 = tosa.add %87, %65 : (tensor<1x32x111x111xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x111x111xf32>
#     %89 = tosa.clamp %88 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x32x111x111xf32>) -> tensor<1x32x111x111xf32>
#     %90 = tosa.transpose %89, %68 : (tensor<1x32x111x111xf32>, tensor<4xi64>) -> tensor<1x111x111x32xf32>
#     %91 = tosa.conv2d %90, %64, %67 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x111x111x32xf32>, tensor<32x3x3x32xf32>, tensor<32xf32>) -> tensor<1x109x109x32xf32>
#     %92 = tosa.transpose %91, %66 : (tensor<1x109x109x32xf32>, tensor<4xi64>) -> tensor<1x32x109x109xf32>
#     %93 = tosa.sub %92, %65 : (tensor<1x32x109x109xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x109x109xf32>
#     %94 = tosa.mul %93, %85 {shift = 0 : i8} : (tensor<1x32x109x109xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x109x109xf32>
#     %95 = tosa.mul %94, %65 {shift = 0 : i8} : (tensor<1x32x109x109xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x109x109xf32>
#     %96 = tosa.add %95, %65 : (tensor<1x32x109x109xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x109x109xf32>
#     %97 = tosa.clamp %96 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x32x109x109xf32>) -> tensor<1x32x109x109xf32>
#     %98 = tosa.transpose %97, %68 : (tensor<1x32x109x109xf32>, tensor<4xi64>) -> tensor<1x109x109x32xf32>
#     %99 = tosa.conv2d %98, %63, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x109x109x32xf32>, tensor<64x3x3x32xf32>, tensor<64xf32>) -> tensor<1x109x109x64xf32>
#     %100 = tosa.transpose %99, %66 : (tensor<1x109x109x64xf32>, tensor<4xi64>) -> tensor<1x64x109x109xf32>
#     %101 = tosa.sub %100, %61 : (tensor<1x64x109x109xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x109x109xf32>
#     %102 = tosa.rsqrt %71 : (tensor<1x64x1x1xf32>) -> tensor<1x64x1x1xf32>
#     %103 = tosa.mul %101, %102 {shift = 0 : i8} : (tensor<1x64x109x109xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x109x109xf32>
#     %104 = tosa.mul %103, %61 {shift = 0 : i8} : (tensor<1x64x109x109xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x109x109xf32>
#     %105 = tosa.add %104, %61 : (tensor<1x64x109x109xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x109x109xf32>
#     %106 = tosa.clamp %105 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x109x109xf32>) -> tensor<1x64x109x109xf32>
#     %107 = tosa.transpose %106, %68 : (tensor<1x64x109x109xf32>, tensor<4xi64>) -> tensor<1x109x109x64xf32>
#     %108 = tosa.max_pool2d %107 {kernel = array<i64: 3, 3>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x109x109x64xf32>) -> tensor<1x54x54x64xf32>
#     %109 = tosa.conv2d %108, %60, %59 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x54x54x64xf32>, tensor<80x1x1x64xf32>, tensor<80xf32>) -> tensor<1x54x54x80xf32>
#     %110 = tosa.transpose %109, %66 : (tensor<1x54x54x80xf32>, tensor<4xi64>) -> tensor<1x80x54x54xf32>
#     %111 = tosa.sub %110, %58 : (tensor<1x80x54x54xf32>, tensor<1x80x1x1xf32>) -> tensor<1x80x54x54xf32>
#     %112 = tosa.rsqrt %72 : (tensor<1x80x1x1xf32>) -> tensor<1x80x1x1xf32>
#     %113 = tosa.mul %111, %112 {shift = 0 : i8} : (tensor<1x80x54x54xf32>, tensor<1x80x1x1xf32>) -> tensor<1x80x54x54xf32>
#     %114 = tosa.mul %113, %58 {shift = 0 : i8} : (tensor<1x80x54x54xf32>, tensor<1x80x1x1xf32>) -> tensor<1x80x54x54xf32>
#     %115 = tosa.add %114, %58 : (tensor<1x80x54x54xf32>, tensor<1x80x1x1xf32>) -> tensor<1x80x54x54xf32>
#     %116 = tosa.clamp %115 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x80x54x54xf32>) -> tensor<1x80x54x54xf32>
#     %117 = tosa.transpose %116, %68 : (tensor<1x80x54x54xf32>, tensor<4xi64>) -> tensor<1x54x54x80xf32>
#     %118 = tosa.conv2d %117, %57, %56 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x54x54x80xf32>, tensor<192x3x3x80xf32>, tensor<192xf32>) -> tensor<1x52x52x192xf32>
#     %119 = tosa.transpose %118, %66 : (tensor<1x52x52x192xf32>, tensor<4xi64>) -> tensor<1x192x52x52xf32>
#     %120 = tosa.sub %119, %55 : (tensor<1x192x52x52xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x52x52xf32>
#     %121 = tosa.rsqrt %73 : (tensor<1x192x1x1xf32>) -> tensor<1x192x1x1xf32>
#     %122 = tosa.mul %120, %121 {shift = 0 : i8} : (tensor<1x192x52x52xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x52x52xf32>
#     %123 = tosa.mul %122, %55 {shift = 0 : i8} : (tensor<1x192x52x52xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x52x52xf32>
#     %124 = tosa.add %123, %55 : (tensor<1x192x52x52xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x52x52xf32>
#     %125 = tosa.clamp %124 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x192x52x52xf32>) -> tensor<1x192x52x52xf32>
#     %126 = tosa.transpose %125, %68 : (tensor<1x192x52x52xf32>, tensor<4xi64>) -> tensor<1x52x52x192xf32>
#     %127 = tosa.max_pool2d %126 {kernel = array<i64: 3, 3>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x52x52x192xf32>) -> tensor<1x25x25x192xf32>
#     %128 = tosa.conv2d %127, %54, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x192xf32>, tensor<64x1x1x192xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %129 = tosa.transpose %128, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %130 = tosa.sub %129, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %131 = tosa.mul %130, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %132 = tosa.mul %131, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %133 = tosa.add %132, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %134 = tosa.clamp %133 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %135 = tosa.conv2d %127, %53, %52 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x192xf32>, tensor<48x1x1x192xf32>, tensor<48xf32>) -> tensor<1x25x25x48xf32>
#     %136 = tosa.transpose %135, %66 : (tensor<1x25x25x48xf32>, tensor<4xi64>) -> tensor<1x48x25x25xf32>
#     %137 = tosa.sub %136, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %138 = tosa.rsqrt %74 : (tensor<1x48x1x1xf32>) -> tensor<1x48x1x1xf32>
#     %139 = tosa.mul %137, %138 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %140 = tosa.mul %139, %51 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %141 = tosa.add %140, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %142 = tosa.clamp %141 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xf32>
#     %143 = tosa.transpose %142, %68 : (tensor<1x48x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x48xf32>
#     %144 = tosa.conv2d %143, %50, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 2, 2, 2, 2>, stride = array<i64: 1, 1>} : (tensor<1x25x25x48xf32>, tensor<64x5x5x48xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %145 = tosa.transpose %144, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %146 = tosa.sub %145, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %147 = tosa.mul %146, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %148 = tosa.mul %147, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %149 = tosa.add %148, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %150 = tosa.clamp %149 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %151 = tosa.transpose %134, %68 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %152 = tosa.conv2d %151, %49, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<96x3x3x64xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %153 = tosa.transpose %152, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %154 = tosa.sub %153, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %155 = tosa.rsqrt %75 : (tensor<1x96x1x1xf32>) -> tensor<1x96x1x1xf32>
#     %156 = tosa.mul %154, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %157 = tosa.mul %156, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %158 = tosa.add %157, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %159 = tosa.clamp %158 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %160 = tosa.transpose %159, %68 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %161 = tosa.conv2d %160, %46, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x96xf32>, tensor<96x3x3x96xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %162 = tosa.transpose %161, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %163 = tosa.sub %162, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %164 = tosa.mul %163, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %165 = tosa.mul %164, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %166 = tosa.add %165, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %167 = tosa.clamp %166 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %168 = tosa.avg_pool2d %127 {acc_type = f32, kernel = array<i64: 3, 3>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x192xf32>) -> tensor<1x25x25x192xf32>
#     %169 = tosa.conv2d %168, %45, %67 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x192xf32>, tensor<32x1x1x192xf32>, tensor<32xf32>) -> tensor<1x25x25x32xf32>
#     %170 = tosa.transpose %169, %66 : (tensor<1x25x25x32xf32>, tensor<4xi64>) -> tensor<1x32x25x25xf32>
#     %171 = tosa.sub %170, %65 : (tensor<1x32x25x25xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x25x25xf32>
#     %172 = tosa.mul %171, %85 {shift = 0 : i8} : (tensor<1x32x25x25xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x25x25xf32>
#     %173 = tosa.mul %172, %65 {shift = 0 : i8} : (tensor<1x32x25x25xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x25x25xf32>
#     %174 = tosa.add %173, %65 : (tensor<1x32x25x25xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x25x25xf32>
#     %175 = tosa.clamp %174 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x32x25x25xf32>) -> tensor<1x32x25x25xf32>
#     %inserted_slice = tensor.insert_slice %134 into %cst_4[0, 0, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x256x25x25xf32>
#     %inserted_slice_5 = tensor.insert_slice %150 into %inserted_slice[0, 64, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x256x25x25xf32>
#     %inserted_slice_6 = tensor.insert_slice %167 into %inserted_slice_5[0, 128, 0, 0] [1, 96, 25, 25] [1, 1, 1, 1] : tensor<1x96x25x25xf32> into tensor<1x256x25x25xf32>
#     %inserted_slice_7 = tensor.insert_slice %175 into %inserted_slice_6[0, 224, 0, 0] [1, 32, 25, 25] [1, 1, 1, 1] : tensor<1x32x25x25xf32> into tensor<1x256x25x25xf32>
#     %176 = tosa.transpose %inserted_slice_7, %68 : (tensor<1x256x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x256xf32>
#     %177 = tosa.conv2d %176, %44, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %178 = tosa.transpose %177, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %179 = tosa.sub %178, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %180 = tosa.mul %179, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %181 = tosa.mul %180, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %182 = tosa.add %181, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %183 = tosa.clamp %182 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %184 = tosa.conv2d %176, %43, %52 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x256xf32>, tensor<48x1x1x256xf32>, tensor<48xf32>) -> tensor<1x25x25x48xf32>
#     %185 = tosa.transpose %184, %66 : (tensor<1x25x25x48xf32>, tensor<4xi64>) -> tensor<1x48x25x25xf32>
#     %186 = tosa.sub %185, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %187 = tosa.mul %186, %138 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %188 = tosa.mul %187, %51 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %189 = tosa.add %188, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %190 = tosa.clamp %189 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xf32>
#     %191 = tosa.transpose %190, %68 : (tensor<1x48x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x48xf32>
#     %192 = tosa.conv2d %191, %50, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 2, 2, 2, 2>, stride = array<i64: 1, 1>} : (tensor<1x25x25x48xf32>, tensor<64x5x5x48xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %193 = tosa.transpose %192, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %194 = tosa.sub %193, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %195 = tosa.mul %194, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %196 = tosa.mul %195, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %197 = tosa.add %196, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %198 = tosa.clamp %197 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %199 = tosa.transpose %183, %68 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %200 = tosa.conv2d %199, %49, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<96x3x3x64xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %201 = tosa.transpose %200, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %202 = tosa.sub %201, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %203 = tosa.mul %202, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %204 = tosa.mul %203, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %205 = tosa.add %204, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %206 = tosa.clamp %205 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %207 = tosa.transpose %206, %68 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %208 = tosa.conv2d %207, %46, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x96xf32>, tensor<96x3x3x96xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %209 = tosa.transpose %208, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %210 = tosa.sub %209, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %211 = tosa.mul %210, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %212 = tosa.mul %211, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %213 = tosa.add %212, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %214 = tosa.clamp %213 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %215 = tosa.avg_pool2d %176 {acc_type = f32, kernel = array<i64: 3, 3>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x256xf32>) -> tensor<1x25x25x256xf32>
#     %216 = tosa.conv2d %215, %44, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x256xf32>, tensor<64x1x1x256xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %217 = tosa.transpose %216, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %218 = tosa.sub %217, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %219 = tosa.mul %218, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %220 = tosa.mul %219, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %221 = tosa.add %220, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %222 = tosa.clamp %221 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %inserted_slice_8 = tensor.insert_slice %183 into %cst_3[0, 0, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_9 = tensor.insert_slice %198 into %inserted_slice_8[0, 64, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_10 = tensor.insert_slice %214 into %inserted_slice_9[0, 128, 0, 0] [1, 96, 25, 25] [1, 1, 1, 1] : tensor<1x96x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_11 = tensor.insert_slice %222 into %inserted_slice_10[0, 224, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %223 = tosa.transpose %inserted_slice_11, %68 : (tensor<1x288x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x288xf32>
#     %224 = tosa.conv2d %223, %42, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x288xf32>, tensor<64x1x1x288xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %225 = tosa.transpose %224, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %226 = tosa.sub %225, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %227 = tosa.mul %226, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %228 = tosa.mul %227, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %229 = tosa.add %228, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %230 = tosa.clamp %229 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %231 = tosa.conv2d %223, %41, %52 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x288xf32>, tensor<48x1x1x288xf32>, tensor<48xf32>) -> tensor<1x25x25x48xf32>
#     %232 = tosa.transpose %231, %66 : (tensor<1x25x25x48xf32>, tensor<4xi64>) -> tensor<1x48x25x25xf32>
#     %233 = tosa.sub %232, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %234 = tosa.mul %233, %138 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %235 = tosa.mul %234, %51 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %236 = tosa.add %235, %51 : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %237 = tosa.clamp %236 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xf32>
#     %238 = tosa.transpose %237, %68 : (tensor<1x48x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x48xf32>
#     %239 = tosa.conv2d %238, %50, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 2, 2, 2, 2>, stride = array<i64: 1, 1>} : (tensor<1x25x25x48xf32>, tensor<64x5x5x48xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %240 = tosa.transpose %239, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %241 = tosa.sub %240, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %242 = tosa.mul %241, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %243 = tosa.mul %242, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %244 = tosa.add %243, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %245 = tosa.clamp %244 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %246 = tosa.transpose %230, %68 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %247 = tosa.conv2d %246, %49, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<96x3x3x64xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %248 = tosa.transpose %247, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %249 = tosa.sub %248, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %250 = tosa.mul %249, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %251 = tosa.mul %250, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %252 = tosa.add %251, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %253 = tosa.clamp %252 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %254 = tosa.transpose %253, %68 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %255 = tosa.conv2d %254, %46, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x96xf32>, tensor<96x3x3x96xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %256 = tosa.transpose %255, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %257 = tosa.sub %256, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %258 = tosa.mul %257, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %259 = tosa.mul %258, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %260 = tosa.add %259, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %261 = tosa.clamp %260 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %262 = tosa.avg_pool2d %223 {acc_type = f32, kernel = array<i64: 3, 3>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x288xf32>) -> tensor<1x25x25x288xf32>
#     %263 = tosa.conv2d %262, %42, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x288xf32>, tensor<64x1x1x288xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %264 = tosa.transpose %263, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %265 = tosa.sub %264, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %266 = tosa.mul %265, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %267 = tosa.mul %266, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %268 = tosa.add %267, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %269 = tosa.clamp %268 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %inserted_slice_12 = tensor.insert_slice %230 into %cst_3[0, 0, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_13 = tensor.insert_slice %245 into %inserted_slice_12[0, 64, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_14 = tensor.insert_slice %261 into %inserted_slice_13[0, 128, 0, 0] [1, 96, 25, 25] [1, 1, 1, 1] : tensor<1x96x25x25xf32> into tensor<1x288x25x25xf32>
#     %inserted_slice_15 = tensor.insert_slice %269 into %inserted_slice_14[0, 224, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x64x25x25xf32> into tensor<1x288x25x25xf32>
#     %270 = tosa.transpose %inserted_slice_15, %68 : (tensor<1x288x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x288xf32>
#     %271 = tosa.conv2d %270, %40, %39 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x25x25x288xf32>, tensor<384x3x3x288xf32>, tensor<384xf32>) -> tensor<1x12x12x384xf32>
#     %272 = tosa.transpose %271, %66 : (tensor<1x12x12x384xf32>, tensor<4xi64>) -> tensor<1x384x12x12xf32>
#     %273 = tosa.sub %272, %38 : (tensor<1x384x12x12xf32>, tensor<1x384x1x1xf32>) -> tensor<1x384x12x12xf32>
#     %274 = tosa.rsqrt %76 : (tensor<1x384x1x1xf32>) -> tensor<1x384x1x1xf32>
#     %275 = tosa.mul %273, %274 {shift = 0 : i8} : (tensor<1x384x12x12xf32>, tensor<1x384x1x1xf32>) -> tensor<1x384x12x12xf32>
#     %276 = tosa.mul %275, %38 {shift = 0 : i8} : (tensor<1x384x12x12xf32>, tensor<1x384x1x1xf32>) -> tensor<1x384x12x12xf32>
#     %277 = tosa.add %276, %38 : (tensor<1x384x12x12xf32>, tensor<1x384x1x1xf32>) -> tensor<1x384x12x12xf32>
#     %278 = tosa.clamp %277 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x384x12x12xf32>) -> tensor<1x384x12x12xf32>
#     %279 = tosa.conv2d %270, %42, %62 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x25x25x288xf32>, tensor<64x1x1x288xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %280 = tosa.transpose %279, %66 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %281 = tosa.sub %280, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %282 = tosa.mul %281, %102 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %283 = tosa.mul %282, %61 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %284 = tosa.add %283, %61 : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %285 = tosa.clamp %284 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %286 = tosa.transpose %285, %68 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %287 = tosa.conv2d %286, %49, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<96x3x3x64xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %288 = tosa.transpose %287, %66 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %289 = tosa.sub %288, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %290 = tosa.mul %289, %155 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %291 = tosa.mul %290, %47 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %292 = tosa.add %291, %47 : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %293 = tosa.clamp %292 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %294 = tosa.transpose %293, %68 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %295 = tosa.conv2d %294, %46, %48 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x25x25x96xf32>, tensor<96x3x3x96xf32>, tensor<96xf32>) -> tensor<1x12x12x96xf32>
#     %296 = tosa.transpose %295, %66 : (tensor<1x12x12x96xf32>, tensor<4xi64>) -> tensor<1x96x12x12xf32>
#     %297 = tosa.sub %296, %47 : (tensor<1x96x12x12xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x12x12xf32>
#     %298 = tosa.mul %297, %155 {shift = 0 : i8} : (tensor<1x96x12x12xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x12x12xf32>
#     %299 = tosa.mul %298, %47 {shift = 0 : i8} : (tensor<1x96x12x12xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x12x12xf32>
#     %300 = tosa.add %299, %47 : (tensor<1x96x12x12xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x12x12xf32>
#     %301 = tosa.clamp %300 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x12x12xf32>) -> tensor<1x96x12x12xf32>
#     %302 = tosa.max_pool2d %270 {kernel = array<i64: 3, 3>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 2, 2>} : (tensor<1x25x25x288xf32>) -> tensor<1x12x12x288xf32>
#     %303 = tosa.transpose %302, %66 : (tensor<1x12x12x288xf32>, tensor<4xi64>) -> tensor<1x288x12x12xf32>
#     %inserted_slice_16 = tensor.insert_slice %278 into %cst_2[0, 0, 0, 0] [1, 384, 12, 12] [1, 1, 1, 1] : tensor<1x384x12x12xf32> into tensor<1x768x12x12xf32>
#     %inserted_slice_17 = tensor.insert_slice %301 into %inserted_slice_16[0, 384, 0, 0] [1, 96, 12, 12] [1, 1, 1, 1] : tensor<1x96x12x12xf32> into tensor<1x768x12x12xf32>
#     %inserted_slice_18 = tensor.insert_slice %303 into %inserted_slice_17[0, 480, 0, 0] [1, 288, 12, 12] [1, 1, 1, 1] : tensor<1x288x12x12xf32> into tensor<1x768x12x12xf32>
#     %304 = tosa.transpose %inserted_slice_18, %68 : (tensor<1x768x12x12xf32>, tensor<4xi64>) -> tensor<1x12x12x768xf32>
#     %305 = tosa.conv2d %304, %37, %56 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x12x12x768xf32>, tensor<192x1x1x768xf32>, tensor<192xf32>) -> tensor<1x12x12x192xf32>
#     %306 = tosa.transpose %305, %66 : (tensor<1x12x12x192xf32>, tensor<4xi64>) -> tensor<1x192x12x12xf32>
#     %307 = tosa.sub %306, %55 : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %308 = tosa.mul %307, %121 {shift = 0 : i8} : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %309 = tosa.mul %308, %55 {shift = 0 : i8} : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %310 = tosa.add %309, %55 : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %311 = tosa.clamp %310 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x192x12x12xf32>) -> tensor<1x192x12x12xf32>
#     %312 = tosa.conv2d %304, %36, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x12x12x768xf32>, tensor<128x1x1x768xf32>, tensor<128xf32>) -> tensor<1x12x12x128xf32>
#     %313 = tosa.transpose %312, %66 : (tensor<1x12x12x128xf32>, tensor<4xi64>) -> tensor<1x128x12x12xf32>
#     %314 = tosa.sub %313, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %315 = tosa.rsqrt %77 : (tensor<1x128x1x1xf32>) -> tensor<1x128x1x1xf32>
#     %316 = tosa.mul %314, %315 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %317 = tosa.mul %316, %34 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %318 = tosa.add %317, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %319 = tosa.clamp %318 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x12x12xf32>) -> tensor<1x128x12x12xf32>
#     %320 = tosa.transpose %319, %68 : (tensor<1x128x12x12xf32>, tensor<4xi64>) -> tensor<1x12x12x128xf32>
#     %321 = tosa.conv2d %320, %33, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 3, 3>, stride = array<i64: 1, 1>} : (tensor<1x12x12x128xf32>, tensor<128x1x7x128xf32>, tensor<128xf32>) -> tensor<1x12x12x128xf32>
#     %322 = tosa.transpose %321, %66 : (tensor<1x12x12x128xf32>, tensor<4xi64>) -> tensor<1x128x12x12xf32>
#     %323 = tosa.sub %322, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %324 = tosa.mul %323, %315 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %325 = tosa.mul %324, %34 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %326 = tosa.add %325, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %327 = tosa.clamp %326 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x12x12xf32>) -> tensor<1x128x12x12xf32>
#     %328 = tosa.transpose %327, %68 : (tensor<1x128x12x12xf32>, tensor<4xi64>) -> tensor<1x12x12x128xf32>
#     %329 = tosa.conv2d %328, %32, %56 {dilation = array<i64: 1, 1>, pad = array<i64: 3, 3, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x12x12x128xf32>, tensor<192x7x1x128xf32>, tensor<192xf32>) -> tensor<1x12x12x192xf32>
#     %330 = tosa.transpose %329, %66 : (tensor<1x12x12x192xf32>, tensor<4xi64>) -> tensor<1x192x12x12xf32>
#     %331 = tosa.sub %330, %55 : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %332 = tosa.mul %331, %121 {shift = 0 : i8} : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %333 = tosa.mul %332, %55 {shift = 0 : i8} : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %334 = tosa.add %333, %55 : (tensor<1x192x12x12xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x12x12xf32>
#     %335 = tosa.clamp %334 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x192x12x12xf32>) -> tensor<1x192x12x12xf32>
#     %336 = tosa.conv2d %320, %31, %35 {dilation = array<i64: 1, 1>, pad = array<i64: 3, 3, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x12x12x128xf32>, tensor<128x7x1x128xf32>, tensor<128xf32>) -> tensor<1x12x12x128xf32>
#     %337 = tosa.transpose %336, %66 : (tensor<1x12x12x128xf32>, tensor<4xi64>) -> tensor<1x128x12x12xf32>
#     %338 = tosa.sub %337, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %339 = tosa.mul %338, %315 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %340 = tosa.mul %339, %34 {shift = 0 : i8} : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %341 = tosa.add %340, %34 : (tensor<1x128x12x12xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x12x12xf32>
#     %342 = tosa.clamp %341 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x12x12xf32>) -> tensor<1x128x12x12xf32>
#     %343 = tosa.transpose %342, %68 : (tensor<1x128x12x12xf32>, tensor<4xi64>) -> tensor<1x12x12x128xf32>
# ...
#     %1314 = tosa.transpose_conv2d %1313, %10, %cst_7 {out_pad = array<i64: -2, -2, -2, -2>, out_shape = array<i64: 1, 25, 25, 48>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<48x5x5x64xf32>, tensor<48xf32>) -> tensor<1x25x25x48xf32>
#     %1315 = tosa.transpose %1314, %96 : (tensor<1x25x25x48xf32>, tensor<4xi64>) -> tensor<1x48x25x25xf32>
#     %1316 = tosa.equal %219, %220 : (tensor<1x48x25x25xf32>, tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xi1>
#     %1317 = tosa.select %1316, %1315, %31 : (tensor<1x48x25x25xi1>, tensor<1x48x25x25xf32>, tensor<f32>) -> tensor<1x48x25x25xf32>
#     %1318 = tosa.mul %1317, %81 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %1319 = tosa.mul %168, %1318 {shift = 0 : i8} : (tensor<1x48x1x1xf32>, tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xf32>
#     %1320 = tosa.transpose %1319, %98 : (tensor<1x48x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x48xf32>
#     %1321 = tosa.transpose_conv2d %1320, %7, %cst_6 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 25, 25, 256>, stride = array<i64: 1, 1>} : (tensor<1x25x25x48xf32>, tensor<256x1x1x48xf32>, tensor<256xf32>) -> tensor<1x25x25x256xf32>
#     %1322 = tosa.add %extracted_slice_145, %1321 : (tensor<1x25x25x256xf32>, tensor<1x25x25x256xf32>) -> tensor<1x25x25x256xf32>
#     %1323 = tosa.equal %212, %213 : (tensor<1x64x25x25xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xi1>
#     %1324 = tosa.select %1323, %1308, %31 : (tensor<1x64x25x25xi1>, tensor<1x64x25x25xf32>, tensor<f32>) -> tensor<1x64x25x25xf32>
#     %1325 = tosa.mul %1324, %91 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %1326 = tosa.mul %132, %1325 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %1327 = tosa.transpose %1326, %98 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %1328 = tosa.transpose_conv2d %1327, %8, %cst_6 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 25, 25, 256>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<256x1x1x64xf32>, tensor<256xf32>) -> tensor<1x25x25x256xf32>
#     %1329 = tosa.add %1322, %1328 : (tensor<1x25x25x256xf32>, tensor<1x25x25x256xf32>) -> tensor<1x25x25x256xf32>
#     %1330 = tosa.transpose %1329, %96 : (tensor<1x25x25x256xf32>, tensor<4xi64>) -> tensor<1x256x25x25xf32>
#     %extracted_slice_146 = tensor.extract_slice %1330[0, 224, 0, 0] [1, 32, 25, 25] [1, 1, 1, 1] : tensor<1x256x25x25xf32> to tensor<1x32x25x25xf32>
#     %extracted_slice_147 = tensor.extract_slice %1330[0, 128, 0, 0] [1, 96, 25, 25] [1, 1, 1, 1] : tensor<1x256x25x25xf32> to tensor<1x96x25x25xf32>
#     %extracted_slice_148 = tensor.extract_slice %1330[0, 64, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x256x25x25xf32> to tensor<1x64x25x25xf32>
#     %extracted_slice_149 = tensor.extract_slice %1330[0, 0, 0, 0] [1, 64, 25, 25] [1, 1, 1, 1] : tensor<1x256x25x25xf32> to tensor<1x64x25x25xf32>
#     %1331 = tosa.equal %204, %205 : (tensor<1x32x25x25xf32>, tensor<1x32x25x25xf32>) -> tensor<1x32x25x25xi1>
#     %1332 = tosa.select %1331, %extracted_slice_146, %31 : (tensor<1x32x25x25xi1>, tensor<1x32x25x25xf32>, tensor<f32>) -> tensor<1x32x25x25xf32>
#     %1333 = tosa.mul %1332, %95 {shift = 0 : i8} : (tensor<1x32x25x25xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x25x25xf32>
#     %1334 = tosa.mul %115, %1333 {shift = 0 : i8} : (tensor<1x32x1x1xf32>, tensor<1x32x25x25xf32>) -> tensor<1x32x25x25xf32>
#     %1335 = tosa.transpose %1334, %98 : (tensor<1x32x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x32xf32>
#     %1336 = tosa.transpose_conv2d %1335, %6, %cst_17 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 25, 25, 192>, stride = array<i64: 1, 1>} : (tensor<1x25x25x32xf32>, tensor<192x1x1x32xf32>, tensor<192xf32>) -> tensor<1x25x25x192xf32>
#     %padded_150 = tensor.pad %157 low[0, 1, 1, 0] high[0, 1, 1, 0] {
#     ^bb0(%arg1: index, %arg2: index, %arg3: index, %arg4: index):
#       tensor.yield %cst_29 : f32
#     } : tensor<1x25x25x192xf32> to tensor<1x27x27x192xf32>
#     %1337 = linalg.generic {indexing_maps = [#map, #map1, #map2, #map], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%padded_150, %cst_23, %1336 : tensor<1x27x27x192xf32>, tensor<3x3xf32>, tensor<1x25x25x192xf32>) outs(%cst_4 : tensor<1x27x27x192xf32>) {
#     ^bb0(%in: f32, %in_152: f32, %in_153: f32, %out: f32):
#       %1412 = arith.mulf %in_153, %cst_28 : f32
#       %1413 = arith.addf %1412, %out : f32
#       linalg.yield %1413 : f32
#     } -> tensor<1x27x27x192xf32>
#     %extracted_slice_151 = tensor.extract_slice %1337[0, 1, 1, 0] [1, 25, 25, 192] [1, 1, 1, 1] : tensor<1x27x27x192xf32> to tensor<1x25x25x192xf32>
#     %1338 = tosa.equal %196, %197 : (tensor<1x96x25x25xf32>, tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xi1>
#     %1339 = tosa.select %1338, %extracted_slice_147, %31 : (tensor<1x96x25x25xi1>, tensor<1x96x25x25xf32>, tensor<f32>) -> tensor<1x96x25x25xf32>
#     %1340 = tosa.mul %1339, %77 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %1341 = tosa.mul %185, %1340 {shift = 0 : i8} : (tensor<1x96x1x1xf32>, tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %1342 = tosa.transpose %1341, %98 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %1343 = tosa.transpose_conv2d %1342, %76, %cst_11 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 25, 25, 96>, stride = array<i64: 1, 1>} : (tensor<1x25x25x96xf32>, tensor<96x3x3x96xf32>, tensor<96xf32>) -> tensor<1x25x25x96xf32>
#     %1344 = tosa.transpose %1343, %96 : (tensor<1x25x25x96xf32>, tensor<4xi64>) -> tensor<1x96x25x25xf32>
#     %1345 = tosa.equal %188, %189 : (tensor<1x96x25x25xf32>, tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xi1>
#     %1346 = tosa.select %1345, %1344, %31 : (tensor<1x96x25x25xi1>, tensor<1x96x25x25xf32>, tensor<f32>) -> tensor<1x96x25x25xf32>
#     %1347 = tosa.mul %1346, %77 {shift = 0 : i8} : (tensor<1x96x25x25xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x25x25xf32>
#     %1348 = tosa.mul %185, %1347 {shift = 0 : i8} : (tensor<1x96x1x1xf32>, tensor<1x96x25x25xf32>) -> tensor<1x96x25x25xf32>
#     %1349 = tosa.transpose %1348, %98 : (tensor<1x96x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x96xf32>
#     %1350 = tosa.transpose_conv2d %1349, %13, %cst_10 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 25, 25, 64>, stride = array<i64: 1, 1>} : (tensor<1x25x25x96xf32>, tensor<64x3x3x96xf32>, tensor<64xf32>) -> tensor<1x25x25x64xf32>
#     %1351 = tosa.transpose %1350, %96 : (tensor<1x25x25x64xf32>, tensor<4xi64>) -> tensor<1x64x25x25xf32>
#     %1352 = tosa.add %extracted_slice_149, %1351 : (tensor<1x64x25x25xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %1353 = tosa.equal %179, %180 : (tensor<1x64x25x25xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xi1>
#     %1354 = tosa.select %1353, %extracted_slice_148, %31 : (tensor<1x64x25x25xi1>, tensor<1x64x25x25xf32>, tensor<f32>) -> tensor<1x64x25x25xf32>
#     %1355 = tosa.mul %1354, %91 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %1356 = tosa.mul %132, %1355 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %1357 = tosa.transpose %1356, %98 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %1358 = tosa.transpose_conv2d %1357, %10, %cst_7 {out_pad = array<i64: -2, -2, -2, -2>, out_shape = array<i64: 1, 25, 25, 48>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<48x5x5x64xf32>, tensor<48xf32>) -> tensor<1x25x25x48xf32>
#     %1359 = tosa.transpose %1358, %96 : (tensor<1x25x25x48xf32>, tensor<4xi64>) -> tensor<1x48x25x25xf32>
#     %1360 = tosa.equal %171, %172 : (tensor<1x48x25x25xf32>, tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xi1>
#     %1361 = tosa.select %1360, %1359, %31 : (tensor<1x48x25x25xi1>, tensor<1x48x25x25xf32>, tensor<f32>) -> tensor<1x48x25x25xf32>
#     %1362 = tosa.mul %1361, %81 {shift = 0 : i8} : (tensor<1x48x25x25xf32>, tensor<1x48x1x1xf32>) -> tensor<1x48x25x25xf32>
#     %1363 = tosa.mul %168, %1362 {shift = 0 : i8} : (tensor<1x48x1x1xf32>, tensor<1x48x25x25xf32>) -> tensor<1x48x25x25xf32>
#     %1364 = tosa.transpose %1363, %98 : (tensor<1x48x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x48xf32>
#     %1365 = tosa.transpose_conv2d %1364, %5, %cst_17 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 25, 25, 192>, stride = array<i64: 1, 1>} : (tensor<1x25x25x48xf32>, tensor<192x1x1x48xf32>, tensor<192xf32>) -> tensor<1x25x25x192xf32>
#     %1366 = tosa.add %extracted_slice_151, %1365 : (tensor<1x25x25x192xf32>, tensor<1x25x25x192xf32>) -> tensor<1x25x25x192xf32>
#     %1367 = tosa.equal %163, %164 : (tensor<1x64x25x25xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xi1>
#     %1368 = tosa.select %1367, %1352, %31 : (tensor<1x64x25x25xi1>, tensor<1x64x25x25xf32>, tensor<f32>) -> tensor<1x64x25x25xf32>
#     %1369 = tosa.mul %1368, %91 {shift = 0 : i8} : (tensor<1x64x25x25xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x25x25xf32>
#     %1370 = tosa.mul %132, %1369 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x25x25xf32>) -> tensor<1x64x25x25xf32>
#     %1371 = tosa.transpose %1370, %98 : (tensor<1x64x25x25xf32>, tensor<4xi64>) -> tensor<1x25x25x64xf32>
#     %1372 = tosa.transpose_conv2d %1371, %4, %cst_17 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 25, 25, 192>, stride = array<i64: 1, 1>} : (tensor<1x25x25x64xf32>, tensor<192x1x1x64xf32>, tensor<192xf32>) -> tensor<1x25x25x192xf32>
#     %1373 = tosa.add %1366, %1372 : (tensor<1x25x25x192xf32>, tensor<1x25x25x192xf32>) -> tensor<1x25x25x192xf32>
#     %1374 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%156, %cst_23, %157, %1373 : tensor<1x52x52x192xf32>, tensor<3x3xf32>, tensor<1x25x25x192xf32>, tensor<1x25x25x192xf32>) outs(%cst_3 : tensor<1x52x52x192xf32>) {
#     ^bb0(%in: f32, %in_152: f32, %in_153: f32, %in_154: f32, %out: f32):
#       %1412 = arith.cmpf oge, %in, %in_153 : f32
#       %1413 = arith.select %1412, %in_154, %cst_29 : f32
#       %1414 = arith.addf %out, %1413 : f32
#       linalg.yield %1414 : f32
#     } -> tensor<1x52x52x192xf32>
#     %1375 = tosa.transpose %1374, %96 : (tensor<1x52x52x192xf32>, tensor<4xi64>) -> tensor<1x192x52x52xf32>
#     %1376 = tosa.equal %154, %155 : (tensor<1x192x52x52xf32>, tensor<1x192x52x52xf32>) -> tensor<1x192x52x52xi1>
#     %1377 = tosa.select %1376, %1375, %31 : (tensor<1x192x52x52xi1>, tensor<1x192x52x52xf32>, tensor<f32>) -> tensor<1x192x52x52xf32>
#     %1378 = tosa.mul %1377, %85 {shift = 0 : i8} : (tensor<1x192x52x52xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x52x52xf32>
#     %1379 = tosa.mul %151, %1378 {shift = 0 : i8} : (tensor<1x192x1x1xf32>, tensor<1x192x52x52xf32>) -> tensor<1x192x52x52xf32>
#     %1380 = tosa.transpose %1379, %98 : (tensor<1x192x52x52xf32>, tensor<4xi64>) -> tensor<1x52x52x192xf32>
#     %1381 = tosa.transpose_conv2d %1380, %3, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 54, 54, 80>, stride = array<i64: 1, 1>} : (tensor<1x52x52x192xf32>, tensor<80x3x3x192xf32>, tensor<80xf32>) -> tensor<1x54x54x80xf32>
#     %1382 = tosa.transpose %1381, %96 : (tensor<1x54x54x80xf32>, tensor<4xi64>) -> tensor<1x80x54x54xf32>
#     %1383 = tosa.equal %145, %146 : (tensor<1x80x54x54xf32>, tensor<1x80x54x54xf32>) -> tensor<1x80x54x54xi1>
#     %1384 = tosa.select %1383, %1382, %31 : (tensor<1x80x54x54xi1>, tensor<1x80x54x54xf32>, tensor<f32>) -> tensor<1x80x54x54xf32>
#     %1385 = tosa.mul %1384, %88 {shift = 0 : i8} : (tensor<1x80x54x54xf32>, tensor<1x80x1x1xf32>) -> tensor<1x80x54x54xf32>
#     %1386 = tosa.mul %142, %1385 {shift = 0 : i8} : (tensor<1x80x1x1xf32>, tensor<1x80x54x54xf32>) -> tensor<1x80x54x54xf32>
#     %1387 = tosa.transpose %1386, %98 : (tensor<1x80x54x54xf32>, tensor<4xi64>) -> tensor<1x54x54x80xf32>
#     %1388 = tosa.transpose_conv2d %1387, %2, %cst_10 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 54, 54, 64>, stride = array<i64: 1, 1>} : (tensor<1x54x54x80xf32>, tensor<64x1x1x80xf32>, tensor<64xf32>) -> tensor<1x54x54x64xf32>
#     %1389 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%137, %cst_23, %138, %1388 : tensor<1x109x109x64xf32>, tensor<3x3xf32>, tensor<1x54x54x64xf32>, tensor<1x54x54x64xf32>) outs(%cst_1 : tensor<1x109x109x64xf32>) {
#     ^bb0(%in: f32, %in_152: f32, %in_153: f32, %in_154: f32, %out: f32):
#       %1412 = arith.cmpf oge, %in, %in_153 : f32
#       %1413 = arith.select %1412, %in_154, %cst_29 : f32
#       %1414 = arith.addf %out, %1413 : f32
#       linalg.yield %1414 : f32
#     } -> tensor<1x109x109x64xf32>
#     %1390 = tosa.transpose %1389, %96 : (tensor<1x109x109x64xf32>, tensor<4xi64>) -> tensor<1x64x109x109xf32>
#     %1391 = tosa.equal %135, %136 : (tensor<1x64x109x109xf32>, tensor<1x64x109x109xf32>) -> tensor<1x64x109x109xi1>
#     %1392 = tosa.select %1391, %1390, %31 : (tensor<1x64x109x109xi1>, tensor<1x64x109x109xf32>, tensor<f32>) -> tensor<1x64x109x109xf32>
#     %1393 = tosa.mul %1392, %91 {shift = 0 : i8} : (tensor<1x64x109x109xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x109x109xf32>
#     %1394 = tosa.mul %132, %1393 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x109x109xf32>) -> tensor<1x64x109x109xf32>
#     %1395 = tosa.transpose %1394, %98 : (tensor<1x64x109x109xf32>, tensor<4xi64>) -> tensor<1x109x109x64xf32>
#     %1396 = tosa.transpose_conv2d %1395, %1, %cst_0 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 109, 109, 32>, stride = array<i64: 1, 1>} : (tensor<1x109x109x64xf32>, tensor<32x3x3x64xf32>, tensor<32xf32>) -> tensor<1x109x109x32xf32>
#     %1397 = tosa.transpose %1396, %96 : (tensor<1x109x109x32xf32>, tensor<4xi64>) -> tensor<1x32x109x109xf32>
#     %1398 = tosa.equal %126, %127 : (tensor<1x32x109x109xf32>, tensor<1x32x109x109xf32>) -> tensor<1x32x109x109xi1>
#     %1399 = tosa.select %1398, %1397, %31 : (tensor<1x32x109x109xi1>, tensor<1x32x109x109xf32>, tensor<f32>) -> tensor<1x32x109x109xf32>
#     %1400 = tosa.mul %1399, %95 {shift = 0 : i8} : (tensor<1x32x109x109xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x109x109xf32>
#     %1401 = tosa.mul %115, %1400 {shift = 0 : i8} : (tensor<1x32x1x1xf32>, tensor<1x32x109x109xf32>) -> tensor<1x32x109x109xf32>
#     %1402 = tosa.transpose %1401, %98 : (tensor<1x32x109x109xf32>, tensor<4xi64>) -> tensor<1x109x109x32xf32>
#     %1403 = tosa.transpose_conv2d %1402, %94, %cst_0 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 111, 111, 32>, stride = array<i64: 1, 1>} : (tensor<1x109x109x32xf32>, tensor<32x3x3x32xf32>, tensor<32xf32>) -> tensor<1x111x111x32xf32>
#     %1404 = tosa.transpose %1403, %96 : (tensor<1x111x111x32xf32>, tensor<4xi64>) -> tensor<1x32x111x111xf32>
#     %1405 = tosa.equal %118, %119 : (tensor<1x32x111x111xf32>, tensor<1x32x111x111xf32>) -> tensor<1x32x111x111xi1>
#     %1406 = tosa.select %1405, %1404, %31 : (tensor<1x32x111x111xi1>, tensor<1x32x111x111xf32>, tensor<f32>) -> tensor<1x32x111x111xf32>
#     %1407 = tosa.mul %1406, %95 {shift = 0 : i8} : (tensor<1x32x111x111xf32>, tensor<1x32x1x1xf32>) -> tensor<1x32x111x111xf32>
#     %1408 = tosa.mul %115, %1407 {shift = 0 : i8} : (tensor<1x32x1x1xf32>, tensor<1x32x111x111xf32>) -> tensor<1x32x111x111xf32>
#     %1409 = tosa.transpose %1408, %98 : (tensor<1x32x111x111xf32>, tensor<4xi64>) -> tensor<1x111x111x32xf32>
#     %1410 = tosa.transpose_conv2d %1409, %0, %cst {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 2, 2>} : (tensor<1x111x111x32xf32>, tensor<3x3x3x32xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
#     %1411 = tosa.transpose %1410, %96 : (tensor<1x224x224x3xf32>, tensor<4xi64>) -> tensor<1x3x224x224xf32>
#     return %1411 : tensor<1x3x224x224xf32>
#   }
# }

# %%
# !ragdoll-opt --help | grep const
# Out:
#       --convert-scf-to-openmp                                -   Convert SCF parallel loop to OpenMP parallel + workshare constructs.
#       --convert-shape-constraints                            -   Convert shape constraint operations to the standard dialect
#       --expand-strided-metadata                              -   Expand memref operations into easier to analyze constructs
#       --remove-shape-constraints                             -   Replace all cstr_ ops with a true witness
#       --tosa-layerwise-constant-fold                         -   Fold layerwise operations on constant tensors
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimizationMay add more tosa.const but would reduce runtime calculations
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimization
