# %%
model_file = "resnet101.mlir"
#batch_size = 2
for bs in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
    #for bs in [1, 4]:
    # !ragdoll-opt {model_file} --ragdoll-autodiff-prepare-batch-size=batchsize={bs} > {model_file}.bs{bs}
#!cat {model_file}.bs2
# Out:
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=1
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007fd9fc20ec40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26499 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=1 > resnet101.mlir.bs1
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=2
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007f48414aac40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26502 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=2 > resnet101.mlir.bs2
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=4
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007f0a93d8cc40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26505 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=4 > resnet101.mlir.bs4
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=8
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007efe92af5c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26510 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=8 > resnet101.mlir.bs8
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=16
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007facb50a6c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26513 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=16 > resnet101.mlir.bs16
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=32
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007fa5f74dbc40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26516 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=32 > resnet101.mlir.bs32
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=64
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007fb3fbc31c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26520 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=64 > resnet101.mlir.bs64
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=128
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007fbc03e30c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26523 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=128 > resnet101.mlir.bs128
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=256
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007ff3e3e45c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26526 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=256 > resnet101.mlir.bs256
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=512
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007ff018430c40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26530 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=512 > resnet101.mlir.bs512
# PLEASE submit a bug report to https://github.com/llvm/llvm-project/issues/ and include the crash backtrace.
# Stack dump:
# 0.	Program arguments: ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=1024
# Stack dump without symbol names (ensure you have llvm-symbolizer in your PATH or set the environment var `LLVM_SYMBOLIZER_PATH` to point to it):
# 0  libLLVM-19git.so 0x00007fab0cf2fc40 llvm::sys::PrintStackTrace(llvm::raw_ostream&, int) + 240
# /bin/bash: line 1: 26533 Segmentation fault      (core dumped) ragdoll-opt resnet101.mlir --ragdoll-autodiff-prepare-batch-size=batchsize=1024 > resnet101.mlir.bs1024
