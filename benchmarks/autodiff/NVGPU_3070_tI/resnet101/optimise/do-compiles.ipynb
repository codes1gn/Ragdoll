# %%
model_file_base = "vit.mlir"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"

# %% [raw]
# #for bs in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
# for bs in [1,4]:
#     model_file = model_file_base + ".bs{}".format(bs)
#     target_file = model_file + ".storeall"
#     !ragdoll-opt {model_file}  \
#     --canonicalize \
#     --enable-cse-in-legalizer \
#     --symbol-dce \
#     --ragdoll-autodiff-vjp-public-functions='strategy=storeall' \
#     --ragdoll-autodiff-vjp \
#     --inline \
#     --ragdoll-autodiff-inline-function-call \
#     --ragdoll-initialisation \
#     --eliminate-empty-tensors \
#     --ragdoll-legalise-to-iree-compatibility \
#     --ragdoll-raise-linalg-to-tosa \
#     --canonicalize \
#     --cse > {target_file}

# %% [raw]
# for bs in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
#     model_file = model_file_base + ".bs{}".format(bs)
#     target_file = model_file + ".recompute"
#     !ragdoll-opt {model_file}  \
#     --canonicalize \
#     --enable-cse-in-legalizer \
#     --symbol-dce \
#     --ragdoll-autodiff-vjp-public-functions='strategy=recompute' \
#     --ragdoll-autodiff-vjp \
#     --inline \
#     --ragdoll-autodiff-inline-function-call \
#     --ragdoll-initialisation \
#     --eliminate-empty-tensors \
#     --ragdoll-legalise-to-iree-compatibility \
#     --ragdoll-raise-linalg-to-tosa \
#     --canonicalize \
#     --cse > {target_file}

# %%
#for bs in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]:
model_file_base = "vit.mlir"
for bs in [1, 4]:
    model_file = model_file_base + ".bs{}".format(bs)
    target_file = model_file + ".heuristic"
    # !ragdoll-opt {model_file}  \
    --canonicalize \
    --enable-cse-in-legalizer \
    --symbol-dce \
    --ragdoll-autodiff-vjp-public-functions='strategy=heuristic' \
    --ragdoll-autodiff-vjp \
    --inline \
    --ragdoll-autodiff-inline-function-call \
    --ragdoll-initialisation \
    --eliminate-empty-tensors \
    --ragdoll-legalise-to-iree-compatibility \
    --ragdoll-raise-linalg-to-tosa \
    --canonicalize \
    --cse > {target_file}

# %%
# !diff vit.mlir.bs1.storeall vit.mlir.bs1.heuristic
# Out:
# 4,72c4,32
# <   ml_program.global private mutable @global664(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global663(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global659(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global652(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global651(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global646(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global645(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global640(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global639(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global635(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global625(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global624(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global623(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global622(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global619(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global618(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global610(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global609(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global605(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global598(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global597(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global592(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global591(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global586(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global585(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global581(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global571(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global570(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global569(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global568(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global565(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global564(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global556(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global555(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global551(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global544(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global543(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global538(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global537(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global532(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global531(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global527(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global517(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global516(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global515(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global514(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global511(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global510(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global502(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global501(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global497(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global490(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global489(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global484(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global483(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global478(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global477(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global473(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global463(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global462(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global461(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global460(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global457(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global456(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global448(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global447(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global443(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global436(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global435(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# ---
# >   ml_program.global private mutable @global528(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global524(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global517(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global516(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global512(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global511(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global506(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global502(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global495(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global494(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global493(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global492(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global490(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global485(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global481(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global474(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global473(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global469(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global468(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global463(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global459(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global452(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global451(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global450(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global449(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global447(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global442(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global438(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global431(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# 74,77c34,37
# <   ml_program.global private mutable @global429(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global424(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global423(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global419(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# ---
# >   ml_program.global private mutable @global426(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global425(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global420(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global416(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# 82,86c42,47
# <   ml_program.global private mutable @global403(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global402(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global394(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global393(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global389(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# ---
# >   ml_program.global private mutable @global404(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global399(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global395(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global388(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global387(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global383(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# 88,142c49,104
# <   ml_program.global private mutable @global381(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global376(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global375(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global370(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global369(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global365(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global355(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global354(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global353(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global352(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global349(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global348(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global340(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global339(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global335(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global328(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global327(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global322(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global321(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global316(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global315(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global311(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global301(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global300(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global299(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global298(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global295(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global294(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global286(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global285(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global281(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global274(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global273(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global268(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global267(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global262(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global261(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global257(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global247(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global246(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global245(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global244(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global241(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global240(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global232(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global231(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global227(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global220(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global219(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global214(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global213(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global208(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global207(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global203(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global193(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# ---
# >   ml_program.global private mutable @global377(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global373(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global366(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global365(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global364(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global363(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global361(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global356(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global352(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global345(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global344(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global340(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global339(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global334(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global330(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global323(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global322(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global321(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global320(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global318(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global313(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global309(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global302(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global301(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global297(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global296(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global291(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global287(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global280(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global279(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global278(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global277(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global275(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global270(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global266(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global259(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global258(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global254(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global253(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global248(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global244(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global237(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global236(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global235(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global234(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global232(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global227(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global223(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global216(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global215(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global211(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global210(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global205(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global201(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global194(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global193(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# 144,200c106,161
# <   ml_program.global private mutable @global191(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global190(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global187(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global186(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global178(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global177(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global173(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global166(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global165(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global160(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global159(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global154(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global153(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global149(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global139(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global138(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global137(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global136(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global133(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global132(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global124(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global123(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global119(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global112(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global111(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global106(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global105(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global100(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global99(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global95(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global85(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global84(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global83(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global82(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global79(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global78(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global70(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global69(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global65(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global58(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global57(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global52(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global51(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global50(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# <   ml_program.global private mutable @global45(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global44(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global40(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# <   ml_program.global private mutable @global30(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global29(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global28(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# <   ml_program.global private mutable @global27(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# <   ml_program.global private mutable @global25(dense<1.000000e+00> : tensor<f32>) : tensor<f32>
# <   ml_program.global private mutable @global23(dense<1.000000e+00> : tensor<12x64x197xf32>) : tensor<12x64x197xf32>
# <   ml_program.global private mutable @global22(dense<1.000000e+00> : tensor<12x197x64xf32>) : tensor<12x197x64xf32>
# <   ml_program.global private mutable @global14(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global13(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# <   ml_program.global private mutable @global9(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# ---
# >   ml_program.global private mutable @global191(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global189(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global184(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global180(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global173(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global172(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global168(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global167(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global162(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global158(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global151(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global150(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global149(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global148(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global146(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global141(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global137(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global130(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global129(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global125(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global124(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global119(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global115(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global108(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global107(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global106(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global105(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global103(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global98(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global94(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global87(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global86(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global82(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global81(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global76(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global72(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global65(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global64(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global63(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global62(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global60(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global55(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global51(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global44(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global43(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global39(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global38(dense<1.000000e+00> : tensor<1x197x3072xf32>) : tensor<1x197x3072xf32>
# >   ml_program.global private mutable @global33(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global29(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global22(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global21(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global20(dense<1.000000e+00> : tensor<12x197x1xf32>) : tensor<12x197x1xf32>
# >   ml_program.global private mutable @global19(dense<1.000000e+00> : tensor<12x197x197xf32>) : tensor<12x197x197xf32>
# >   ml_program.global private mutable @global17(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# >   ml_program.global private mutable @global12(dense<1.000000e+00> : tensor<1x197x1xf32>) : tensor<1x197x1xf32>
# >   ml_program.global private mutable @global8(dense<1.000000e+00> : tensor<1x197x768xf32>) : tensor<1x197x768xf32>
# 231c192
# <     ml_program.global_store @global9 = %25 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global8 = %25 : tensor<1x197x768xf32>
# 236c197
# <     ml_program.global_store @global13 = %29 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global12 = %29 : tensor<1x197x1xf32>
# 238d198
# <     ml_program.global_store @global14 = %30 : tensor<1x197x1xf32>
# 243a204
# >     ml_program.global_store @global17 = %35 : tensor<1x197x768xf32>
# 247d207
# <     ml_program.global_store @global22 = %38 : tensor<12x197x64xf32>
# 249d208
# <     ml_program.global_store @global23 = %39 : tensor<12x64x197xf32>
# 252d210
# <     ml_program.global_store @global25 = %41 : tensor<f32>
# 253a212
# >     ml_program.global_store @global19 = %42 : tensor<12x197x197xf32>
# 255d213
# <     ml_program.global_store @global27 = %43 : tensor<12x197x197xf32>
# 257c215
# <     ml_program.global_store @global28 = %44 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global20 = %44 : tensor<12x197x1xf32>
# 259c217
# <     ml_program.global_store @global29 = %45 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global21 = %45 : tensor<12x197x1xf32>
# 261c219
# <     ml_program.global_store @global30 = %46 : tensor<12x197x197xf32>
# ---
# >     ml_program.global_store @global22 = %46 : tensor<12x197x197xf32>
# 272c230
# <     ml_program.global_store @global40 = %56 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global29 = %56 : tensor<1x197x768xf32>
# 277c235
# <     ml_program.global_store @global44 = %60 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global33 = %60 : tensor<1x197x1xf32>
# 279d236
# <     ml_program.global_store @global45 = %61 : tensor<1x197x1xf32>
# 285c242
# <     ml_program.global_store @global50 = %66 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global38 = %66 : tensor<1x197x3072xf32>
# 287c244
# <     ml_program.global_store @global51 = %67 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global39 = %67 : tensor<1x197x3072xf32>
# 289d245
# <     ml_program.global_store @global52 = %68 : tensor<1x197x3072xf32>
# 293a250
# >     ml_program.global_store @global43 = %72 : tensor<1x197x3072xf32>
# 295d251
# <     ml_program.global_store @global57 = %73 : tensor<1x197x3072xf32>
# 297c253
# <     ml_program.global_store @global58 = %74 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global44 = %74 : tensor<1x197x3072xf32>
# 305c261
# <     ml_program.global_store @global65 = %81 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global51 = %81 : tensor<1x197x768xf32>
# 310c266
# <     ml_program.global_store @global69 = %85 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global55 = %85 : tensor<1x197x1xf32>
# 312d267
# <     ml_program.global_store @global70 = %86 : tensor<1x197x1xf32>
# 317a273
# >     ml_program.global_store @global60 = %91 : tensor<1x197x768xf32>
# 321d276
# <     ml_program.global_store @global78 = %94 : tensor<12x197x64xf32>
# 323d277
# <     ml_program.global_store @global79 = %95 : tensor<12x64x197xf32>
# 325a280
# >     ml_program.global_store @global62 = %97 : tensor<12x197x197xf32>
# 327d281
# <     ml_program.global_store @global82 = %98 : tensor<12x197x197xf32>
# 329c283
# <     ml_program.global_store @global83 = %99 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global63 = %99 : tensor<12x197x1xf32>
# 331c285
# <     ml_program.global_store @global84 = %100 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global64 = %100 : tensor<12x197x1xf32>
# 333c287
# <     ml_program.global_store @global85 = %101 : tensor<12x197x197xf32>
# ---
# >     ml_program.global_store @global65 = %101 : tensor<12x197x197xf32>
# 344c298
# <     ml_program.global_store @global95 = %111 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global72 = %111 : tensor<1x197x768xf32>
# 349c303
# <     ml_program.global_store @global99 = %115 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global76 = %115 : tensor<1x197x1xf32>
# 351d304
# <     ml_program.global_store @global100 = %116 : tensor<1x197x1xf32>
# 357c310
# <     ml_program.global_store @global105 = %121 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global81 = %121 : tensor<1x197x3072xf32>
# 359c312
# <     ml_program.global_store @global106 = %122 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global82 = %122 : tensor<1x197x3072xf32>
# 363a317
# >     ml_program.global_store @global86 = %126 : tensor<1x197x3072xf32>
# 365d318
# <     ml_program.global_store @global111 = %127 : tensor<1x197x3072xf32>
# 367c320
# <     ml_program.global_store @global112 = %128 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global87 = %128 : tensor<1x197x3072xf32>
# 375c328
# <     ml_program.global_store @global119 = %135 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global94 = %135 : tensor<1x197x768xf32>
# 380c333
# <     ml_program.global_store @global123 = %139 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global98 = %139 : tensor<1x197x1xf32>
# 382d334
# <     ml_program.global_store @global124 = %140 : tensor<1x197x1xf32>
# 387a340
# >     ml_program.global_store @global103 = %145 : tensor<1x197x768xf32>
# 391d343
# <     ml_program.global_store @global132 = %148 : tensor<12x197x64xf32>
# 393d344
# <     ml_program.global_store @global133 = %149 : tensor<12x64x197xf32>
# 395a347
# >     ml_program.global_store @global105 = %151 : tensor<12x197x197xf32>
# 397d348
# <     ml_program.global_store @global136 = %152 : tensor<12x197x197xf32>
# 399c350
# <     ml_program.global_store @global137 = %153 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global106 = %153 : tensor<12x197x1xf32>
# 401c352
# <     ml_program.global_store @global138 = %154 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global107 = %154 : tensor<12x197x1xf32>
# 403c354
# <     ml_program.global_store @global139 = %155 : tensor<12x197x197xf32>
# ---
# >     ml_program.global_store @global108 = %155 : tensor<12x197x197xf32>
# 414c365
# <     ml_program.global_store @global149 = %165 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global115 = %165 : tensor<1x197x768xf32>
# 419c370
# <     ml_program.global_store @global153 = %169 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global119 = %169 : tensor<1x197x1xf32>
# 421d371
# <     ml_program.global_store @global154 = %170 : tensor<1x197x1xf32>
# 427c377
# <     ml_program.global_store @global159 = %175 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global124 = %175 : tensor<1x197x3072xf32>
# 429c379
# <     ml_program.global_store @global160 = %176 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global125 = %176 : tensor<1x197x3072xf32>
# 433a384
# >     ml_program.global_store @global129 = %180 : tensor<1x197x3072xf32>
# 435d385
# <     ml_program.global_store @global165 = %181 : tensor<1x197x3072xf32>
# 437c387
# <     ml_program.global_store @global166 = %182 : tensor<1x197x3072xf32>
# ---
# >     ml_program.global_store @global130 = %182 : tensor<1x197x3072xf32>
# 445c395
# <     ml_program.global_store @global173 = %189 : tensor<1x197x768xf32>
# ---
# >     ml_program.global_store @global137 = %189 : tensor<1x197x768xf32>
# 450c400
# <     ml_program.global_store @global177 = %193 : tensor<1x197x1xf32>
# ---
# >     ml_program.global_store @global141 = %193 : tensor<1x197x1xf32>
# 452d401
# <     ml_program.global_store @global178 = %194 : tensor<1x197x1xf32>
# 457a407
# >     ml_program.global_store @global146 = %199 : tensor<1x197x768xf32>
# 461d410
# <     ml_program.global_store @global186 = %202 : tensor<12x197x64xf32>
# 463d411
# <     ml_program.global_store @global187 = %203 : tensor<12x64x197xf32>
# 465a414
# >     ml_program.global_store @global148 = %205 : tensor<12x197x197xf32>
# 467d415
# <     ml_program.global_store @global190 = %206 : tensor<12x197x197xf32>
# 469c417
# <     ml_program.global_store @global191 = %207 : tensor<12x197x1xf32>
# ---
# >     ml_program.global_store @global149 = %207 : tensor<12x197x1xf32>
# 471c419
# ...
# >     %935 = tosa.mul %31, %931 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %936 = tosa.reduce_sum %935 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
# >     %937 = tosa.mul %global63, %global63 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %938 = tosa.negate %937 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %939 = tosa.reciprocal %938 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %940 = tosa.mul %939, %936 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %941 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%940 : tensor<12x197x1xf32>) outs(%cst_0 : tensor<12x197x197xf32>) {
# 2416,2423c2285,2291
# <     %941 = tosa.add %933, %940 : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# <     %942 = tosa.mul %global27, %941 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# <     %943 = tosa.mul %global25, %942 {shift = 0 : i8} : (tensor<f32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# <     %944 = tosa.transpose %global23, %2 : (tensor<12x64x197xf32>, tensor<3xi32>) -> tensor<12x197x64xf32>
# <     %945 = tosa.matmul %943, %944 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# <     %946 = tosa.add %932, %945 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# <     %947 = tosa.matmul %929, %943 : (tensor<12x64x197xf32>, tensor<12x197x197xf32>) -> tensor<12x64x197xf32>
# <     %948 = tosa.transpose %947, %1 : (tensor<12x64x197xf32>, tensor<3xi64>) -> tensor<12x197x64xf32>
# ---
# >     %942 = tosa.add %934, %941 : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %943 = tosa.mul %31, %942 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %944 = tosa.mul %22, %943 {shift = 0 : i8} : (tensor<f32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %945 = tosa.matmul %944, %30 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %946 = tosa.add %933, %945 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %947 = tosa.matmul %930, %944 : (tensor<12x64x197xf32>, tensor<12x197x197xf32>) -> tensor<12x64x197xf32>
# >     %948 = tosa.transpose %947, %11 : (tensor<12x64x197xf32>, tensor<3xi64>) -> tensor<12x197x64xf32>
# 2426c2294
# <     %951 = tosa.transpose %950, %3 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
# ---
# >     %951 = tosa.transpose %950, %13 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
# 2428,2431c2296,2299
# <     %953 = tosa.matmul %952, %4 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
# <     %954 = tosa.mul %953, %12 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
# <     %955 = tosa.mul %global14, %954 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# <     %956 = tosa.mul %global9, %954 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# ---
# >     %953 = tosa.matmul %952, %2 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
# >     %954 = tosa.mul %953, %10 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
# >     %955 = tosa.mul %27, %954 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %956 = tosa.mul %global51, %954 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# 2433,2434c2301,2302
# <     %958 = tosa.pow %global13, %9 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# <     %959 = tosa.mul %958, %10 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# ---
# >     %958 = tosa.pow %global55, %7 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %959 = tosa.mul %958, %8 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# 2436c2304
# <     %961 = tosa.mul %960, %13 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# ---
# >     %961 = tosa.mul %960, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# 2441c2309
# <     %963 = tosa.mul %global9, %962 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# ---
# >     %963 = tosa.mul %global51, %962 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# 2444c2312
# <     %966 = tosa.add %924, %965 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# ---
# >     %966 = tosa.add %925, %965 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# 2447c2315
# <     %969 = tosa.mul %968, %13 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# ---
# >     %969 = tosa.mul %968, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# 2453,2456c2321,2416
# <     %extracted_slice = tensor.extract_slice %971[0, 1, 0] [1, 196, 768] [1, 1, 1] : tensor<1x197x768xf32> to tensor<1x196x768xf32>
# <     %972 = tosa.reshape %extracted_slice {new_shape = array<i64: 1, 14, 14, 768>} : (tensor<1x196x768xf32>) -> tensor<1x14x14x768xf32>
# <     %973 = tosa.transpose_conv2d %972, %0, %cst {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 16, 16>} : (tensor<1x14x14x768xf32>, tensor<3x16x16x768xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
# <     return %973 : tensor<1x224x224x3xf32>
# ---
# >     %972 = tosa.matmul %971, %6 : (tensor<1x197x768xf32>, tensor<1x768x3072xf32>) -> tensor<1x197x3072xf32>
# >     %973 = tosa.mul %global44, %972 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %974 = tosa.mul %global39, %972 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %975 = tosa.mul %26, %26 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %976 = tosa.sub %5, %975 : (tensor<f32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %977 = tosa.mul %976, %974 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %978 = tosa.mul %25, %977 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %979 = tosa.pow %global38, %4 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %980 = tosa.mul %979, %17 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %981 = tosa.add %978, %980 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %982 = tosa.mul %973, %15 {shift = 0 : i8} : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %983 = tosa.add %981, %982 : (tensor<1x197x3072xf32>, tensor<1x197x3072xf32>) -> tensor<1x197x3072xf32>
# >     %984 = tosa.matmul %983, %3 : (tensor<1x197x3072xf32>, tensor<1x3072x768xf32>) -> tensor<1x197x768xf32>
# >     %985 = tosa.mul %984, %10 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
# >     %986 = tosa.mul %24, %985 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %987 = tosa.mul %global29, %985 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %988 = tosa.reduce_sum %987 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
# >     %989 = tosa.pow %global33, %7 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %990 = tosa.mul %989, %8 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %991 = tosa.mul %990, %988 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
# >     %992 = tosa.mul %991, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %993 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%992 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
# >     ^bb0(%in: f32, %out: f32):
# >       linalg.yield %in : f32
# >     } -> tensor<1x197x768xf32>
# >     %994 = tosa.mul %global29, %993 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %995 = tosa.add %986, %994 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %996 = tosa.add %995, %994 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %997 = tosa.add %971, %996 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %998 = tosa.negate %996 : (tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %999 = tosa.reduce_sum %998 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
# >     %1000 = tosa.mul %999, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %1001 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%1000 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
# >     ^bb0(%in: f32, %out: f32):
# >       linalg.yield %in : f32
# >     } -> tensor<1x197x768xf32>
# >     %1002 = tosa.add %997, %1001 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1003 = tosa.matmul %1002, %2 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
# >     %1004 = tosa.reshape %1003 {new_shape = array<i64: 1, 197, 12, 64>} : (tensor<1x197x768xf32>) -> tensor<1x197x12x64xf32>
# >     %1005 = tosa.transpose %1004, %13 : (tensor<1x197x12x64xf32>, tensor<4xi64>) -> tensor<1x12x197x64xf32>
# >     %1006 = tosa.reshape %1005 {new_shape = array<i64: 12, 197, 64>} : (tensor<1x12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %1007 = tosa.transpose %21, %1 : (tensor<12x197x64xf32>, tensor<3xi32>) -> tensor<12x64x197xf32>
# >     %1008 = tosa.matmul %1006, %1007 : (tensor<12x197x64xf32>, tensor<12x64x197xf32>) -> tensor<12x197x197xf32>
# >     %1009 = tosa.transpose %global22, %1 : (tensor<12x197x197xf32>, tensor<3xi32>) -> tensor<12x197x197xf32>
# >     %1010 = tosa.matmul %1009, %1006 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %1011 = tosa.mul %global21, %1008 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %1012 = tosa.mul %23, %1008 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %1013 = tosa.reduce_sum %1012 {axis = 2 : i32} : (tensor<12x197x197xf32>) -> tensor<12x197x1xf32>
# >     %1014 = tosa.mul %global20, %global20 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %1015 = tosa.negate %1014 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %1016 = tosa.reciprocal %1015 : (tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %1017 = tosa.mul %1016, %1013 {shift = 0 : i8} : (tensor<12x197x1xf32>, tensor<12x197x1xf32>) -> tensor<12x197x1xf32>
# >     %1018 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%1017 : tensor<12x197x1xf32>) outs(%cst_0 : tensor<12x197x197xf32>) {
# >     ^bb0(%in: f32, %out: f32):
# >       linalg.yield %in : f32
# >     } -> tensor<12x197x197xf32>
# >     %1019 = tosa.add %1011, %1018 : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %1020 = tosa.mul %23, %1019 {shift = 0 : i8} : (tensor<12x197x197xf32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %1021 = tosa.mul %22, %1020 {shift = 0 : i8} : (tensor<f32>, tensor<12x197x197xf32>) -> tensor<12x197x197xf32>
# >     %1022 = tosa.matmul %1021, %21 : (tensor<12x197x197xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %1023 = tosa.add %1010, %1022 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %1024 = tosa.matmul %1007, %1021 : (tensor<12x64x197xf32>, tensor<12x197x197xf32>) -> tensor<12x64x197xf32>
# >     %1025 = tosa.transpose %1024, %11 : (tensor<12x64x197xf32>, tensor<3xi64>) -> tensor<12x197x64xf32>
# >     %1026 = tosa.add %1023, %1025 : (tensor<12x197x64xf32>, tensor<12x197x64xf32>) -> tensor<12x197x64xf32>
# >     %1027 = tosa.reshape %1026 {new_shape = array<i64: 1, 12, 197, 64>} : (tensor<12x197x64xf32>) -> tensor<1x12x197x64xf32>
# >     %1028 = tosa.transpose %1027, %13 : (tensor<1x12x197x64xf32>, tensor<4xi64>) -> tensor<1x197x12x64xf32>
# >     %1029 = tosa.reshape %1028 {new_shape = array<i64: 1, 197, 768>} : (tensor<1x197x12x64xf32>) -> tensor<1x197x768xf32>
# >     %1030 = tosa.matmul %1029, %2 : (tensor<1x197x768xf32>, tensor<1x768x768xf32>) -> tensor<1x197x768xf32>
# >     %1031 = tosa.mul %1030, %10 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<768xf32>) -> tensor<1x197x768xf32>
# >     %1032 = tosa.mul %18, %1031 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1033 = tosa.mul %global8, %1031 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1034 = tosa.reduce_sum %1033 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
# >     %1035 = tosa.pow %global12, %7 : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %1036 = tosa.mul %1035, %8 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %1037 = tosa.mul %1036, %1034 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<1x197x1xf32>) -> tensor<1x197x1xf32>
# >     %1038 = tosa.mul %1037, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %1039 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%1038 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
# >     ^bb0(%in: f32, %out: f32):
# >       linalg.yield %in : f32
# >     } -> tensor<1x197x768xf32>
# >     %1040 = tosa.mul %global8, %1039 {shift = 0 : i8} : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1041 = tosa.add %1032, %1040 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1042 = tosa.add %1041, %1040 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1043 = tosa.add %1002, %1042 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1044 = tosa.negate %1042 : (tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %1045 = tosa.reduce_sum %1044 {axis = 2 : i32} : (tensor<1x197x768xf32>) -> tensor<1x197x1xf32>
# >     %1046 = tosa.mul %1045, %12 {shift = 0 : i8} : (tensor<1x197x1xf32>, tensor<f32>) -> tensor<1x197x1xf32>
# >     %1047 = linalg.generic {indexing_maps = [#map, #map1], iterator_types = ["parallel", "parallel", "reduction", "parallel"]} ins(%1046 : tensor<1x197x1xf32>) outs(%cst_1 : tensor<1x197x768xf32>) {
# >     ^bb0(%in: f32, %out: f32):
# >       linalg.yield %in : f32
# >     } -> tensor<1x197x768xf32>
# >     %1048 = tosa.add %1043, %1047 : (tensor<1x197x768xf32>, tensor<1x197x768xf32>) -> tensor<1x197x768xf32>
# >     %extracted_slice = tensor.extract_slice %1048[0, 1, 0] [1, 196, 768] [1, 1, 1] : tensor<1x197x768xf32> to tensor<1x196x768xf32>
# >     %1049 = tosa.reshape %extracted_slice {new_shape = array<i64: 1, 14, 14, 768>} : (tensor<1x196x768xf32>) -> tensor<1x14x14x768xf32>
# >     %1050 = tosa.transpose_conv2d %1049, %0, %cst {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 16, 16>} : (tensor<1x14x14x768xf32>, tensor<3x16x16x768xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
# >     return %1050 : tensor<1x224x224x3xf32>
