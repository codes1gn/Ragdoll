# %%
model_file = "densenet201.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
target_file = model_file + ".heuristic"
#!./convert_v0_to_v1.sh {model_file}
# !ragdoll-opt {model_file} --ragdoll-identical-transpose-removal > {model_file}.tmp
#!cat {model_file}.tmp

# !mv {model_file}.tmp {model_file}

# %%
model_file = "densenet201.mlir.v1"
#target_file = model_file + ".recompute"
#target_file = model_file + ".storeall"
#target_file = model_file + ".hybrid"
#target_file = model_file + ".heuristic"
target_file = model_file + ".recompute"
# !ragdoll-opt {model_file}  \
--canonicalize \
--enable-cse-in-legalizer \
--symbol-dce \
--ragdoll-autodiff-vjp-public-functions='strategy=recompute' \
--ragdoll-autodiff-vjp \
--inline \
--ragdoll-autodiff-inline-function-call \
--ragdoll-initialisation \
--eliminate-empty-tensors \
--ragdoll-legalise-to-iree-compatibility \
--ragdoll-raise-linalg-to-tosa \
--canonicalize \
--cse > {target_file}

# %%
# !cat {target_file}
# Out:
# #map = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 + d4, d2 + d5, d3)>
# #map1 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d4, d5)>
# #map2 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1, d2, d3)>
# #map3 = affine_map<(d0, d1, d2, d3, d4, d5) -> (d0, d1 * 2 + d4, d2 * 2 + d5, d3)>
# module {
#   ml_program.global private mutable @global0(dense<1.000000e+00> : tensor<1x3x224x224xf32>) : tensor<1x3x224x224xf32>
#   func.func @forward(%arg0: tensor<1x3x224x224xf32>) -> tensor<1x1000xf32> {
#     %0 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1000xf32>}> : () -> tensor<1000xf32>
#     %1 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1920x1000xf32>}> : () -> tensor<1x1920x1000xf32>
#     %2 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1920x1x1xf32>}> : () -> tensor<1x1920x1x1xf32>
#     %3 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1888xf32>}> : () -> tensor<128x1x1x1888xf32>
#     %4 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1888x1x1xf32>}> : () -> tensor<1x1888x1x1xf32>
#     %5 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1856xf32>}> : () -> tensor<128x1x1x1856xf32>
#     %6 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1856x1x1xf32>}> : () -> tensor<1x1856x1x1xf32>
#     %7 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1824xf32>}> : () -> tensor<128x1x1x1824xf32>
#     %8 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1824x1x1xf32>}> : () -> tensor<1x1824x1x1xf32>
#     %9 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1792xf32>}> : () -> tensor<128x1x1x1792xf32>
#     %10 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<896xf32>}> : () -> tensor<896xf32>
#     %11 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<896x1x1x1792xf32>}> : () -> tensor<896x1x1x1792xf32>
#     %12 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1792x1x1xf32>}> : () -> tensor<1x1792x1x1xf32>
#     %13 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1760xf32>}> : () -> tensor<128x1x1x1760xf32>
#     %14 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1760x1x1xf32>}> : () -> tensor<1x1760x1x1xf32>
#     %15 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1728xf32>}> : () -> tensor<128x1x1x1728xf32>
#     %16 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1728x1x1xf32>}> : () -> tensor<1x1728x1x1xf32>
#     %17 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1696xf32>}> : () -> tensor<128x1x1x1696xf32>
#     %18 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1696x1x1xf32>}> : () -> tensor<1x1696x1x1xf32>
#     %19 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1664xf32>}> : () -> tensor<128x1x1x1664xf32>
#     %20 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1664x1x1xf32>}> : () -> tensor<1x1664x1x1xf32>
#     %21 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1632xf32>}> : () -> tensor<128x1x1x1632xf32>
#     %22 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1632x1x1xf32>}> : () -> tensor<1x1632x1x1xf32>
#     %23 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1600xf32>}> : () -> tensor<128x1x1x1600xf32>
#     %24 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1600x1x1xf32>}> : () -> tensor<1x1600x1x1xf32>
#     %25 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1568xf32>}> : () -> tensor<128x1x1x1568xf32>
#     %26 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1568x1x1xf32>}> : () -> tensor<1x1568x1x1xf32>
#     %27 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1536xf32>}> : () -> tensor<128x1x1x1536xf32>
#     %28 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1536x1x1xf32>}> : () -> tensor<1x1536x1x1xf32>
#     %29 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1504xf32>}> : () -> tensor<128x1x1x1504xf32>
#     %30 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1504x1x1xf32>}> : () -> tensor<1x1504x1x1xf32>
#     %31 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1472xf32>}> : () -> tensor<128x1x1x1472xf32>
#     %32 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1472x1x1xf32>}> : () -> tensor<1x1472x1x1xf32>
#     %33 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1440xf32>}> : () -> tensor<128x1x1x1440xf32>
#     %34 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1440x1x1xf32>}> : () -> tensor<1x1440x1x1xf32>
#     %35 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1408xf32>}> : () -> tensor<128x1x1x1408xf32>
#     %36 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1408x1x1xf32>}> : () -> tensor<1x1408x1x1xf32>
#     %37 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1376xf32>}> : () -> tensor<128x1x1x1376xf32>
#     %38 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1376x1x1xf32>}> : () -> tensor<1x1376x1x1xf32>
#     %39 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1344xf32>}> : () -> tensor<128x1x1x1344xf32>
#     %40 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1344x1x1xf32>}> : () -> tensor<1x1344x1x1xf32>
#     %41 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1312xf32>}> : () -> tensor<128x1x1x1312xf32>
#     %42 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1312x1x1xf32>}> : () -> tensor<1x1312x1x1xf32>
#     %43 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1280xf32>}> : () -> tensor<128x1x1x1280xf32>
#     %44 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1280x1x1xf32>}> : () -> tensor<1x1280x1x1xf32>
#     %45 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1248xf32>}> : () -> tensor<128x1x1x1248xf32>
#     %46 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1248x1x1xf32>}> : () -> tensor<1x1248x1x1xf32>
#     %47 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1216xf32>}> : () -> tensor<128x1x1x1216xf32>
#     %48 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1216x1x1xf32>}> : () -> tensor<1x1216x1x1xf32>
#     %49 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1184xf32>}> : () -> tensor<128x1x1x1184xf32>
#     %50 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1184x1x1xf32>}> : () -> tensor<1x1184x1x1xf32>
#     %51 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1152xf32>}> : () -> tensor<128x1x1x1152xf32>
#     %52 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1152x1x1xf32>}> : () -> tensor<1x1152x1x1xf32>
#     %53 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1120xf32>}> : () -> tensor<128x1x1x1120xf32>
#     %54 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1120x1x1xf32>}> : () -> tensor<1x1120x1x1xf32>
#     %55 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1088xf32>}> : () -> tensor<128x1x1x1088xf32>
#     %56 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1088x1x1xf32>}> : () -> tensor<1x1088x1x1xf32>
#     %57 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1056xf32>}> : () -> tensor<128x1x1x1056xf32>
#     %58 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1056x1x1xf32>}> : () -> tensor<1x1056x1x1xf32>
#     %59 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x1024xf32>}> : () -> tensor<128x1x1x1024xf32>
#     %60 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x1024x1x1xf32>}> : () -> tensor<1x1024x1x1xf32>
#     %61 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x992xf32>}> : () -> tensor<128x1x1x992xf32>
#     %62 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x992x1x1xf32>}> : () -> tensor<1x992x1x1xf32>
#     %63 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x960xf32>}> : () -> tensor<128x1x1x960xf32>
#     %64 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x960x1x1xf32>}> : () -> tensor<1x960x1x1xf32>
#     %65 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x928xf32>}> : () -> tensor<128x1x1x928xf32>
#     %66 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x928x1x1xf32>}> : () -> tensor<1x928x1x1xf32>
#     %67 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x896xf32>}> : () -> tensor<128x1x1x896xf32>
#     %68 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x896x1x1xf32>}> : () -> tensor<1x896x1x1xf32>
#     %69 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x864xf32>}> : () -> tensor<128x1x1x864xf32>
#     %70 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x864x1x1xf32>}> : () -> tensor<1x864x1x1xf32>
#     %71 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x832xf32>}> : () -> tensor<128x1x1x832xf32>
#     %72 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x832x1x1xf32>}> : () -> tensor<1x832x1x1xf32>
#     %73 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x800xf32>}> : () -> tensor<128x1x1x800xf32>
#     %74 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x800x1x1xf32>}> : () -> tensor<1x800x1x1xf32>
#     %75 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x768xf32>}> : () -> tensor<128x1x1x768xf32>
#     %76 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x768x1x1xf32>}> : () -> tensor<1x768x1x1xf32>
#     %77 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x736xf32>}> : () -> tensor<128x1x1x736xf32>
#     %78 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x736x1x1xf32>}> : () -> tensor<1x736x1x1xf32>
#     %79 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x704xf32>}> : () -> tensor<128x1x1x704xf32>
#     %80 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x704x1x1xf32>}> : () -> tensor<1x704x1x1xf32>
#     %81 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x672xf32>}> : () -> tensor<128x1x1x672xf32>
#     %82 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x672x1x1xf32>}> : () -> tensor<1x672x1x1xf32>
#     %83 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x640xf32>}> : () -> tensor<128x1x1x640xf32>
#     %84 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x640x1x1xf32>}> : () -> tensor<1x640x1x1xf32>
#     %85 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x608xf32>}> : () -> tensor<128x1x1x608xf32>
#     %86 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x608x1x1xf32>}> : () -> tensor<1x608x1x1xf32>
#     %87 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x576xf32>}> : () -> tensor<128x1x1x576xf32>
#     %88 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x576x1x1xf32>}> : () -> tensor<1x576x1x1xf32>
#     %89 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x544xf32>}> : () -> tensor<128x1x1x544xf32>
#     %90 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x544x1x1xf32>}> : () -> tensor<1x544x1x1xf32>
#     %91 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x512xf32>}> : () -> tensor<128x1x1x512xf32>
#     %92 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<256xf32>}> : () -> tensor<256xf32>
#     %93 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<256x1x1x512xf32>}> : () -> tensor<256x1x1x512xf32>
#     %94 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x512x1x1xf32>}> : () -> tensor<1x512x1x1xf32>
#     %95 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x480xf32>}> : () -> tensor<128x1x1x480xf32>
#     %96 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x480x1x1xf32>}> : () -> tensor<1x480x1x1xf32>
#     %97 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x448xf32>}> : () -> tensor<128x1x1x448xf32>
#     %98 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x448x1x1xf32>}> : () -> tensor<1x448x1x1xf32>
#     %99 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x416xf32>}> : () -> tensor<128x1x1x416xf32>
#     %100 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x416x1x1xf32>}> : () -> tensor<1x416x1x1xf32>
#     %101 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x384xf32>}> : () -> tensor<128x1x1x384xf32>
#     %102 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x384x1x1xf32>}> : () -> tensor<1x384x1x1xf32>
#     %103 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x352xf32>}> : () -> tensor<128x1x1x352xf32>
#     %104 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x352x1x1xf32>}> : () -> tensor<1x352x1x1xf32>
#     %105 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x320xf32>}> : () -> tensor<128x1x1x320xf32>
#     %106 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x320x1x1xf32>}> : () -> tensor<1x320x1x1xf32>
#     %107 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x288xf32>}> : () -> tensor<128x1x1x288xf32>
#     %108 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x288x1x1xf32>}> : () -> tensor<1x288x1x1xf32>
#     %109 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x256xf32>}> : () -> tensor<128x1x1x256xf32>
#     %110 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x256x1x1xf32>}> : () -> tensor<1x256x1x1xf32>
#     %111 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x224xf32>}> : () -> tensor<128x1x1x224xf32>
#     %112 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x224x1x1xf32>}> : () -> tensor<1x224x1x1xf32>
#     %113 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x192xf32>}> : () -> tensor<128x1x1x192xf32>
#     %114 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x192x1x1xf32>}> : () -> tensor<1x192x1x1xf32>
#     %115 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x160xf32>}> : () -> tensor<128x1x1x160xf32>
#     %116 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x160x1x1xf32>}> : () -> tensor<1x160x1x1xf32>
#     %117 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x128xf32>}> : () -> tensor<128x1x1x128xf32>
#     %118 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x96xf32>}> : () -> tensor<128x1x1x96xf32>
#     %119 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x96x1x1xf32>}> : () -> tensor<1x96x1x1xf32>
#     %120 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<32xf32>}> : () -> tensor<32xf32>
#     %121 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<32x3x3x128xf32>}> : () -> tensor<32x3x3x128xf32>
#     %122 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x128x1x1xf32>}> : () -> tensor<1x128x1x1xf32>
#     %123 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<128xf32>}> : () -> tensor<128xf32>
#     %124 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<128x1x1x64xf32>}> : () -> tensor<128x1x1x64xf32>
#     %125 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<1x64x1x1xf32>}> : () -> tensor<1x64x1x1xf32>
#     %126 = "tosa.const"() <{value = dense<[0, 3, 1, 2]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %127 = "tosa.const"() <{value = dense<0.000000e+00> : tensor<64xf32>}> : () -> tensor<64xf32>
#     %128 = "tosa.const"() <{value = dense<[0, 2, 3, 1]> : tensor<4xi64>}> : () -> tensor<4xi64>
#     %129 = "tosa.const"() <{value = dense<7.777000e-02> : tensor<64x7x7x3xf32>}> : () -> tensor<64x7x7x3xf32>
#     %cst = arith.constant dense<0.000000e+00> : tensor<1x1920x7x7xf32>
#     %cst_0 = arith.constant dense<0.000000e+00> : tensor<1x1888x7x7xf32>
#     %cst_1 = arith.constant dense<0.000000e+00> : tensor<1x1856x7x7xf32>
#     %cst_2 = arith.constant dense<0.000000e+00> : tensor<1x1824x7x7xf32>
#     %cst_3 = arith.constant dense<0.000000e+00> : tensor<1x1792x7x7xf32>
#     %cst_4 = arith.constant dense<0.000000e+00> : tensor<1x1760x7x7xf32>
#     %cst_5 = arith.constant dense<0.000000e+00> : tensor<1x1728x7x7xf32>
#     %cst_6 = arith.constant dense<0.000000e+00> : tensor<1x1696x7x7xf32>
#     %cst_7 = arith.constant dense<0.000000e+00> : tensor<1x1664x7x7xf32>
#     %cst_8 = arith.constant dense<0.000000e+00> : tensor<1x1632x7x7xf32>
#     %cst_9 = arith.constant dense<0.000000e+00> : tensor<1x1600x7x7xf32>
#     %cst_10 = arith.constant dense<0.000000e+00> : tensor<1x1568x7x7xf32>
#     %cst_11 = arith.constant dense<0.000000e+00> : tensor<1x1536x7x7xf32>
#     %cst_12 = arith.constant dense<0.000000e+00> : tensor<1x1504x7x7xf32>
#     %cst_13 = arith.constant dense<0.000000e+00> : tensor<1x1472x7x7xf32>
#     %cst_14 = arith.constant dense<0.000000e+00> : tensor<1x1440x7x7xf32>
#     %cst_15 = arith.constant dense<0.000000e+00> : tensor<1x1408x7x7xf32>
#     %cst_16 = arith.constant dense<0.000000e+00> : tensor<1x1376x7x7xf32>
#     %cst_17 = arith.constant dense<0.000000e+00> : tensor<1x1344x7x7xf32>
#     %cst_18 = arith.constant dense<0.000000e+00> : tensor<1x1312x7x7xf32>
#     %cst_19 = arith.constant dense<0.000000e+00> : tensor<1x1280x7x7xf32>
#     %cst_20 = arith.constant dense<0.000000e+00> : tensor<1x1248x7x7xf32>
#     %cst_21 = arith.constant dense<0.000000e+00> : tensor<1x1216x7x7xf32>
#     %cst_22 = arith.constant dense<0.000000e+00> : tensor<1x1184x7x7xf32>
#     %cst_23 = arith.constant dense<0.000000e+00> : tensor<1x1152x7x7xf32>
#     %cst_24 = arith.constant dense<0.000000e+00> : tensor<1x1120x7x7xf32>
#     %cst_25 = arith.constant dense<0.000000e+00> : tensor<1x1088x7x7xf32>
#     %cst_26 = arith.constant dense<0.000000e+00> : tensor<1x1056x7x7xf32>
#     %cst_27 = arith.constant dense<0.000000e+00> : tensor<1x1024x7x7xf32>
#     %cst_28 = arith.constant dense<0.000000e+00> : tensor<1x992x7x7xf32>
#     %cst_29 = arith.constant dense<0.000000e+00> : tensor<1x960x7x7xf32>
#     %cst_30 = arith.constant dense<0.000000e+00> : tensor<1x928x7x7xf32>
#     %cst_31 = arith.constant dense<0.000000e+00> : tensor<1x1792x14x14xf32>
#     %cst_32 = arith.constant dense<0.000000e+00> : tensor<1x1760x14x14xf32>
#     %cst_33 = arith.constant dense<0.000000e+00> : tensor<1x1728x14x14xf32>
#     %cst_34 = arith.constant dense<0.000000e+00> : tensor<1x1696x14x14xf32>
#     %cst_35 = arith.constant dense<0.000000e+00> : tensor<1x1664x14x14xf32>
#     %cst_36 = arith.constant dense<0.000000e+00> : tensor<1x1632x14x14xf32>
#     %cst_37 = arith.constant dense<0.000000e+00> : tensor<1x1600x14x14xf32>
#     %cst_38 = arith.constant dense<0.000000e+00> : tensor<1x1568x14x14xf32>
#     %cst_39 = arith.constant dense<0.000000e+00> : tensor<1x1536x14x14xf32>
#     %cst_40 = arith.constant dense<0.000000e+00> : tensor<1x1504x14x14xf32>
#     %cst_41 = arith.constant dense<0.000000e+00> : tensor<1x1472x14x14xf32>
#     %cst_42 = arith.constant dense<0.000000e+00> : tensor<1x1440x14x14xf32>
#     %cst_43 = arith.constant dense<0.000000e+00> : tensor<1x1408x14x14xf32>
#     %cst_44 = arith.constant dense<0.000000e+00> : tensor<1x1376x14x14xf32>
#     %cst_45 = arith.constant dense<0.000000e+00> : tensor<1x1344x14x14xf32>
#     %cst_46 = arith.constant dense<0.000000e+00> : tensor<1x1312x14x14xf32>
#     %cst_47 = arith.constant dense<0.000000e+00> : tensor<1x1280x14x14xf32>
#     %cst_48 = arith.constant dense<0.000000e+00> : tensor<1x1248x14x14xf32>
#     %cst_49 = arith.constant dense<0.000000e+00> : tensor<1x1216x14x14xf32>
#     %cst_50 = arith.constant dense<0.000000e+00> : tensor<1x1184x14x14xf32>
#     %cst_51 = arith.constant dense<0.000000e+00> : tensor<1x1152x14x14xf32>
#     %cst_52 = arith.constant dense<0.000000e+00> : tensor<1x1120x14x14xf32>
#     %cst_53 = arith.constant dense<0.000000e+00> : tensor<1x1088x14x14xf32>
#     %cst_54 = arith.constant dense<0.000000e+00> : tensor<1x1056x14x14xf32>
#     %cst_55 = arith.constant dense<0.000000e+00> : tensor<1x1024x14x14xf32>
#     %cst_56 = arith.constant dense<0.000000e+00> : tensor<1x992x14x14xf32>
#     %cst_57 = arith.constant dense<0.000000e+00> : tensor<1x960x14x14xf32>
#     %cst_58 = arith.constant dense<0.000000e+00> : tensor<1x928x14x14xf32>
#     %cst_59 = arith.constant dense<0.000000e+00> : tensor<1x896x14x14xf32>
#     %cst_60 = arith.constant dense<0.000000e+00> : tensor<1x864x14x14xf32>
#     %cst_61 = arith.constant dense<0.000000e+00> : tensor<1x832x14x14xf32>
#     %cst_62 = arith.constant dense<0.000000e+00> : tensor<1x800x14x14xf32>
#     %cst_63 = arith.constant dense<0.000000e+00> : tensor<1x768x14x14xf32>
#     %cst_64 = arith.constant dense<0.000000e+00> : tensor<1x736x14x14xf32>
#     %cst_65 = arith.constant dense<0.000000e+00> : tensor<1x704x14x14xf32>
#     %cst_66 = arith.constant dense<0.000000e+00> : tensor<1x672x14x14xf32>
#     %cst_67 = arith.constant dense<0.000000e+00> : tensor<1x640x14x14xf32>
#     %cst_68 = arith.constant dense<0.000000e+00> : tensor<1x608x14x14xf32>
#     %cst_69 = arith.constant dense<0.000000e+00> : tensor<1x576x14x14xf32>
#     %cst_70 = arith.constant dense<0.000000e+00> : tensor<1x544x14x14xf32>
#     %cst_71 = arith.constant dense<0.000000e+00> : tensor<1x512x14x14xf32>
#     %cst_72 = arith.constant dense<0.000000e+00> : tensor<1x480x14x14xf32>
#     %cst_73 = arith.constant dense<0.000000e+00> : tensor<1x448x14x14xf32>
#     %cst_74 = arith.constant dense<0.000000e+00> : tensor<1x416x14x14xf32>
#     %cst_75 = arith.constant dense<0.000000e+00> : tensor<1x384x14x14xf32>
#     %cst_76 = arith.constant dense<0.000000e+00> : tensor<1x352x14x14xf32>
#     %cst_77 = arith.constant dense<0.000000e+00> : tensor<1x320x14x14xf32>
#     %cst_78 = arith.constant dense<0.000000e+00> : tensor<1x288x14x14xf32>
#     %cst_79 = arith.constant dense<0.000000e+00> : tensor<1x512x28x28xf32>
#     %cst_80 = arith.constant dense<0.000000e+00> : tensor<1x480x28x28xf32>
#     %cst_81 = arith.constant dense<0.000000e+00> : tensor<1x448x28x28xf32>
#     %cst_82 = arith.constant dense<0.000000e+00> : tensor<1x416x28x28xf32>
#     %cst_83 = arith.constant dense<0.000000e+00> : tensor<1x384x28x28xf32>
#     %cst_84 = arith.constant dense<0.000000e+00> : tensor<1x352x28x28xf32>
#     %cst_85 = arith.constant dense<0.000000e+00> : tensor<1x320x28x28xf32>
#     %cst_86 = arith.constant dense<0.000000e+00> : tensor<1x288x28x28xf32>
#     %cst_87 = arith.constant dense<0.000000e+00> : tensor<1x256x28x28xf32>
#     %cst_88 = arith.constant dense<0.000000e+00> : tensor<1x224x28x28xf32>
#     %cst_89 = arith.constant dense<0.000000e+00> : tensor<1x192x28x28xf32>
#     %cst_90 = arith.constant dense<0.000000e+00> : tensor<1x160x28x28xf32>
#     %cst_91 = arith.constant dense<0.000000e+00> : tensor<1x256x56x56xf32>
#     %cst_92 = arith.constant dense<0.000000e+00> : tensor<1x224x56x56xf32>
#     %cst_93 = arith.constant dense<0.000000e+00> : tensor<1x192x56x56xf32>
#     %cst_94 = arith.constant dense<0.000000e+00> : tensor<1x160x56x56xf32>
#     %cst_95 = arith.constant dense<0.000000e+00> : tensor<1x128x56x56xf32>
#     %cst_96 = arith.constant dense<0.000000e+00> : tensor<1x96x56x56xf32>
#     %130 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x64x1x1xf32>}> : () -> tensor<1x64x1x1xf32>
#     %131 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x128x1x1xf32>}> : () -> tensor<1x128x1x1xf32>
#     %132 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x96x1x1xf32>}> : () -> tensor<1x96x1x1xf32>
#     %133 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x160x1x1xf32>}> : () -> tensor<1x160x1x1xf32>
#     %134 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x192x1x1xf32>}> : () -> tensor<1x192x1x1xf32>
#     %135 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x224x1x1xf32>}> : () -> tensor<1x224x1x1xf32>
#     %136 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x256x1x1xf32>}> : () -> tensor<1x256x1x1xf32>
#     %137 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x288x1x1xf32>}> : () -> tensor<1x288x1x1xf32>
#     %138 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x320x1x1xf32>}> : () -> tensor<1x320x1x1xf32>
#     %139 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x352x1x1xf32>}> : () -> tensor<1x352x1x1xf32>
#     %140 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x384x1x1xf32>}> : () -> tensor<1x384x1x1xf32>
#     %141 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x416x1x1xf32>}> : () -> tensor<1x416x1x1xf32>
#     %142 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x448x1x1xf32>}> : () -> tensor<1x448x1x1xf32>
#     %143 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x480x1x1xf32>}> : () -> tensor<1x480x1x1xf32>
#     %144 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x512x1x1xf32>}> : () -> tensor<1x512x1x1xf32>
#     %145 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x544x1x1xf32>}> : () -> tensor<1x544x1x1xf32>
#     %146 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x576x1x1xf32>}> : () -> tensor<1x576x1x1xf32>
#     %147 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x608x1x1xf32>}> : () -> tensor<1x608x1x1xf32>
#     %148 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x640x1x1xf32>}> : () -> tensor<1x640x1x1xf32>
#     %149 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x672x1x1xf32>}> : () -> tensor<1x672x1x1xf32>
#     %150 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x704x1x1xf32>}> : () -> tensor<1x704x1x1xf32>
#     %151 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x736x1x1xf32>}> : () -> tensor<1x736x1x1xf32>
#     %152 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x768x1x1xf32>}> : () -> tensor<1x768x1x1xf32>
#     %153 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x800x1x1xf32>}> : () -> tensor<1x800x1x1xf32>
#     %154 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x832x1x1xf32>}> : () -> tensor<1x832x1x1xf32>
#     %155 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x864x1x1xf32>}> : () -> tensor<1x864x1x1xf32>
#     %156 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x896x1x1xf32>}> : () -> tensor<1x896x1x1xf32>
#     %157 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x928x1x1xf32>}> : () -> tensor<1x928x1x1xf32>
#     %158 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x960x1x1xf32>}> : () -> tensor<1x960x1x1xf32>
#     %159 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x992x1x1xf32>}> : () -> tensor<1x992x1x1xf32>
#     %160 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1024x1x1xf32>}> : () -> tensor<1x1024x1x1xf32>
#     %161 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1056x1x1xf32>}> : () -> tensor<1x1056x1x1xf32>
#     %162 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1088x1x1xf32>}> : () -> tensor<1x1088x1x1xf32>
#     %163 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1120x1x1xf32>}> : () -> tensor<1x1120x1x1xf32>
#     %164 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1152x1x1xf32>}> : () -> tensor<1x1152x1x1xf32>
#     %165 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1184x1x1xf32>}> : () -> tensor<1x1184x1x1xf32>
#     %166 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1216x1x1xf32>}> : () -> tensor<1x1216x1x1xf32>
#     %167 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1248x1x1xf32>}> : () -> tensor<1x1248x1x1xf32>
#     %168 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1280x1x1xf32>}> : () -> tensor<1x1280x1x1xf32>
#     %169 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1312x1x1xf32>}> : () -> tensor<1x1312x1x1xf32>
#     %170 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1344x1x1xf32>}> : () -> tensor<1x1344x1x1xf32>
#     %171 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1376x1x1xf32>}> : () -> tensor<1x1376x1x1xf32>
#     %172 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1408x1x1xf32>}> : () -> tensor<1x1408x1x1xf32>
#     %173 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1440x1x1xf32>}> : () -> tensor<1x1440x1x1xf32>
#     %174 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1472x1x1xf32>}> : () -> tensor<1x1472x1x1xf32>
#     %175 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1504x1x1xf32>}> : () -> tensor<1x1504x1x1xf32>
#     %176 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1536x1x1xf32>}> : () -> tensor<1x1536x1x1xf32>
#     %177 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1568x1x1xf32>}> : () -> tensor<1x1568x1x1xf32>
#     %178 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1600x1x1xf32>}> : () -> tensor<1x1600x1x1xf32>
#     %179 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1632x1x1xf32>}> : () -> tensor<1x1632x1x1xf32>
#     %180 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1664x1x1xf32>}> : () -> tensor<1x1664x1x1xf32>
#     %181 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1696x1x1xf32>}> : () -> tensor<1x1696x1x1xf32>
#     %182 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1728x1x1xf32>}> : () -> tensor<1x1728x1x1xf32>
#     %183 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1760x1x1xf32>}> : () -> tensor<1x1760x1x1xf32>
#     %184 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1792x1x1xf32>}> : () -> tensor<1x1792x1x1xf32>
#     %185 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1824x1x1xf32>}> : () -> tensor<1x1824x1x1xf32>
#     %186 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1856x1x1xf32>}> : () -> tensor<1x1856x1x1xf32>
#     %187 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1888x1x1xf32>}> : () -> tensor<1x1888x1x1xf32>
#     %188 = "tosa.const"() <{value = dense<7.778000e-02> : tensor<1x1920x1x1xf32>}> : () -> tensor<1x1920x1x1xf32>
#     ml_program.global_store @global0 = %arg0 : tensor<1x3x224x224xf32>
#     %189 = tosa.transpose %arg0, %128 : (tensor<1x3x224x224xf32>, tensor<4xi64>) -> tensor<1x224x224x3xf32>
#     %190 = tosa.conv2d %189, %129, %127 {dilation = array<i64: 1, 1>, pad = array<i64: 3, 3, 3, 3>, stride = array<i64: 2, 2>} : (tensor<1x224x224x3xf32>, tensor<64x7x7x3xf32>, tensor<64xf32>) -> tensor<1x112x112x64xf32>
#     %191 = tosa.transpose %190, %126 : (tensor<1x112x112x64xf32>, tensor<4xi64>) -> tensor<1x64x112x112xf32>
#     %192 = tosa.sub %191, %125 : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %193 = tosa.rsqrt %130 : (tensor<1x64x1x1xf32>) -> tensor<1x64x1x1xf32>
#     %194 = tosa.mul %192, %193 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %195 = tosa.mul %194, %125 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %196 = tosa.add %195, %125 : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %197 = tosa.clamp %196 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xf32>
#     %198 = tosa.transpose %197, %128 : (tensor<1x64x112x112xf32>, tensor<4xi64>) -> tensor<1x112x112x64xf32>
#     %199 = tosa.max_pool2d %198 {kernel = array<i64: 3, 3>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>) -> tensor<1x56x56x64xf32>
#     %200 = tosa.transpose %199, %126 : (tensor<1x56x56x64xf32>, tensor<4xi64>) -> tensor<1x64x56x56xf32>
#     %201 = tosa.sub %200, %125 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %202 = tosa.mul %201, %193 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %203 = tosa.mul %202, %125 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %204 = tosa.add %203, %125 : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %205 = tosa.clamp %204 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %206 = tosa.transpose %205, %128 : (tensor<1x64x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x64xf32>
#     %207 = tosa.conv2d %206, %124, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x64xf32>, tensor<128x1x1x64xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %208 = tosa.transpose %207, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %209 = tosa.sub %208, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %210 = tosa.rsqrt %131 : (tensor<1x128x1x1xf32>) -> tensor<1x128x1x1xf32>
#     %211 = tosa.mul %209, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %212 = tosa.mul %211, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %213 = tosa.add %212, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %214 = tosa.clamp %213 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %215 = tosa.transpose %214, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %216 = tosa.conv2d %215, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %217 = tosa.transpose %216, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice = tensor.insert_slice %200 into %cst_96[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x96x56x56xf32>
#     %inserted_slice_97 = tensor.insert_slice %217 into %inserted_slice[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x96x56x56xf32>
#     %218 = tosa.sub %inserted_slice_97, %119 : (tensor<1x96x56x56xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x56x56xf32>
#     %219 = tosa.rsqrt %132 : (tensor<1x96x1x1xf32>) -> tensor<1x96x1x1xf32>
#     %220 = tosa.mul %218, %219 {shift = 0 : i8} : (tensor<1x96x56x56xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x56x56xf32>
#     %221 = tosa.mul %220, %119 {shift = 0 : i8} : (tensor<1x96x56x56xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x56x56xf32>
#     %222 = tosa.add %221, %119 : (tensor<1x96x56x56xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x56x56xf32>
#     %223 = tosa.clamp %222 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x96x56x56xf32>) -> tensor<1x96x56x56xf32>
#     %224 = tosa.transpose %223, %128 : (tensor<1x96x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x96xf32>
#     %225 = tosa.conv2d %224, %118, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x96xf32>, tensor<128x1x1x96xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %226 = tosa.transpose %225, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %227 = tosa.sub %226, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %228 = tosa.mul %227, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %229 = tosa.mul %228, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %230 = tosa.add %229, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %231 = tosa.clamp %230 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %232 = tosa.transpose %231, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %233 = tosa.conv2d %232, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %234 = tosa.transpose %233, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice_98 = tensor.insert_slice %200 into %cst_95[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x128x56x56xf32>
#     %inserted_slice_99 = tensor.insert_slice %217 into %inserted_slice_98[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x128x56x56xf32>
#     %inserted_slice_100 = tensor.insert_slice %234 into %inserted_slice_99[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x128x56x56xf32>
#     %235 = tosa.sub %inserted_slice_100, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %236 = tosa.mul %235, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %237 = tosa.mul %236, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %238 = tosa.add %237, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %239 = tosa.clamp %238 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %240 = tosa.transpose %239, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %241 = tosa.conv2d %240, %117, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x1x1x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %242 = tosa.transpose %241, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %243 = tosa.sub %242, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %244 = tosa.mul %243, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %245 = tosa.mul %244, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %246 = tosa.add %245, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %247 = tosa.clamp %246 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %248 = tosa.transpose %247, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %249 = tosa.conv2d %248, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %250 = tosa.transpose %249, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice_101 = tensor.insert_slice %200 into %cst_94[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x160x56x56xf32>
#     %inserted_slice_102 = tensor.insert_slice %217 into %inserted_slice_101[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x160x56x56xf32>
#     %inserted_slice_103 = tensor.insert_slice %234 into %inserted_slice_102[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x160x56x56xf32>
#     %inserted_slice_104 = tensor.insert_slice %250 into %inserted_slice_103[0, 128, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x160x56x56xf32>
#     %251 = tosa.sub %inserted_slice_104, %116 : (tensor<1x160x56x56xf32>, tensor<1x160x1x1xf32>) -> tensor<1x160x56x56xf32>
#     %252 = tosa.rsqrt %133 : (tensor<1x160x1x1xf32>) -> tensor<1x160x1x1xf32>
#     %253 = tosa.mul %251, %252 {shift = 0 : i8} : (tensor<1x160x56x56xf32>, tensor<1x160x1x1xf32>) -> tensor<1x160x56x56xf32>
#     %254 = tosa.mul %253, %116 {shift = 0 : i8} : (tensor<1x160x56x56xf32>, tensor<1x160x1x1xf32>) -> tensor<1x160x56x56xf32>
#     %255 = tosa.add %254, %116 : (tensor<1x160x56x56xf32>, tensor<1x160x1x1xf32>) -> tensor<1x160x56x56xf32>
#     %256 = tosa.clamp %255 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x160x56x56xf32>) -> tensor<1x160x56x56xf32>
#     %257 = tosa.transpose %256, %128 : (tensor<1x160x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x160xf32>
#     %258 = tosa.conv2d %257, %115, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x160xf32>, tensor<128x1x1x160xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %259 = tosa.transpose %258, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %260 = tosa.sub %259, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %261 = tosa.mul %260, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %262 = tosa.mul %261, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %263 = tosa.add %262, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %264 = tosa.clamp %263 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %265 = tosa.transpose %264, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %266 = tosa.conv2d %265, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %267 = tosa.transpose %266, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice_105 = tensor.insert_slice %200 into %cst_93[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x192x56x56xf32>
#     %inserted_slice_106 = tensor.insert_slice %217 into %inserted_slice_105[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x192x56x56xf32>
#     %inserted_slice_107 = tensor.insert_slice %234 into %inserted_slice_106[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x192x56x56xf32>
#     %inserted_slice_108 = tensor.insert_slice %250 into %inserted_slice_107[0, 128, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x192x56x56xf32>
#     %inserted_slice_109 = tensor.insert_slice %267 into %inserted_slice_108[0, 160, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x192x56x56xf32>
#     %268 = tosa.sub %inserted_slice_109, %114 : (tensor<1x192x56x56xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x56x56xf32>
#     %269 = tosa.rsqrt %134 : (tensor<1x192x1x1xf32>) -> tensor<1x192x1x1xf32>
#     %270 = tosa.mul %268, %269 {shift = 0 : i8} : (tensor<1x192x56x56xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x56x56xf32>
#     %271 = tosa.mul %270, %114 {shift = 0 : i8} : (tensor<1x192x56x56xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x56x56xf32>
#     %272 = tosa.add %271, %114 : (tensor<1x192x56x56xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x56x56xf32>
#     %273 = tosa.clamp %272 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x192x56x56xf32>) -> tensor<1x192x56x56xf32>
#     %274 = tosa.transpose %273, %128 : (tensor<1x192x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x192xf32>
#     %275 = tosa.conv2d %274, %113, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x192xf32>, tensor<128x1x1x192xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %276 = tosa.transpose %275, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %277 = tosa.sub %276, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %278 = tosa.mul %277, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %279 = tosa.mul %278, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %280 = tosa.add %279, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %281 = tosa.clamp %280 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %282 = tosa.transpose %281, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %283 = tosa.conv2d %282, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %284 = tosa.transpose %283, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice_110 = tensor.insert_slice %200 into %cst_92[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x224x56x56xf32>
#     %inserted_slice_111 = tensor.insert_slice %217 into %inserted_slice_110[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x224x56x56xf32>
#     %inserted_slice_112 = tensor.insert_slice %234 into %inserted_slice_111[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x224x56x56xf32>
#     %inserted_slice_113 = tensor.insert_slice %250 into %inserted_slice_112[0, 128, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x224x56x56xf32>
#     %inserted_slice_114 = tensor.insert_slice %267 into %inserted_slice_113[0, 160, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x224x56x56xf32>
#     %inserted_slice_115 = tensor.insert_slice %284 into %inserted_slice_114[0, 192, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x32x56x56xf32> into tensor<1x224x56x56xf32>
#     %285 = tosa.sub %inserted_slice_115, %112 : (tensor<1x224x56x56xf32>, tensor<1x224x1x1xf32>) -> tensor<1x224x56x56xf32>
#     %286 = tosa.rsqrt %135 : (tensor<1x224x1x1xf32>) -> tensor<1x224x1x1xf32>
#     %287 = tosa.mul %285, %286 {shift = 0 : i8} : (tensor<1x224x56x56xf32>, tensor<1x224x1x1xf32>) -> tensor<1x224x56x56xf32>
#     %288 = tosa.mul %287, %112 {shift = 0 : i8} : (tensor<1x224x56x56xf32>, tensor<1x224x1x1xf32>) -> tensor<1x224x56x56xf32>
#     %289 = tosa.add %288, %112 : (tensor<1x224x56x56xf32>, tensor<1x224x1x1xf32>) -> tensor<1x224x56x56xf32>
#     %290 = tosa.clamp %289 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x224x56x56xf32>) -> tensor<1x224x56x56xf32>
#     %291 = tosa.transpose %290, %128 : (tensor<1x224x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x224xf32>
#     %292 = tosa.conv2d %291, %111, %123 {dilation = array<i64: 1, 1>, pad = array<i64: 0, 0, 0, 0>, stride = array<i64: 1, 1>} : (tensor<1x56x56x224xf32>, tensor<128x1x1x224xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %293 = tosa.transpose %292, %126 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %294 = tosa.sub %293, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %295 = tosa.mul %294, %210 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %296 = tosa.mul %295, %122 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %297 = tosa.add %296, %122 : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %298 = tosa.clamp %297 {max_fp = 3.40282347E+38 : f32, max_int = 2147483647 : i64, min_fp = 0.000000e+00 : f32, min_int = 0 : i64} : (tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %299 = tosa.transpose %298, %128 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %300 = tosa.conv2d %299, %121, %120 {dilation = array<i64: 1, 1>, pad = array<i64: 1, 1, 1, 1>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<32x3x3x128xf32>, tensor<32xf32>) -> tensor<1x56x56x32xf32>
#     %301 = tosa.transpose %300, %126 : (tensor<1x56x56x32xf32>, tensor<4xi64>) -> tensor<1x32x56x56xf32>
#     %inserted_slice_116 = tensor.insert_slice %200 into %cst_91[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x64x56x56xf32> into tensor<1x256x56x56xf32>
# ...
#     %5044 = tosa.transpose %5038, %189 : (tensor<1x32x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x32xf32>
#     %5045 = tosa.transpose_conv2d %5044, %60, %cst_63 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x32xf32>, tensor<128x3x3x32xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5046 = tosa.transpose %5045, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5047 = tosa.equal %341, %342 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5048 = tosa.select %5047, %5046, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5049 = tosa.mul %5048, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5050 = tosa.mul %271, %5049 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %5051 = tosa.transpose %5050, %189 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %5052 = tosa.transpose_conv2d %5051, %4, %cst_6 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 192>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<192x1x1x128xf32>, tensor<192xf32>) -> tensor<1x56x56x192xf32>
#     %5053 = tosa.transpose %5052, %187 : (tensor<1x56x56x192xf32>, tensor<4xi64>) -> tensor<1x192x56x56xf32>
#     %5054 = tosa.equal %333, %334 : (tensor<1x192x56x56xf32>, tensor<1x192x56x56xf32>) -> tensor<1x192x56x56xi1>
#     %5055 = tosa.select %5054, %5053, %61 : (tensor<1x192x56x56xi1>, tensor<1x192x56x56xf32>, tensor<f32>) -> tensor<1x192x56x56xf32>
#     %5056 = tosa.mul %5055, %175 {shift = 0 : i8} : (tensor<1x192x56x56xf32>, tensor<1x192x1x1xf32>) -> tensor<1x192x56x56xf32>
#     %5057 = tosa.mul %330, %5056 {shift = 0 : i8} : (tensor<1x192x1x1xf32>, tensor<1x192x56x56xf32>) -> tensor<1x192x56x56xf32>
#     %extracted_slice_3954 = tensor.extract_slice %5057[0, 160, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x192x56x56xf32> to tensor<1x32x56x56xf32>
#     %5058 = tosa.add %5039, %extracted_slice_3954 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3955 = tensor.extract_slice %5057[0, 128, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x192x56x56xf32> to tensor<1x32x56x56xf32>
#     %5059 = tosa.add %5040, %extracted_slice_3955 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3956 = tensor.extract_slice %5057[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x192x56x56xf32> to tensor<1x32x56x56xf32>
#     %5060 = tosa.add %5041, %extracted_slice_3956 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3957 = tensor.extract_slice %5057[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x192x56x56xf32> to tensor<1x32x56x56xf32>
#     %5061 = tosa.add %5042, %extracted_slice_3957 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3958 = tensor.extract_slice %5057[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x192x56x56xf32> to tensor<1x64x56x56xf32>
#     %5062 = tosa.add %5043, %extracted_slice_3958 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5063 = tosa.transpose %5058, %189 : (tensor<1x32x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x32xf32>
#     %5064 = tosa.transpose_conv2d %5063, %60, %cst_63 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x32xf32>, tensor<128x3x3x32xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5065 = tosa.transpose %5064, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5066 = tosa.equal %324, %325 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5067 = tosa.select %5066, %5065, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5068 = tosa.mul %5067, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5069 = tosa.mul %271, %5068 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %5070 = tosa.transpose %5069, %189 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %5071 = tosa.transpose_conv2d %5070, %3, %cst_5 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 160>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<160x1x1x128xf32>, tensor<160xf32>) -> tensor<1x56x56x160xf32>
#     %5072 = tosa.transpose %5071, %187 : (tensor<1x56x56x160xf32>, tensor<4xi64>) -> tensor<1x160x56x56xf32>
#     %5073 = tosa.equal %316, %317 : (tensor<1x160x56x56xf32>, tensor<1x160x56x56xf32>) -> tensor<1x160x56x56xi1>
#     %5074 = tosa.select %5073, %5072, %61 : (tensor<1x160x56x56xi1>, tensor<1x160x56x56xf32>, tensor<f32>) -> tensor<1x160x56x56xf32>
#     %5075 = tosa.mul %5074, %177 {shift = 0 : i8} : (tensor<1x160x56x56xf32>, tensor<1x160x1x1xf32>) -> tensor<1x160x56x56xf32>
#     %5076 = tosa.mul %313, %5075 {shift = 0 : i8} : (tensor<1x160x1x1xf32>, tensor<1x160x56x56xf32>) -> tensor<1x160x56x56xf32>
#     %extracted_slice_3959 = tensor.extract_slice %5076[0, 128, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x160x56x56xf32> to tensor<1x32x56x56xf32>
#     %5077 = tosa.add %5059, %extracted_slice_3959 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3960 = tensor.extract_slice %5076[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x160x56x56xf32> to tensor<1x32x56x56xf32>
#     %5078 = tosa.add %5060, %extracted_slice_3960 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3961 = tensor.extract_slice %5076[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x160x56x56xf32> to tensor<1x32x56x56xf32>
#     %5079 = tosa.add %5061, %extracted_slice_3961 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3962 = tensor.extract_slice %5076[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x160x56x56xf32> to tensor<1x64x56x56xf32>
#     %5080 = tosa.add %5062, %extracted_slice_3962 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5081 = tosa.transpose %5077, %189 : (tensor<1x32x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x32xf32>
#     %5082 = tosa.transpose_conv2d %5081, %60, %cst_63 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x32xf32>, tensor<128x3x3x32xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5083 = tosa.transpose %5082, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5084 = tosa.equal %307, %308 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5085 = tosa.select %5084, %5083, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5086 = tosa.mul %5085, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5087 = tosa.mul %271, %5086 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %5088 = tosa.transpose %5087, %189 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %5089 = tosa.transpose_conv2d %5088, %178, %cst_63 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<128x1x1x128xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5090 = tosa.transpose %5089, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5091 = tosa.equal %299, %300 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5092 = tosa.select %5091, %5090, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5093 = tosa.mul %5092, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5094 = tosa.mul %271, %5093 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %extracted_slice_3963 = tensor.extract_slice %5094[0, 96, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x128x56x56xf32> to tensor<1x32x56x56xf32>
#     %5095 = tosa.add %5078, %extracted_slice_3963 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3964 = tensor.extract_slice %5094[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x128x56x56xf32> to tensor<1x32x56x56xf32>
#     %5096 = tosa.add %5079, %extracted_slice_3964 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3965 = tensor.extract_slice %5094[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x128x56x56xf32> to tensor<1x64x56x56xf32>
#     %5097 = tosa.add %5080, %extracted_slice_3965 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5098 = tosa.transpose %5095, %189 : (tensor<1x32x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x32xf32>
#     %5099 = tosa.transpose_conv2d %5098, %60, %cst_63 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x32xf32>, tensor<128x3x3x32xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5100 = tosa.transpose %5099, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5101 = tosa.equal %291, %292 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5102 = tosa.select %5101, %5100, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5103 = tosa.mul %5102, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5104 = tosa.mul %271, %5103 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %5105 = tosa.transpose %5104, %189 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %5106 = tosa.transpose_conv2d %5105, %2, %cst_3 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 96>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<96x1x1x128xf32>, tensor<96xf32>) -> tensor<1x56x56x96xf32>
#     %5107 = tosa.transpose %5106, %187 : (tensor<1x56x56x96xf32>, tensor<4xi64>) -> tensor<1x96x56x56xf32>
#     %5108 = tosa.equal %283, %284 : (tensor<1x96x56x56xf32>, tensor<1x96x56x56xf32>) -> tensor<1x96x56x56xi1>
#     %5109 = tosa.select %5108, %5107, %61 : (tensor<1x96x56x56xi1>, tensor<1x96x56x56xf32>, tensor<f32>) -> tensor<1x96x56x56xf32>
#     %5110 = tosa.mul %5109, %180 {shift = 0 : i8} : (tensor<1x96x56x56xf32>, tensor<1x96x1x1xf32>) -> tensor<1x96x56x56xf32>
#     %5111 = tosa.mul %280, %5110 {shift = 0 : i8} : (tensor<1x96x1x1xf32>, tensor<1x96x56x56xf32>) -> tensor<1x96x56x56xf32>
#     %extracted_slice_3966 = tensor.extract_slice %5111[0, 64, 0, 0] [1, 32, 56, 56] [1, 1, 1, 1] : tensor<1x96x56x56xf32> to tensor<1x32x56x56xf32>
#     %5112 = tosa.add %5096, %extracted_slice_3966 : (tensor<1x32x56x56xf32>, tensor<1x32x56x56xf32>) -> tensor<1x32x56x56xf32>
#     %extracted_slice_3967 = tensor.extract_slice %5111[0, 0, 0, 0] [1, 64, 56, 56] [1, 1, 1, 1] : tensor<1x96x56x56xf32> to tensor<1x64x56x56xf32>
#     %5113 = tosa.add %5097, %extracted_slice_3967 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5114 = tosa.transpose %5112, %189 : (tensor<1x32x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x32xf32>
#     %5115 = tosa.transpose_conv2d %5114, %60, %cst_63 {out_pad = array<i64: -1, -1, -1, -1>, out_shape = array<i64: 1, 56, 56, 128>, stride = array<i64: 1, 1>} : (tensor<1x56x56x32xf32>, tensor<128x3x3x32xf32>, tensor<128xf32>) -> tensor<1x56x56x128xf32>
#     %5116 = tosa.transpose %5115, %187 : (tensor<1x56x56x128xf32>, tensor<4xi64>) -> tensor<1x128x56x56xf32>
#     %5117 = tosa.equal %274, %275 : (tensor<1x128x56x56xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xi1>
#     %5118 = tosa.select %5117, %5116, %61 : (tensor<1x128x56x56xi1>, tensor<1x128x56x56xf32>, tensor<f32>) -> tensor<1x128x56x56xf32>
#     %5119 = tosa.mul %5118, %183 {shift = 0 : i8} : (tensor<1x128x56x56xf32>, tensor<1x128x1x1xf32>) -> tensor<1x128x56x56xf32>
#     %5120 = tosa.mul %271, %5119 {shift = 0 : i8} : (tensor<1x128x1x1xf32>, tensor<1x128x56x56xf32>) -> tensor<1x128x56x56xf32>
#     %5121 = tosa.transpose %5120, %189 : (tensor<1x128x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x128xf32>
#     %5122 = tosa.transpose_conv2d %5121, %1, %cst_2 {out_pad = array<i64: 0, 0, 0, 0>, out_shape = array<i64: 1, 56, 56, 64>, stride = array<i64: 1, 1>} : (tensor<1x56x56x128xf32>, tensor<64x1x1x128xf32>, tensor<64xf32>) -> tensor<1x56x56x64xf32>
#     %5123 = tosa.transpose %5122, %187 : (tensor<1x56x56x64xf32>, tensor<4xi64>) -> tensor<1x64x56x56xf32>
#     %5124 = tosa.equal %265, %266 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xi1>
#     %5125 = tosa.select %5124, %5123, %61 : (tensor<1x64x56x56xi1>, tensor<1x64x56x56xf32>, tensor<f32>) -> tensor<1x64x56x56xf32>
#     %5126 = tosa.mul %5125, %186 {shift = 0 : i8} : (tensor<1x64x56x56xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x56x56xf32>
#     %5127 = tosa.mul %254, %5126 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5128 = tosa.add %5113, %5127 : (tensor<1x64x56x56xf32>, tensor<1x64x56x56xf32>) -> tensor<1x64x56x56xf32>
#     %5129 = tosa.transpose %5128, %189 : (tensor<1x64x56x56xf32>, tensor<4xi64>) -> tensor<1x56x56x64xf32>
#     %padded = tensor.pad %259 low[0, 1, 1, 0] high[0, 1, 1, 0] {
#     ^bb0(%arg1: index, %arg2: index, %arg3: index, %arg4: index):
#       tensor.yield %cst_67 : f32
#     } : tensor<1x112x112x64xf32> to tensor<1x114x114x64xf32>
#     %5130 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%padded, %cst_0, %260, %5129 : tensor<1x114x114x64xf32>, tensor<3x3xf32>, tensor<1x56x56x64xf32>, tensor<1x56x56x64xf32>) outs(%cst_1 : tensor<1x114x114x64xf32>) {
#     ^bb0(%in: f32, %in_3969: f32, %in_3970: f32, %in_3971: f32, %out: f32):
#       %5139 = arith.cmpf oge, %in, %in_3970 : f32
#       %5140 = arith.select %5139, %in_3971, %cst_66 : f32
#       %5141 = arith.addf %out, %5140 : f32
#       linalg.yield %5141 : f32
#     } -> tensor<1x114x114x64xf32>
#     %extracted_slice_3968 = tensor.extract_slice %5130[0, 1, 1, 0] [1, 112, 112, 64] [1, 1, 1, 1] : tensor<1x114x114x64xf32> to tensor<1x112x112x64xf32>
#     %5131 = tosa.transpose %extracted_slice_3968, %187 : (tensor<1x112x112x64xf32>, tensor<4xi64>) -> tensor<1x64x112x112xf32>
#     %5132 = tosa.equal %257, %258 : (tensor<1x64x112x112xf32>, tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xi1>
#     %5133 = tosa.select %5132, %5131, %61 : (tensor<1x64x112x112xi1>, tensor<1x64x112x112xf32>, tensor<f32>) -> tensor<1x64x112x112xf32>
#     %5134 = tosa.mul %5133, %186 {shift = 0 : i8} : (tensor<1x64x112x112xf32>, tensor<1x64x1x1xf32>) -> tensor<1x64x112x112xf32>
#     %5135 = tosa.mul %254, %5134 {shift = 0 : i8} : (tensor<1x64x1x1xf32>, tensor<1x64x112x112xf32>) -> tensor<1x64x112x112xf32>
#     %5136 = tosa.transpose %5135, %189 : (tensor<1x64x112x112xf32>, tensor<4xi64>) -> tensor<1x112x112x64xf32>
#     %5137 = tosa.transpose_conv2d %5136, %0, %cst {out_pad = array<i64: -3, -3, -3, -3>, out_shape = array<i64: 1, 224, 224, 3>, stride = array<i64: 2, 2>} : (tensor<1x112x112x64xf32>, tensor<3x7x7x64xf32>, tensor<3xf32>) -> tensor<1x224x224x3xf32>
#     %5138 = tosa.transpose %5137, %187 : (tensor<1x224x224x3xf32>, tensor<4xi64>) -> tensor<1x3x224x224xf32>
#     return %5138 : tensor<1x3x224x224xf32>
#   }
# }

# %%
# !ragdoll-opt --help | grep const
# Out:
#       --convert-scf-to-openmp                                -   Convert SCF parallel loop to OpenMP parallel + workshare constructs.
#       --convert-shape-constraints                            -   Convert shape constraint operations to the standard dialect
#       --expand-strided-metadata                              -   Expand memref operations into easier to analyze constructs
#       --remove-shape-constraints                             -   Replace all cstr_ ops with a true witness
#       --tosa-layerwise-constant-fold                         -   Fold layerwise operations on constant tensors
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimizationMay add more tosa.const but would reduce runtime calculations
#         --aggressive-reduce-constant                         - Always perform the reduce constant optimization
