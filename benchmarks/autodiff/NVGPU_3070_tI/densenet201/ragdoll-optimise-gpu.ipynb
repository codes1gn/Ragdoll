# %%
model_name = "densenet201-ragdoll"
model_file = "densenet201.mlir.v1"

import iree
import iree.compiler
import iree.runtime
import torch
import numpy as np
from torch import nn
from torchvision import models

import warnings
warnings.filterwarnings("ignore")

from timeit import timeit as ti
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from ragdoll.compiler import *
from ragdoll.benchmark import *
import ragdoll

def get_dataframe(forward, backward, item):
    return pd.concat([
        pd.DataFrame({
            "time": forward,
            "pass": "Forward",
            "item": item
        }, index=[0]),
        pd.DataFrame({
            "time": backward,
            "pass": "Backward",
            "item": item
        }, index=[0]),
        pd.DataFrame({
            "time": forward + backward,
            "pass": "Full",
            "item": item
        }, index=[0]),
    ])

def timeit(stmt, n=33):
    return ti(stmt, globals=globals(), number=n) * 1000 / n

image = torch.randn(1, 3, 224, 224)
image_np = image.detach().cpu().numpy()
image_transposed = torch.randn(1, 224, 224, 3)
image_np_transposed = image_transposed.detach().cpu().numpy()
model = models.densenet201().train(False)
model.load_state_dict({k: torch.ones_like(v) * 0.23421 for k, v in model.state_dict().items()})
output = model(image)
grad = torch.randn_like(output)
grad_np = grad.cpu().numpy()

BENCHMARK_REPEAT=33
df = pd.DataFrame()

# %% [raw]
# !iree-compile {model_file}.heuristic{"-mulswap"} \
# -o {model_file}.heuristic{"-mulswap"}.vmfb \
# --iree-hal-target-backends=cuda \
# --iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
# --iree-hal-cuda-llvm-target-arch=sm_86

# %%
#!iree-compile recompute.mlir \
# !iree-compile {model_file}.recompute \
-o {model_file}.recompute.vmfb \
--iree-hal-target-backends=cuda \
--iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
--iree-hal-cuda-llvm-target-arch=sm_86

# !iree-compile {model_file}.storeall \
-o {model_file}.storeall.vmfb \
--iree-hal-target-backends=cuda \
--iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
--iree-hal-cuda-llvm-target-arch=sm_86

"""
# !iree-compile {model_file}.hybrid \
-o {model_file}.hybrid.vmfb \
--iree-hal-target-backends=cuda \
--iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
--iree-hal-cuda-llvm-target-arch=sm_86
"""

# !iree-compile {model_file}.heuristic \
-o {model_file}.heuristic.vmfb \
--iree-hal-target-backends=cuda \
--iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
--iree-hal-cuda-llvm-target-arch=sm_86

#!iree-compile {model_file}.heuristic{"-mulswap"} \
#-o {model_file}.heuristic{"-mulswap"}.vmfb \
#--iree-hal-target-backends=cuda \
#--iree-hal-benchmark-dispatch-repeat-count={BENCHMARK_REPEAT} \
#--iree-hal-cuda-llvm-target-arch=sm_86

recompute = model_file+".recompute.vmfb"
storeall = model_file+".storeall.vmfb"
#hybrid = model_file+".hybrid.vmfb"
heuristic = model_file+".heuristic.vmfb"
#heuristic2 = model_file+".heuristic-mulswap.vmfb"

def load_executable(fb_file):
    config = iree.runtime.system_api.Config("cuda")
    vmi = iree.runtime.VmInstance()
    # replace compile with args of fatbin type
    # fb_file = ragdoll.compile(mlir, "gpu", "input", "codegen", benchmark=True)
    with open(fb_file, 'rb') as f:
        binary_data = f.read()
    vmm = iree.runtime.VmModule.from_flatbuffer(vmi, binary_data)
    vmo = iree.runtime.load_vm_module(vmm, config)
    return vmo

#recompute_fb, storeall_fb = [
#    load_executable(x) for x in [recompute, storeall]
#]
recompute_fb = load_executable(recompute)
storeall_fb = load_executable(storeall)
#hybrid_fb = load_executable(hybrid)
heuristic_fb = load_executable(heuristic)
#heuristic2_fb = load_executable(heuristic2)
# Out:
# densenet201.mlir.v1.recompute:12853:13: error: expected 7 offset values, got 5
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.recompute:3875:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.recompute:12853:13: note: see current operation: %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.recompute:12853:13: error: failed to run translation of source executable to target executable for backend #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.recompute:3875:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.recompute:12853:13: note: see current operation:
# "hal.executable.variant"() ({
#   "hal.executable.export"() ({
#   ^bb0(%arg0: !hal.device):
#     %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#     %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#     "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#   }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_1067_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#   "builtin.module"() ({
#     "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_1067_generic_128x28x28x2x2_f32"}> ({
#       %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#       %1 = "arith.constant"() <{value = 23028928 : index}> : () -> index
#       %2 = "arith.constant"() <{value = 14197952 : index}> : () -> index
#       %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#       %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#       %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
#       %6 = "hal.interface.binding.subspan"(%2) {alignment = 64 : index, binding = 1 : index, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>
#       %7 = "hal.interface.workgroup.id"() {dimension = 0 : index} : () -> index
#       %8 = "flow.dispatch.tensor.load"(%6, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> tensor<56x56x1xf32>
#       %9 = "flow.dispatch.tensor.load"(%5, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 28, 28, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>, index) -> tensor<28x28x1xf32>
#       %10 = "linalg.fill"(%4, %8) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         "linalg.yield"(%arg0) : (f32) -> ()
#       }) {lowering_config = #iree_codegen.lowering_config<tile_sizes = [[1], [0, 4, 4, 2, 2]]>} : (f32, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#       %11 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %12 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %13 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %14 = "arith.constant"() <{value = 2 : index}> : () -> index
#       %15 = "arith.constant"() <{value = 2 : index}> : () -> index
#       %16 = "tensor.empty"() : () -> tensor<56x4x4x2x2x56x1xf32>
#       %17 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#       %18 = "linalg.fill"(%17, %16) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         "linalg.yield"(%arg0) : (f32) -> ()
#       }) : (f32, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#       %19 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %20 = "arith.constant"() <{value = 1 : index}> : () -> index
#       %21 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %22 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %23 = "arith.constant"() <{value = 28 : index}> : () -> index
#       %24 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %25 = "scf.for"(%22, %23, %24, %18) ({
#       ^bb0(%arg0: index, %arg1: tensor<56x4x4x2x2x56x1xf32>):
#         %27 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %28 = "arith.constant"() <{value = 28 : index}> : () -> index
#         %29 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %30 = "scf.for"(%27, %28, %29, %arg1) ({
#         ^bb0(%arg2: index, %arg3: tensor<56x4x4x2x2x56x1xf32>):
#           %31 = "arith.constant"() <{value = 0 : index}> : () -> index
#           %32 = "arith.constant"() <{value = 2 : index}> : () -> index
#           %33 = "arith.constant"() <{value = 2 : index}> : () -> index
#           %34 = "scf.for"(%31, %32, %33, %arg3) ({
#           ^bb0(%arg4: index, %arg5: tensor<56x4x4x2x2x56x1xf32>):
#             %35 = "arith.constant"() <{value = 0 : index}> : () -> index
#             %36 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %37 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %38 = "scf.for"(%35, %36, %37, %arg5) ({
#             ^bb0(%arg6: index, %arg7: tensor<56x4x4x2x2x56x1xf32>):
#               %39 = "tensor.extract_slice"(%0, %arg4, %arg6) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808>, static_sizes = array<i64: 2, 2>, static_strides = array<i64: 1, 1>}> : (tensor<2x2xf32>, index, index) -> tensor<2x2xf32>
#               %40 = "tensor.extract_slice"(%9, %arg0, %arg2) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808, 0>, static_sizes = array<i64: 4, 4, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<28x28x1xf32>, index, index) -> tensor<4x4x1xf32>
#               %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#               %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#               ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                 %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 "linalg.yield"(%47) : (f32) -> ()
#               }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#               %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#               %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#       }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#       %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#         "linalg.yield"(%27) : (f32) -> ()
#       }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#       "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#       "func.return"() : () -> ()
#     }) : () -> ()
#   }) : () -> ()
#   "hal.executable.variant_end"() : () -> ()
# }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.recompute:12853:13: error: failed to serialize executables
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.recompute:3875:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.recompute:12853:13: note: see current operation:
# "hal.executable"() ({
#   "hal.executable.variant"() ({
#     "hal.executable.export"() ({
#     ^bb0(%arg0: !hal.device):
#       %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#       %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#       "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#     }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_1067_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#     "builtin.module"() ({
#       "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_1067_generic_128x28x28x2x2_f32"}> ({
#         %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#         %1 = "arith.constant"() <{value = 23028928 : index}> : () -> index
#         %2 = "arith.constant"() <{value = 14197952 : index}> : () -> index
#         %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#         %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
#         %6 = "hal.interface.binding.subspan"(%2) {alignment = 64 : index, binding = 1 : index, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>
#         %7 = "hal.interface.workgroup.id"() {dimension = 0 : index} : () -> index
#         %8 = "flow.dispatch.tensor.load"(%6, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> tensor<56x56x1xf32>
#         %9 = "flow.dispatch.tensor.load"(%5, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 28, 28, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>, index) -> tensor<28x28x1xf32>
#         %10 = "linalg.fill"(%4, %8) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) {lowering_config = #iree_codegen.lowering_config<tile_sizes = [[1], [0, 4, 4, 2, 2]]>} : (f32, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         %11 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %12 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %13 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %14 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %15 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %16 = "tensor.empty"() : () -> tensor<56x4x4x2x2x56x1xf32>
#         %17 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %18 = "linalg.fill"(%17, %16) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) : (f32, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %19 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %20 = "arith.constant"() <{value = 1 : index}> : () -> index
#         %21 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %22 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %23 = "arith.constant"() <{value = 28 : index}> : () -> index
#         %24 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %25 = "scf.for"(%22, %23, %24, %18) ({
#         ^bb0(%arg0: index, %arg1: tensor<56x4x4x2x2x56x1xf32>):
#           %27 = "arith.constant"() <{value = 0 : index}> : () -> index
#           %28 = "arith.constant"() <{value = 28 : index}> : () -> index
#           %29 = "arith.constant"() <{value = 4 : index}> : () -> index
#           %30 = "scf.for"(%27, %28, %29, %arg1) ({
#           ^bb0(%arg2: index, %arg3: tensor<56x4x4x2x2x56x1xf32>):
#             %31 = "arith.constant"() <{value = 0 : index}> : () -> index
#             %32 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %33 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %34 = "scf.for"(%31, %32, %33, %arg3) ({
#             ^bb0(%arg4: index, %arg5: tensor<56x4x4x2x2x56x1xf32>):
#               %35 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %36 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %37 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %38 = "scf.for"(%35, %36, %37, %arg5) ({
#               ^bb0(%arg6: index, %arg7: tensor<56x4x4x2x2x56x1xf32>):
#                 %39 = "tensor.extract_slice"(%0, %arg4, %arg6) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808>, static_sizes = array<i64: 2, 2>, static_strides = array<i64: 1, 1>}> : (tensor<2x2xf32>, index, index) -> tensor<2x2xf32>
#                 %40 = "tensor.extract_slice"(%9, %arg0, %arg2) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808, 0>, static_sizes = array<i64: 4, 4, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<28x28x1xf32>, index, index) -> tensor<4x4x1xf32>
#                 %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#                 %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#                 ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                   %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   "linalg.yield"(%47) : (f32) -> ()
#                 }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#                 %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#                 %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#                 %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#                 "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#               }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#           "linalg.yield"(%27) : (f32) -> ()
#         }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#         "func.return"() : () -> ()
#       }) : () -> ()
#     }) : () -> ()
#     "hal.executable.variant_end"() : () -> ()
#   }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#   "hal.executable_end"() : () -> ()
# }) {sym_name = "dforward_dispatch_1067", sym_visibility = "private"} : () -> ()
#     %5017 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%370, %cst_29, %5016 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:10762:13: error: expected 7 offset values, got 5
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:5051:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.storeall:10762:13: note: see current operation: %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:10762:13: error: failed to run translation of source executable to target executable for backend #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:5051:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.storeall:10762:13: note: see current operation:
# "hal.executable.variant"() ({
#   "hal.executable.export"() ({
#   ^bb0(%arg0: !hal.device):
#     %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#     %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#     "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#   }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_655_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#   "builtin.module"() ({
#     "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_655_generic_128x28x28x2x2_f32"}> ({
#       %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#       %1 = "arith.constant"() <{value = 305280 : index}> : () -> index
#       %2 = "arith.constant"() <{value = 706688 : index}> : () -> index
#       %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#       %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#       %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
#       %6 = "hal.interface.binding.subspan"(%2) {alignment = 64 : index, binding = 1 : index, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>
#       %7 = "hal.interface.workgroup.id"() {dimension = 0 : index} : () -> index
#       %8 = "flow.dispatch.tensor.load"(%6, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> tensor<56x56x1xf32>
#       %9 = "flow.dispatch.tensor.load"(%5, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 28, 28, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>, index) -> tensor<28x28x1xf32>
#       %10 = "linalg.fill"(%4, %8) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         "linalg.yield"(%arg0) : (f32) -> ()
#       }) {lowering_config = #iree_codegen.lowering_config<tile_sizes = [[1], [0, 4, 4, 2, 2]]>} : (f32, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#       %11 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %12 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %13 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %14 = "arith.constant"() <{value = 2 : index}> : () -> index
#       %15 = "arith.constant"() <{value = 2 : index}> : () -> index
#       %16 = "tensor.empty"() : () -> tensor<56x4x4x2x2x56x1xf32>
#       %17 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#       %18 = "linalg.fill"(%17, %16) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         "linalg.yield"(%arg0) : (f32) -> ()
#       }) : (f32, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#       %19 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %20 = "arith.constant"() <{value = 1 : index}> : () -> index
#       %21 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %22 = "arith.constant"() <{value = 0 : index}> : () -> index
#       %23 = "arith.constant"() <{value = 28 : index}> : () -> index
#       %24 = "arith.constant"() <{value = 4 : index}> : () -> index
#       %25 = "scf.for"(%22, %23, %24, %18) ({
#       ^bb0(%arg0: index, %arg1: tensor<56x4x4x2x2x56x1xf32>):
#         %27 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %28 = "arith.constant"() <{value = 28 : index}> : () -> index
#         %29 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %30 = "scf.for"(%27, %28, %29, %arg1) ({
#         ^bb0(%arg2: index, %arg3: tensor<56x4x4x2x2x56x1xf32>):
#           %31 = "arith.constant"() <{value = 0 : index}> : () -> index
#           %32 = "arith.constant"() <{value = 2 : index}> : () -> index
#           %33 = "arith.constant"() <{value = 2 : index}> : () -> index
#           %34 = "scf.for"(%31, %32, %33, %arg3) ({
#           ^bb0(%arg4: index, %arg5: tensor<56x4x4x2x2x56x1xf32>):
#             %35 = "arith.constant"() <{value = 0 : index}> : () -> index
#             %36 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %37 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %38 = "scf.for"(%35, %36, %37, %arg5) ({
#             ^bb0(%arg6: index, %arg7: tensor<56x4x4x2x2x56x1xf32>):
#               %39 = "tensor.extract_slice"(%0, %arg4, %arg6) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808>, static_sizes = array<i64: 2, 2>, static_strides = array<i64: 1, 1>}> : (tensor<2x2xf32>, index, index) -> tensor<2x2xf32>
#               %40 = "tensor.extract_slice"(%9, %arg0, %arg2) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808, 0>, static_sizes = array<i64: 4, 4, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<28x28x1xf32>, index, index) -> tensor<4x4x1xf32>
#               %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#               %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#               ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                 %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 "linalg.yield"(%47) : (f32) -> ()
#               }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#               %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#               %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#       }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#       %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#         "linalg.yield"(%27) : (f32) -> ()
#       }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#       "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#       "func.return"() : () -> ()
#     }) : () -> ()
#   }) : () -> ()
#   "hal.executable.variant_end"() : () -> ()
# }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:10762:13: error: failed to serialize executables
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.storeall:5051:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.storeall:10762:13: note: see current operation:
# "hal.executable"() ({
#   "hal.executable.variant"() ({
#     "hal.executable.export"() ({
#     ^bb0(%arg0: !hal.device):
#       %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#       %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#       "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#     }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_655_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#     "builtin.module"() ({
#       "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_655_generic_128x28x28x2x2_f32"}> ({
#         %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#         %1 = "arith.constant"() <{value = 305280 : index}> : () -> index
#         %2 = "arith.constant"() <{value = 706688 : index}> : () -> index
#         %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#         %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
#         %6 = "hal.interface.binding.subspan"(%2) {alignment = 64 : index, binding = 1 : index, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>
#         %7 = "hal.interface.workgroup.id"() {dimension = 0 : index} : () -> index
#         %8 = "flow.dispatch.tensor.load"(%6, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> tensor<56x56x1xf32>
#         %9 = "flow.dispatch.tensor.load"(%5, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 28, 28, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>, index) -> tensor<28x28x1xf32>
#         %10 = "linalg.fill"(%4, %8) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) {lowering_config = #iree_codegen.lowering_config<tile_sizes = [[1], [0, 4, 4, 2, 2]]>} : (f32, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         %11 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %12 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %13 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %14 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %15 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %16 = "tensor.empty"() : () -> tensor<56x4x4x2x2x56x1xf32>
#         %17 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %18 = "linalg.fill"(%17, %16) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) : (f32, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %19 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %20 = "arith.constant"() <{value = 1 : index}> : () -> index
#         %21 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %22 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %23 = "arith.constant"() <{value = 28 : index}> : () -> index
#         %24 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %25 = "scf.for"(%22, %23, %24, %18) ({
#         ^bb0(%arg0: index, %arg1: tensor<56x4x4x2x2x56x1xf32>):
#           %27 = "arith.constant"() <{value = 0 : index}> : () -> index
#           %28 = "arith.constant"() <{value = 28 : index}> : () -> index
#           %29 = "arith.constant"() <{value = 4 : index}> : () -> index
#           %30 = "scf.for"(%27, %28, %29, %arg1) ({
#           ^bb0(%arg2: index, %arg3: tensor<56x4x4x2x2x56x1xf32>):
#             %31 = "arith.constant"() <{value = 0 : index}> : () -> index
#             %32 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %33 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %34 = "scf.for"(%31, %32, %33, %arg3) ({
#             ^bb0(%arg4: index, %arg5: tensor<56x4x4x2x2x56x1xf32>):
#               %35 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %36 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %37 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %38 = "scf.for"(%35, %36, %37, %arg5) ({
#               ^bb0(%arg6: index, %arg7: tensor<56x4x4x2x2x56x1xf32>):
#                 %39 = "tensor.extract_slice"(%0, %arg4, %arg6) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808>, static_sizes = array<i64: 2, 2>, static_strides = array<i64: 1, 1>}> : (tensor<2x2xf32>, index, index) -> tensor<2x2xf32>
#                 %40 = "tensor.extract_slice"(%9, %arg0, %arg2) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808, 0>, static_sizes = array<i64: 4, 4, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<28x28x1xf32>, index, index) -> tensor<4x4x1xf32>
#                 %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#                 %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#                 ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                   %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   "linalg.yield"(%47) : (f32) -> ()
#                 }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#                 %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#                 %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#                 %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#                 "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#               }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#           "linalg.yield"(%27) : (f32) -> ()
#         }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#         "func.return"() : () -> ()
#       }) : () -> ()
#     }) : () -> ()
#     "hal.executable.variant_end"() : () -> ()
#   }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#   "hal.executable_end"() : () -> ()
# }) {sym_name = "dforward_dispatch_655", sym_visibility = "private"} : () -> ()
#     %3161 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global435, %cst_29, %3160 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:10452:13: error: expected 7 offset values, got 5
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:4803:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.heuristic:10452:13: note: see current operation: %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:10452:13: error: failed to run translation of source executable to target executable for backend #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:4803:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.heuristic:10452:13: note: see current operation:
# "hal.executable.variant"() ({
#   "hal.executable.export"() ({
#   ^bb0(%arg0: !hal.device):
#     %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#     %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#     "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#   }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_652_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#   "builtin.module"() ({
#     "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_652_generic_128x28x28x2x2_f32"}> ({
#       %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#       %1 = "arith.constant"() <{value = 4014080 : index}> : () -> index
#       %2 = "arith.constant"() <{value = 4415488 : index}> : () -> index
#       %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#       %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#       %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
# ...
#               %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#               %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#               ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                 %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                 "linalg.yield"(%47) : (f32) -> ()
#               }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#               %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#               %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#       }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#       %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#       ^bb0(%arg0: f32, %arg1: f32):
#         %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#         "linalg.yield"(%27) : (f32) -> ()
#       }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#       "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#       "func.return"() : () -> ()
#     }) : () -> ()
#   }) : () -> ()
#   "hal.executable.variant_end"() : () -> ()
# }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:10452:13: error: failed to serialize executables
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# densenet201.mlir.v1.heuristic:4803:3: note: called from
#   func.func @dforward(%arg0: tensor<1x1000xf32>) -> tensor<1x3x224x224xf32> {
#   ^
# densenet201.mlir.v1.heuristic:10452:13: note: see current operation:
# "hal.executable"() ({
#   "hal.executable.variant"() ({
#     "hal.executable.export"() ({
#     ^bb0(%arg0: !hal.device):
#       %0 = "arith.constant"() <{value = 128 : index}> : () -> index
#       %1 = "arith.constant"() <{value = 1 : index}> : () -> index
#       "hal.return"(%0, %1, %1) : (index, index, index) -> ()
#     }) {layout = #hal.pipeline.layout<push_constants = 0, sets = [<0, bindings = [<0, storage_buffer, ReadOnly>, <1, storage_buffer>]>]>, ordinal = 0 : index, subgroup_size = 32 : index, sym_name = "dforward_dispatch_652_generic_128x28x28x2x2_f32", translation_info = #iree_codegen.translation_info<LLVMGPUWarpReduction>, workgroup_size = [32 : index, 1 : index, 1 : index]} : () -> ()
#     "builtin.module"() ({
#       "func.func"() <{function_type = () -> (), sym_name = "dforward_dispatch_652_generic_128x28x28x2x2_f32"}> ({
#         %0 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<2x2xf32>}> : () -> tensor<2x2xf32>
#         %1 = "arith.constant"() <{value = 4014080 : index}> : () -> index
#         %2 = "arith.constant"() <{value = 4415488 : index}> : () -> index
#         %3 = "arith.constant"() <{value = 2.500000e-01 : f32}> : () -> f32
#         %4 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %5 = "hal.interface.binding.subspan"(%1) {alignment = 64 : index, binding = 0 : index, descriptor_flags = 1 : i32, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>
#         %6 = "hal.interface.binding.subspan"(%2) {alignment = 64 : index, binding = 1 : index, descriptor_type = #hal.descriptor_type<storage_buffer>, operandSegmentSizes = array<i32: 1, 0>, set = 0 : index} : (index) -> !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>
#         %7 = "hal.interface.workgroup.id"() {dimension = 0 : index} : () -> index
#         %8 = "flow.dispatch.tensor.load"(%6, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> tensor<56x56x1xf32>
#         %9 = "flow.dispatch.tensor.load"(%5, %7) <{operandSegmentSizes = array<i32: 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 28, 28, 1>, static_strides = array<i64: 1, 1, 1>}> : (!flow.dispatch.tensor<readonly:tensor<28x28x128xf32>>, index) -> tensor<28x28x1xf32>
#         %10 = "linalg.fill"(%4, %8) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) {lowering_config = #iree_codegen.lowering_config<tile_sizes = [[1], [0, 4, 4, 2, 2]]>} : (f32, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         %11 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %12 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %13 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %14 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %15 = "arith.constant"() <{value = 2 : index}> : () -> index
#         %16 = "tensor.empty"() : () -> tensor<56x4x4x2x2x56x1xf32>
#         %17 = "arith.constant"() <{value = 0.000000e+00 : f32}> : () -> f32
#         %18 = "linalg.fill"(%17, %16) <{operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           "linalg.yield"(%arg0) : (f32) -> ()
#         }) : (f32, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %19 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %20 = "arith.constant"() <{value = 1 : index}> : () -> index
#         %21 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %22 = "arith.constant"() <{value = 0 : index}> : () -> index
#         %23 = "arith.constant"() <{value = 28 : index}> : () -> index
#         %24 = "arith.constant"() <{value = 4 : index}> : () -> index
#         %25 = "scf.for"(%22, %23, %24, %18) ({
#         ^bb0(%arg0: index, %arg1: tensor<56x4x4x2x2x56x1xf32>):
#           %27 = "arith.constant"() <{value = 0 : index}> : () -> index
#           %28 = "arith.constant"() <{value = 28 : index}> : () -> index
#           %29 = "arith.constant"() <{value = 4 : index}> : () -> index
#           %30 = "scf.for"(%27, %28, %29, %arg1) ({
#           ^bb0(%arg2: index, %arg3: tensor<56x4x4x2x2x56x1xf32>):
#             %31 = "arith.constant"() <{value = 0 : index}> : () -> index
#             %32 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %33 = "arith.constant"() <{value = 2 : index}> : () -> index
#             %34 = "scf.for"(%31, %32, %33, %arg3) ({
#             ^bb0(%arg4: index, %arg5: tensor<56x4x4x2x2x56x1xf32>):
#               %35 = "arith.constant"() <{value = 0 : index}> : () -> index
#               %36 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %37 = "arith.constant"() <{value = 2 : index}> : () -> index
#               %38 = "scf.for"(%35, %36, %37, %arg5) ({
#               ^bb0(%arg6: index, %arg7: tensor<56x4x4x2x2x56x1xf32>):
#                 %39 = "tensor.extract_slice"(%0, %arg4, %arg6) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808>, static_sizes = array<i64: 2, 2>, static_strides = array<i64: 1, 1>}> : (tensor<2x2xf32>, index, index) -> tensor<2x2xf32>
#                 %40 = "tensor.extract_slice"(%9, %arg0, %arg2) <{operandSegmentSizes = array<i32: 1, 2, 0, 0>, static_offsets = array<i64: -9223372036854775808, -9223372036854775808, 0>, static_sizes = array<i64: 4, 4, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<28x28x1xf32>, index, index) -> tensor<4x4x1xf32>
#                 %41 = "tensor.extract_slice"(%arg7, %20) <{operandSegmentSizes = array<i32: 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<?x4x4x2x2xf32>
#                 %42 = "linalg.generic"(%39, %40, %41) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4) -> (d3, d4)>, affine_map<(d0, d1, d2, d3, d4) -> (d1, d2, d0)>, affine_map<(d0, d1, d2, d3, d4) -> (d1 * 2 + d3, d1, d2, d3, d4, d2 * 2 + d4, d0)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 2, 1>}> ({
#                 ^bb0(%arg8: f32, %arg9: f32, %arg10: f32):
#                   %46 = "arith.mulf"(%arg9, %3) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   %47 = "arith.addf"(%46, %arg10) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#                   "linalg.yield"(%47) : (f32) -> ()
#                 }) : (tensor<2x2xf32>, tensor<4x4x1xf32>, tensor<?x4x4x2x2xf32>) -> tensor<?x4x4x2x2xf32>
#                 %43 = "arith.constant"() <{value = 0 : index}> : () -> index
#                 %44 = "tensor.dim"(%42, %43) : (tensor<?x4x4x2x2xf32>, index) -> index
#                 %45 = "tensor.insert_slice"(%42, %arg7, %44) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0>, static_offsets = array<i64: 0, 0, 0, 0, 0>, static_sizes = array<i64: -9223372036854775808, 4, 4, 2, 2>, static_strides = array<i64: 1, 1, 1, 1, 1>}> : (tensor<?x4x4x2x2xf32>, tensor<56x4x4x2x2x56x1xf32>, index) -> tensor<56x4x4x2x2x56x1xf32>
#                 "scf.yield"(%45) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#               }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#               "scf.yield"(%38) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#             }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#             "scf.yield"(%34) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#           }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#           "scf.yield"(%30) : (tensor<56x4x4x2x2x56x1xf32>) -> ()
#         }) : (index, index, index, tensor<56x4x4x2x2x56x1xf32>) -> tensor<56x4x4x2x2x56x1xf32>
#         %26 = "linalg.generic"(%25, %10) <{indexing_maps = [affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d1, d2, d3, d4, d5, d6)>, affine_map<(d0, d1, d2, d3, d4, d5, d6) -> (d0, d5, d6)>], iterator_types = [#linalg.iterator_type<parallel>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<reduction>, #linalg.iterator_type<parallel>, #linalg.iterator_type<parallel>], operandSegmentSizes = array<i32: 1, 1>}> ({
#         ^bb0(%arg0: f32, %arg1: f32):
#           %27 = "arith.addf"(%arg0, %arg1) <{fastmath = #arith.fastmath<none>}> : (f32, f32) -> f32
#           "linalg.yield"(%27) : (f32) -> ()
#         }) : (tensor<56x4x4x2x2x56x1xf32>, tensor<56x56x1xf32>) -> tensor<56x56x1xf32>
#         "flow.dispatch.tensor.store"(%26, %6, %7) <{operandSegmentSizes = array<i32: 1, 1, 0, 1, 0, 0>, static_offsets = array<i64: 0, 0, -9223372036854775808>, static_sizes = array<i64: 56, 56, 1>, static_strides = array<i64: 1, 1, 1>}> : (tensor<56x56x1xf32>, !flow.dispatch.tensor<writeonly:tensor<56x56x128xf32>>, index) -> ()
#         "func.return"() : () -> ()
#       }) : () -> ()
#     }) : () -> ()
#     "hal.executable.variant_end"() : () -> ()
#   }) {sym_name = "cuda_nvptx_fb", target = #hal.executable.target<"cuda", "cuda-nvptx-fb", {target_arch = "sm_86"}>} : () -> ()
#   "hal.executable_end"() : () -> ()
# }) {sym_name = "dforward_dispatch_652", sym_visibility = "private"} : () -> ()
#     %3223 = linalg.generic {indexing_maps = [#map3, #map1, #map2, #map3], iterator_types = ["parallel", "reduction", "reduction", "parallel", "reduction", "reduction"]} ins(%global217, %cst_29, %3222 : tensor<1x56x56x128xf32>, tensor<2x2xf32>, tensor<1x28x28x128xf32>) outs(%cst_4 : tensor<1x56x56x128xf32>) {
#             ^
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 42
#      37     return vmo
#      39 #recompute_fb, storeall_fb = [
#      40 #    load_executable(x) for x in [recompute, storeall]
#      41 #]
# ---> 42 recompute_fb = load_executable(recompute)
#      43 storeall_fb = load_executable(storeall)
#      44 #hybrid_fb = load_executable(hybrid)
#
# Cell In[2], line 33, in load_executable(fb_file)
#      30 vmi = iree.runtime.VmInstance()
#      31 # replace compile with args of fatbin type
#      32 # fb_file = ragdoll.compile(mlir, "gpu", "input", "codegen", benchmark=True)
# ---> 33 with open(fb_file, 'rb') as f:
#      34     binary_data = f.read()
#      35 vmm = iree.runtime.VmModule.from_flatbuffer(vmi, binary_data)
#
# File ~/miniconda3/envs/albert-research-py310/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'densenet201.mlir.v1.recompute.vmfb'

# %%
#f1 = timeit("recompute_fb.forward(image_np)") / BENCHMARK_REPEAT
f1 = timeit("recompute_fb.forward(image_np_transposed)") / BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-forward in timeit: ', f1)
b1 = timeit("recompute_fb.dforward(grad_np)") /  BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-backward in timeit: ', b1)
df = pd.concat([df, get_dataframe(f1, b1, "Nabla-Recompute")])
print(df)

# %%
f1 = timeit("storeall_fb.forward(image_np_transposed)") / BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-forward in timeit: ', f1)
b1 = timeit("storeall_fb.dforward(grad_np)") / BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-forward in timeit: ', b1)
df = pd.concat([df, get_dataframe(f1, b1, "Nabla-Storeall")])
print(df)

# %% [raw]
# f1 = timeit("hybrid_fb.forward(image_np_transposed)") / BENCHMARK_REPEAT
# print('ragdoll-opt1-gpu-forward in timeit: ', f1)
# b1 = timeit("hybrid_fb.dforward(grad_np)") / BENCHMARK_REPEAT
# print('ragdoll-opt1-gpu-forward in timeit: ', b1)
# df = pd.concat([df, get_dataframe(f1, b1, "Nabla-Hybrid")])
# print(df)

# %%
f1 = timeit("heuristic_fb.forward(image_np_transposed)") / BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-forward in timeit: ', f1)
b1 = timeit("heuristic_fb.dforward(grad_np)") / BENCHMARK_REPEAT
print('ragdoll-opt1-gpu-forward in timeit: ', b1)
df = pd.concat([df, get_dataframe(f1, b1, "Nabla-Heuristic")])
print(df)

# %% [raw]
# f1 = timeit("heuristic2_fb.forward(image_np_transposed)") / BENCHMARK_REPEAT
# print('ragdoll-opt1-gpu-forward in timeit: ', f1)
# b1 = timeit("heuristic2_fb.dforward(grad_np)") / BENCHMARK_REPEAT
# print('ragdoll-opt1-gpu-forward in timeit: ', b1)
# df = pd.concat([df, get_dataframe(f1, b1, "Nabla-Heuristic-Mulswap")])
# print(df)

# %%
df.style.hide(axis="index")
plt.rcParams["figure.dpi"] = 300

sns.barplot(df, x="pass", y="time", hue="item")
plt.xlabel("Pass")
plt.ylabel("Time Normalized (ms)")
plt.legend().set_title("Item")
plt.title(model_name)

plt.savefig(f"{model_name}-time.png")
